# %% [markdown]
# # Cryer & Chan (2008) Dataset 3 (S-Z)

# %% [markdown]
# ## `SP`
#
# * Quarterly S&P Composite Index
# * 1936Q1–1977Q4
# * Source: Frees, E. W., Data Analysis Using Regression Models, Prentice-Hall, Engelwood Cliffs,NJ, 1996.

# %%
df = pd.read_csv("data/tsa/SP.dat")
df.index = pd.date_range("1936Q1", "1977Q4", freq="QS")
df.tail()
# Out:
#                 SP
# 1976-10-01  1074.6
# 1977-01-01   984.2
# 1977-04-01  1004.8
# 1977-07-01   965.3
# 1977-10-01   951.0

# %%
df.plot()

# %% [markdown]
# ## `spots`
#
# * Annual American (relative) sunspot numbers collected
# * 1945 to 2005
# * The annual (relative) sunspot number is a weighted average of solar activities measured from a network of observatories.
# * Source: www.ngdc.noaa.gov/stp/SOLAR/ftpsunspotnumber.html#american

# %%
df = pd.read_csv("data/tsa/spots.dat")
df.index = pd.date_range("1945", "2005", freq="AS")
df.tail()
# Out:
#             spots
# 2001-01-01  123.3
# 2002-01-01  109.4
# 2003-01-01   65.9
# 2004-01-01   43.3
# 2005-01-01   30.2

# %%
df.plot()

# %% [markdown]
# ## `spots1`
#
# * Annual international sunspot numbers, NOAA National Geophysical Data Center.
# * 1700 - 2005
# * Source: ftp.ngdc.noaa.gov/STP/SOLAR_DATA/SUNSPOT_NUMBERS/YEARLY.PLT

# %%
df = pd.read_csv("data/tsa/spots1.dat")
df.index = pd.date_range("1700", "2005", freq="AS")
df.tail()
# Out:
#             spots1
# 2001-01-01   111.0
# 2002-01-01   104.0
# 2003-01-01    63.7
# 2004-01-01    40.4
# 2005-01-01    29.8

# %%
df.plot()

# %% [markdown]
# ## `star`
#
# * Brightness of a variable star at midnight on 600 successive nights.
# * Source: www.statsci.org/data/general/star.html

# %%
df = pd.read_csv("data/tsa/star.dat")
df.index = pd.date_range(0, periods=len(df), freq="D")
df.head()
# Out:
#             star
# 1970-01-01    25
# 1970-01-02    28
# 1970-01-03    31
# 1970-01-04    32
# 1970-01-05    33

# %%
df.plot()

# %% [markdown]
# ## `tbone`
#
# * A digitized sound file of about 0.4 seconds of a Bb just below middle C
# * played on a tenor trombone by Chuck Kreeb, a member of Tempered Brass and a friend of one of the authors.

# %%
df = pd.read_csv("data/tsa/tbone.dat")
df.index = pd.date_range(0, periods=len(df), freq="100us")
df.tail()
# Out:
#                                tbone
# 1970-01-01 00:00:00.441800 -0.074036
# 1970-01-01 00:00:00.441900  0.364746
# 1970-01-01 00:00:00.442000  0.630280
# 1970-01-01 00:00:00.442100  0.696167
# 1970-01-01 00:00:00.442200  0.670197

# %%
df[:300].plot()

# %% [markdown]
# ## `tempdub`
#
# * Monthly average temperatures in Dubuque, Iowa
# * 1/1964–12/1975
# * Source: http://mesonet.agron.iastate.edu/climodat/index.phtml?station=ia2364&report=16

# %%
df = pd.read_csv("data/tsa/tempdub.dat")
df.index = pd.date_range("1/1964", "12/1975", freq="MS")
df.tail()
# Out:
#             tempdub
# 1975-08-01     71.1
# 1975-09-01     57.3
# 1975-10-01     52.5
# 1975-11-01     40.6
# 1975-12-01     26.2

# %%
df.plot()

# %% [markdown]
# ## `tuba`
#
# * A digitized sound file of about 0.4 seconds of a Bb an octave and one whole step below middle C
# * played on a BBb tuba by Linda Fisher, a member of Tempered Brass and a friend of one of the authors.

# %%
df = pd.read_csv("data/tsa/tuba.dat")
df.index = pd.date_range(0, periods=len(df), freq="100us")
df.tail()
# Out:
#                                 tuba
# 1970-01-01 00:00:00.439700 -0.256683
# 1970-01-01 00:00:00.439800 -0.327118
# 1970-01-01 00:00:00.439900 -0.400635
# 1970-01-01 00:00:00.440000 -0.468994
# 1970-01-01 00:00:00.440100 -0.526703

# %%
df[:300].plot()

# %% [markdown]
# ## `units`
#
# * Annual sales of certain large equipment
# * 1983–2006
# * Proprietary sales data from a large international company

# %%
df = pd.read_csv("data/tsa/units.dat")
df.index = pd.date_range("1983", periods=len(df), freq="AS")
df.tail()
# Out:
#               units
# 2002-01-01  142.170
# 2003-01-01  129.730
# 2004-01-01  134.704
# 2005-01-01  178.144
# 2006-01-01  211.650

# %%
df.plot()

# %% [markdown]
# ## `usd.hkd`
#
# * Daily exchange rates of U.S. dollar to Hong Kong dollar,
# * 01/2005–03/2006
# * A data frame with 431 observations on the following six variables.
#   * r: daily returns of USD/HKD exchange rates
#   * v: estimated conditional variances based on an AR(1)+GARCH(3,1)
#   * hkrate: daily USD/HKD exchange rates
#   * outlier1: dummy variable of day 203, corresponding to July 22, 2005
#   * outlier2: dummy variable of day 290, another possible outlier
#   * day: calendar day
# * Source: www.oanda.com/convert/fxhistory

# %%
df = pd.read_csv("data/tsa/usd.hkd.dat", sep=" ")
df.index = pd.date_range("01/2005", periods=len(df), freq="B")
df.head()
# Out:
#                    r         v    hkrate  outlier1  outlier2  day
# 2005-01-03 -0.030453  0.000681 -0.030869         0         0    1
# 2005-01-04 -0.011480  0.000751 -0.006432         0         0    2
# 2005-01-05  0.024675  0.000565  0.025726         0         0    3
# 2005-01-06  0.042784  0.000622  0.038577         0         0    4
# 2005-01-07  0.107824  0.001000  0.101516         0         0    5

# %%
df.hkrate.plot()

# %% [markdown]
# ## `veilleux`
#
# * A bivariate time series from an experiment studying prey-predator dynamics.
# * The first time series consists of the number of prey individuals (Didinium natsutum) per ml measured every 12 hours
# over a period of 35 days.
# * The second time series consists of the corresponding number of predators (Paramecium aurelia) per ml.
# * Source: Veilleux, B. G. (1976) “The analysis of a predatory interaction between Didinium and Paramecium.” MSc thesis, University of
# Alberta, Canada. See also www.journals.royalsoc.ac.uk/content/lekv0yqp2ecpabvd/archive1.pdf

# %%
df = pd.read_csv("data/tsa/veilleux.dat", sep=" ")
df.index = pd.date_range(0, periods=len(df), freq="12H")
df.head()
# Out:
#                      Didinium  Paramecium
# 1970-01-01 00:00:00     15.65        5.76
# 1970-01-01 12:00:00     53.57        9.05
# 1970-01-02 00:00:00     73.34       17.26
# 1970-01-02 12:00:00     93.93       41.97
# 1970-01-03 00:00:00    115.40       55.97

# %%
df.plot()

# %% [markdown]
# ## `wages`
#
# * Monthly average hourly wages in the U.S. apparel industry
# * 07/1981–06/1987
# * Source: Cryer, J. D. Time Series Analysis, Duxbury Press, Boston, 1986.

# %%
df = pd.read_csv("data/tsa/wages.dat")
df.index = pd.date_range("07/1981", "06/1987", freq="MS")
df.head()
# Out:
#             wages
# 1981-07-01   7.75
# 1981-08-01   7.74
# 1981-09-01   7.87
# 1981-10-01   7.89
# 1981-11-01   7.94

# %%
df.plot()

# %% [markdown]
# ## `winnebago`
#
# * Monthly unit sales of recreational vehicles from Winnebago, Inc.
# * 11/1966 to 02/1972
# * Source: Roberts, H. V., Data Analysis for Managers with Minitab, second edition, The Scientific Press, Redwood City, CA, 1991.

# %%
df = pd.read_csv("data/tsa/winnebago.dat")
df.index = pd.date_range("11/1966", "02/1972", freq="MS")
df.head()
# Out:
#             winnebago
# 1966-11-01         61
# 1966-12-01         48
# 1967-01-01         53
# 1967-02-01         78
# 1967-03-01         75

# %%
df.plot()
