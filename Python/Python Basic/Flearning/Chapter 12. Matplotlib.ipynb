# %% [markdown]
# # Chapter 12. Matplotlib

# %%
# %matplotlib nbagg # 노트북상에 나타나는 그림을 Interactive 하게 조정가능. inline 일 경우 조정이 불가능.

# %%
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
import numpy as np

# %% [markdown]
# ## 라인 플롯(line plot)
#  - 라인 플롯은 연속적인 직선으로 구성된 플롯입니다. 어떤 특정한 독립변수 X가 변화함에 따라 종속변수 Y가 어떻게 변화하는지를 나타내고자 할 때 라인 플롯을 사용합니다.

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s
# Out:
# 0     0.504982
# 10    0.103601
# 20   -1.679769
# 30   -1.077845
# 40   -0.970867
# 50   -0.387792
# 60   -0.248159
# 70   -0.669224
# 80    0.135149
# 90    1.146453
# dtype: float64

# %%
s.plot()
# plt.plot(s)
# Out:
# <img src="data:image/png;base64,...">

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(axis=0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10))
df
# Out:
#            A         B         C         D
# 0   0.860185  0.578756  0.089773  1.319223
# 10  1.155201  0.724897 -0.954035  1.701749
# 20  0.748491  0.737410 -3.407145  1.241831
# 30 -0.156661  0.331066 -2.599285  0.605293
# 40  0.703761  0.501866 -3.004670  1.485183
# 50  1.104557  0.815483 -3.726578  2.831660
# 60  0.366196  0.459640 -3.593132  1.766646
# 70  1.309031 -0.180293 -2.287576  1.125580
# 80  1.082481  0.533005 -2.232124 -0.307870
# 90  0.053863  0.799106 -0.587476 -0.805553

# %%
df.plot()
#plt.plot(df)
# Out:
# <img src="data:image/png;base64,...">

# %%
df["B"].plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## 바 플롯(bar plot)
#  - 바 플롯은 막대 형태의 플롯입니다. 독립변수 X가 변화하면서 종속변수 Y가 변화하는 양상을 나타낼 때, <br> X가 연속적인 숫자에 해당하는 경우 라인 플롯을 그렸다면, X가 유한 개의 값만을 가질 경우 바 플롯을 사용하면 유용합니다.

# %%
s2 = pd.Series(np.random.rand(16), index=list("abcdefghijklmnop"))
s2
# Out:
# a    0.782728
# b    0.741227
# c    0.314909
# d    0.850542
# e    0.222396
# f    0.972167
# g    0.187361
# h    0.790893
# i    0.754413
# j    0.179568
# k    0.104350
# l    0.980808
# m    0.541629
# n    0.077743
# o    0.897125
# p    0.423208
# dtype: float64

# %%
s2.plot(kind="bar")
# Out:
# <img src="data:image/png;base64,...">

# %%
s2.plot(kind="barh")
# Out:
# <img src="data:image/png;base64,...">

# %%
df2 = pd.DataFrame(np.random.rand(6, 4), 
                   index=["one", "two", "three", "four", "five", "six"],
                   columns=pd.Index(["A", "B", "C", "D"], name="Genus"))
df2
# Out:
# Genus         A         B         C         D
# one    0.453323  0.519227  0.730872  0.801882
# two    0.035631  0.342204  0.199274  0.417936
# three  0.259525  0.491071  0.394976  0.585023
# four   0.418271  0.775877  0.619288  0.356914
# five   0.417361  0.042292  0.998484  0.860786
# six    0.122119  0.536187  0.428464  0.749681

# %%
df2.plot(kind="bar")
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# - 바 플롯을 그릴 때 stacked=True 인자를 넣어주면, 하나의 인덱스에 대한 각 열의 값을 한 줄로 쌓아 표시해줍니다.

# %%
df2.plot(kind="barh", stacked=True)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## 히스토그램(histogram)
#
#  - 히스토그램의 경우 어느 하나의 변수 X가 가질 수 있는 값의 구간을 여러 개 설정한 뒤, 각각의 구간에 속하는 갯수를 막대 형태로 <br>나타낸 플롯입니다. Series로부터 히스토그램을 그릴 때는 인덱스를 따로 명시할 필요가 없으며, 그저 값들만 가지고 있으면 됩니다.

# %%
s3 = pd.Series(np.random.normal(0, 1, size=200))
s3.hist()
# Out:
# <img src="data:image/png;base64,...">

# %%
s3.hist(bins=50)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# - 만약 normed=True 인자를 넣어주면, 각 bin에 속하는 갯수를 전체 갯수로 나눈 비율, 즉 정규화한(normalized) 값을 사용하여 히스토그램을 그립니다.

# %%
s3.hist(bins=100, normed=True)
# Out:
# <img src="data:image/png;base64,...">
