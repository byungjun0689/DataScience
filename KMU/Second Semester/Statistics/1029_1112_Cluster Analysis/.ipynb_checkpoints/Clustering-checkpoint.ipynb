# Pennsylvania
# Rhode Island
# South Carolina
# South Dakota
# Tennessee
# Texas
# Utah
# Vermont
# Virginia
# Washington           31
# West Virginia       113        117
# Wisconsin           122        116            60
# Wyoming              15         42           108       123

# %%
options(repr.plot.width=5, repr.plot.height=5)
pairs(USArrests)
# Out:
# plot without title

# %%
mahalanobis(USArrests, colMeans(USArrests), cov(USArrests)) # 열의 중심에서 얼마나 떨어져있냐? 공분산 행렬을 통해서
# Out:
#        Alabama         Alaska        Arizona       Arkansas     California
#      2.3361665     15.1680638      5.7240749      1.4744001      6.5198834
#       Colorado    Connecticut       Delaware        Florida        Georgia
#      5.1675431      3.1199978      5.9206962      4.5555037      9.5556141
#         Hawaii          Idaho       Illinois        Indiana           Iowa
#      7.3838682      2.6996606      2.5572838      1.2856909      2.0936916
#         Kansas       Kentucky      Louisiana          Maine       Maryland
#      0.5659241      3.6753352      4.5743258      3.0391048      3.2438436
#  Massachusetts       Michigan      Minnesota    Mississippi       Missouri
#      3.4493654      2.2467698      1.6179094      7.8368676      0.9402315
#        Montana       Nebraska         Nevada  New Hampshire     New Jersey
#      1.0947097      0.7563206      8.1390645      2.2557657      4.0342537
#     New Mexico       New York North Carolina   North Dakota           Ohio
#      2.3134509      2.9272068     12.6102433      4.5070960      1.8374468
#       Oklahoma         Oregon   Pennsylvania   Rhode Island South Carolina
#      0.1216993      3.0387808      1.8044534      9.7843187      4.7363035
#   South Dakota      Tennessee          Texas           Utah        Vermont
#      2.7168038      3.6333816      3.8972486      2.5391464      7.1116744
#       Virginia     Washington  West Virginia      Wisconsin        Wyoming
#      0.2960040      2.2992245      3.8954199      2.3234779      0.5746895

# %% [markdown]
# ## 계층적 군집분석 : 최단 연결법(Single Linkage)

# %%
x <- data.frame(c(1,3,6,12,20))
rownames(x) <- c("a","b","c","d","e")
colnames(x) <- "range"
x
# Out:
#   range
# a     1
# b     3
# c     6
# d    12
# e    20

# %% [markdown]
#  - row / col Names은 각 해당 값
#  - 안의 Value는 두개의 거리 차이.

# %%
dist(x,method="euclidean")
# Out:
#    a  b  c  d
# b  2
# c  5  3
# d 11  9  6
# e 19 17 14  8

# %%
options(repr.plot.width=8, repr.plot.height=3)
par(mfrow=c(1,4))
hc1 <- hclust(dist(x),method="single")
plot(hc1)
hc2 <- hclust(dist(x),method="complete")
plot(hc2)
hc3 <- hclust(dist(x),method="average")
plot(hc3)
hc4 <- hclust(dist(x),method="ward.D")
plot(hc4)
par(mfrow=c(1,1))
# Out:
# Plot with title "Cluster Dendrogram"

# %% [markdown]
# ### Cluster  생성이후
#  - 우리가 짜른 기준에 잘 자른것이 맞는지. 특성이 비슷한게 무엇인지 등의 판단을 해야한다.

# %%
options(repr.plot.width=8, repr.plot.height=6)
hc1 <- hclust(dist(USArrests),method="single")
plot(hc1)
# Out:
# Plot with title "Cluster Dendrogram"

# %% [markdown]
# ### Cutree
#  - 몇개의 그룹으로 나누겠다.
#  - Height 몇에서 자르겠다. 등의 조건을 줄 수있다.

# %%
USArrests_s <- scale(USArrests)

# %%
hc3 <- hclust(dist(USArrests_s),method="average")
hc3_result <- cutree(hc3,k=5)

# %% [markdown]
#  - 어디 Cluster에 있는지 표시

# %%
t(hc3_result)
# Out:
#      Alabama Alaska Arizona Arkansas California Colorado Connecticut Delaware
# [1,] "1"     "2"    "3"     "4"      "3"        "3"      "4"         "4"
#      Florida Georgia ...   South Dakota Tennessee Texas Utah Vermont Virginia
# [1,] "3"     "1"     "..." "5"          "1"       "3"   "4"  "5"     "4"
#      Washington West Virginia Wisconsin Wyoming
# [1,] "4"        "5"           "4"       "4"

# %%
options(repr.plot.width=5, repr.plot.height=4)
plot(Murder ~ Assault, data=USArrests_s, col=hc3_result,pch=hc3_result)
# Out:
# plot without title

# %%
plot(Murder ~ Assault, data=USArrests, type="n")
text(USArrests$Assault,USArrests$Murder, rownames(USArrests), col=hc3_result, cex=0.5)
# Out:
# plot without title

# %% [markdown]
#  - 각 군집의 특징을 보는 것이좋다.

# %%
USArrests_s <- cbind(USArrests_s,hc3_result)

# %%
head(USArrests_s)
# Out:
#                Murder   Assault   UrbanPop         Rape hc3_result
# Alabama    1.24256408 0.7828393 -0.5209066 -0.003416473          1
# Alaska     0.50786248 1.1068225 -1.2117642  2.484202941          2
# Arizona    0.07163341 1.4788032  0.9989801  1.042878388          3
# Arkansas   0.23234938 0.2308680 -1.0735927 -0.184916602          4
# California 0.27826823 1.2628144  1.7589234  2.067820292          3
# Colorado   0.02571456 0.3988593  0.8608085  1.864967207          3

# %%
options(repr.plot.width=8, repr.plot.height=8)
par(mfrow=c(2,2))
for (i in 1:4){
     boxplot(USArrests_s[,i]~USArrests_s[,5],main=names(USArrests)[i])
}
# Out:
# Plot with title "Rape"

# %%
USArrests_s[hc3_result==2,]
# Out:
#     Murder    Assault   UrbanPop       Rape hc3_result
#  0.5078625  1.1068225 -1.2117642  2.4842029  2.0000000

# %% [markdown]
#  - 위와 같이 하나의 데이터만 있기 때문에 그냥 하나로 ( 벡터로 인식 ) 출력된다.
#  - Matrix형태로 변환해서 출력되야한다.

# %%
par(mfrow=c(2,3))
for(i in 1:5){
    boxplot(USArrests_s[hc3_result==i,-5],las=2, main=paste("Group",i))
}
# Out:
# Plot with title "Group 5"

# %%
par(mfrow=c(2,3))
for (i in 1:5){
  boxplot(matrix(USArrests_s[hc3_result==i,-5],,4),las=2,main=paste("Group",i),
          ylim=c(-3,3))
}
# Out:
# Plot with title "Group 5"

# %% [markdown]
#  - 데이터를 보는 방법 2

# %%
library(psych)

# %%
describe(USArrests_s[,-5])
# Out:
#          vars  n mean sd median trimmed  mad   min  max range  skew kurtosis
# Murder      1 50    0  1  -0.12   -0.06 1.24 -1.60 2.21  3.81  0.37    -0.95
# Assault     2 50    0  1  -0.14   -0.03 1.33 -1.51 1.99  3.50  0.22    -1.15
# UrbanPop    3 50    0  1   0.03    0.02 1.23 -2.32 1.76  4.08 -0.21    -0.87
# Rape        4 50    0  1  -0.12   -0.09 0.92 -1.49 2.64  4.13  0.75     0.08
#            se
# Murder   0.14
# Assault  0.14
# UrbanPop 0.14
# Rape     0.14

# %%
describeBy(USArrests, group=hc3_result)
# Out:
# group: 1
#          vars n   mean    sd median trimmed   mad   min   max range  skew
# Murder      1 7  14.67  1.69   14.4   14.67  1.78  13.0  17.4   4.4  0.37
# Assault     2 7 251.29 48.38  249.0  251.29 44.48 188.0 337.0 149.0  0.42
# UrbanPop    3 7  54.29  8.54   58.0   54.29 11.86  44.0  66.0  22.0 -0.04
# Rape        4 7  21.69  4.03   22.2   21.69  5.34  16.1  26.9  10.8 -0.13
#          kurtosis    se
# Murder      -1.66  0.64
# Assault     -1.09 18.28
# UrbanPop    -1.90  3.23
# Rape        -1.68  1.52
# ------------------------------------------------------------
# group: 2
#          vars n  mean sd median trimmed mad   min   max range skew kurtosis se
# Murder      1 1  10.0 NA   10.0    10.0   0  10.0  10.0     0   NA       NA NA
# Assault     2 1 263.0 NA  263.0   263.0   0 263.0 263.0     0   NA       NA NA
# UrbanPop    3 1  48.0 NA   48.0    48.0   0  48.0  48.0     0   NA       NA NA
# Rape        4 1  44.5 NA   44.5    44.5   0  44.5  44.5     0   NA       NA NA
# ------------------------------------------------------------
# group: 3
#          vars  n   mean    sd median trimmed   mad   min   max range  skew
# Murder      1 12  10.88  2.16  11.20   10.73  1.85   7.9  15.4   7.5  0.34
# Assault     2 12 256.92 45.46 254.50  257.00 51.89 178.0 335.0 157.0 -0.16
# UrbanPop    3 12  78.33  7.02  80.00   78.20  6.67  67.0  91.0  24.0 -0.02
# Rape        4 12  32.25  6.73  31.45   31.70  6.67  24.0  46.0  22.0  0.61
#          kurtosis    se
# Murder      -0.72  0.62
# Assault     -1.06 13.12
# UrbanPop    -1.07  2.03
# Rape        -0.92  1.94
# ------------------------------------------------------------
# group: 4
#          vars  n   mean    sd median trimmed   mad  min   max range skew
# Murder      1 23   5.53  2.09    5.9    5.45  2.22  2.6   9.7   7.1 0.19
# Assault     2 23 129.43 43.35  120.0  128.95 43.00 46.0 238.0 192.0 0.23
# UrbanPop    3 23  68.91 11.23   67.0   68.79 10.38 50.0  89.0  39.0 0.09
# Rape        4 23  17.79  4.80   16.5   17.61  4.45  8.3  29.3  21.0 0.30
#          kurtosis   se
# Murder      -1.12 0.44
# Assault      0.14 9.04
# UrbanPop    -1.00 2.34
# Rape         0.00 1.00
# ------------------------------------------------------------
# group: 5
#          vars n  mean    sd median trimmed   mad  min  max range  skew kurtosis
# Murder      1 7  2.70  1.58    2.2    2.70  0.15  0.8  5.7   4.9  0.75    -0.82
# Assault     2 7 65.14 17.58   57.0   65.14 17.79 45.0 86.0  41.0  0.11    -2.08
# UrbanPop    3 7 46.29  9.09   45.0   46.29  8.90 32.0 57.0  25.0 -0.20    -1.59
# Rape        4 7  9.89  1.99    9.5    9.89  2.52  7.3 12.8   5.5  0.06    -1.70
#            se
# Murder   0.60
# Assault  6.65
# UrbanPop 3.43
# Rape     0.75

# %% [markdown]
# ## Kmeans Function
#  - 비계층적군집분석

# %%
km=kmeans(USArrests_s[,-5],3)
km
# Out:
# K-means clustering with 3 clusters of sizes 8, 29, 13
#
# Cluster means:
#       Murder    Assault    UrbanPop        Rape
# 1  1.4118898  0.8743346 -0.81452109  0.01927104
# 2 -0.7010700 -0.7071522 -0.09924526 -0.57773737
# 3  0.6950701  1.0394414  0.72263703  1.27693964
#
# Clustering vector:
#        Alabama         Alaska        Arizona       Arkansas     California
#              1              3              3              1              3
#       Colorado    Connecticut       Delaware        Florida        Georgia
#              3              2              2              3              1
#         Hawaii          Idaho       Illinois        Indiana           Iowa
#              2              2              3              2              2
#         Kansas       Kentucky      Louisiana          Maine       Maryland
#              2              2              1              2              3
#  Massachusetts       Michigan      Minnesota    Mississippi       Missouri
#              2              3              2              1              3
#        Montana       Nebraska         Nevada  New Hampshire     New Jersey
#              2              2              3              2              2
#     New Mexico       New York North Carolina   North Dakota           Ohio
#              3              3              1              2              2
#       Oklahoma         Oregon   Pennsylvania   Rhode Island South Carolina
#              2              2              2              2              1
#   South Dakota      Tennessee          Texas           Utah        Vermont
#              2              1              3              2              2
#       Virginia     Washington  West Virginia      Wisconsin        Wyoming
#              2              2              2              2              2
#
# Within cluster sum of squares by cluster:
# [1]  8.316061 53.354791 19.922437
#  (between_SS / total_SS =  58.4 %)
#
# Available components:
#
# [1] "cluster"      "centers"      "totss"        "withinss"     "tot.withinss"
# [6] "betweenss"    "size"         "iter"         "ifault"

# %%
head(km$cluster)
# Out:
#    Alabama     Alaska    Arizona   Arkansas California   Colorado
#          1          3          3          1          3          3

# %%
head(km$centers)
# Out:
#       Murder    Assault    UrbanPop        Rape
# 1  1.4118898  0.8743346 -0.81452109  0.01927104
# 2 -0.7010700 -0.7071522 -0.09924526 -0.57773737
# 3  0.6950701  1.0394414  0.72263703  1.27693964

# %% [markdown]
#  - 각 클러스터의 중심에서 각 클러스터의 해당 값의 거리 제곱의 합

# %%
km$withinss
# Out:
# [1]  8.316061 53.354791 19.922437

# %% [markdown]
#  - 전체 데이터의 중심에서 각 클러스터의 중심으로 거리
#  - withinss < betweenssr가 되어야 된다.

# %%
km$betweenss
# Out:
# [1] 114.4067

# %%
USArrests_s <- as.data.frame(USArrests_s)

# %%
options(repr.plot.width=6,repr.plot.height=5)
plot(Murder ~ Rape, data = USArrests_s, type="n")
text(USArrests_s$Rape, USArrests_s$Murder, rownames(USArrests),col=km$cluster, cex=0.8)
points(km$centers[,c(1,4)],col=1:3,pch=4, cex=2)
# Out:
# plot without title

# %%
wss = c()
for(i in 2:20){
   km=kmeans(USArrests_s[,-5],i)
   wss[i] = sum(km$withinss)
}

# %%
options(repr.plot.width=5,repr.plot.height=5)
plot(wss,type="l")
points(wss)
# Out:
# plot without title

# %% [markdown]
# # Pracice 4

# %%
jet <- read.csv("jet.csv")
head(jet)
# Out:
#       X FFD   SPR  RGF   PLF SLF CAR
# 1  FH-1  82 1.468 3.30 0.166 0.1  no
# 2  FJ-1  89 1.605 3.64 0.154 0.1  no
# 3 F-86A 101 2.168 4.87 0.177 2.9 yes
# 4 F9F-2 107 2.054 4.72 0.275 1.1  no
# 5 F-94A 115 2.467 4.11 0.298 1.0 yes
# 6 F3D-1 122 1.294 3.75 0.150 0.9  no

# %% [markdown]
#  - 계층적군집분석

# %%
jet2 <- jet
rownames(jet2) <- jet[,1]

# %%
jet2 <- jet2[,-c(1,2,7)]
jet2_s <- as.data.frame(scale(jet2))

# %%
hc = hclust(dist(jet2_s),method = "complete")
plot(hc)
# Out:
# Plot with title "Cluster Dendrogram"

# %% [markdown]
#  - barplot 에서 standard error bar 를 그리기

# %%
jet2_s$cluster <- cutree(hc,2)

# %%
# long type? 비교 값들이 세로로 쭉 있는것.
head(jet2_s)
# Out:
#              SPR        RGF         PLF        SLF cluster
# FH-1  -1.0461420 -1.6962704 -0.02622718 -2.1583057       1
# FJ-1  -0.9882683 -1.2447365 -0.16470671 -2.1583057       1
# F-86A -0.7504372  0.3887538  0.10071238  0.6324506       1
# F9F-2 -0.7985949  0.1895477  1.23162849 -1.1616070       1
# F-94A -0.6241291 -0.6205573  1.49704758 -1.2612769       1
# F3D-1 -1.1196457 -1.0986520 -0.21086655 -1.3609467       1

# %%
library(ggplot2)
library(psych)
# Out:
# Attaching package: 'ggplot2'
#
# The following objects are masked from 'package:psych':
#
#     %+%, alpha

# %%
describeBy(jet2_s,group=jet2_s$cluster)
# Out:
# group: 1
#         vars  n  mean   sd median trimmed  mad   min   max range  skew kurtosis
# SPR        1 12 -0.78 0.35  -0.75   -0.77 0.31 -1.47 -0.14  1.34 -0.18    -0.50
# RGF        2 12 -0.47 0.71  -0.48   -0.45 0.89 -1.70  0.55  2.24 -0.11    -1.44
# PLF        3 12 -0.19 1.00  -0.16   -0.18 0.39 -1.94  1.50  3.44 -0.19    -0.59
# SLF        4 12 -0.51 1.07  -0.21   -0.47 1.33 -2.16  0.73  2.89 -0.31    -1.60
# cluster    5 12  1.00 0.00   1.00    1.00 0.00  1.00  1.00  0.00   NaN      NaN
#           se
# SPR     0.10
# RGF     0.21
# PLF     0.29
# SLF     0.31
# cluster 0.00
# ------------------------------------------------------------
# group: 2
#         vars  n mean   sd median trimmed  mad   min  max range  skew kurtosis
# SPR        1 10 0.93 0.64   0.95    0.93 0.79 -0.03 1.94  1.97  0.06    -1.37
# RGF        2 10 0.57 1.03   0.64    0.53 1.07 -1.01 2.49  3.49  0.21    -1.02
# PLF        3 10 0.23 1.00   0.13    0.12 1.21 -0.91 2.28  3.20  0.59    -0.79
# SLF        4 10 0.61 0.41   0.63    0.64 0.37 -0.26 1.23  1.50 -0.61    -0.36
# cluster    5 10 2.00 0.00   2.00    2.00 0.00  2.00 2.00  0.00   NaN      NaN
#           se
# SPR     0.20
# RGF     0.32
# PLF     0.32
# SLF     0.13
# cluster 0.00

# %% [markdown]
#  - sd : 표준편차
#  - se : $sd \over \sqrt{n}$

# %%
tab <- describeBy(jet2_s[,1],group=jet2_s$cluster,mat=T)
tab
# Out:
#     item group1 vars  n       mean        sd     median    trimmed       mad
# X11    1      1    1 12 -0.7776491 0.3477135 -0.7472690 -0.7719814 0.3137776
# X12    2      2    1 10  0.9331789 0.6416093  0.9532446  0.9267896 0.7882019
#             min        max    range        skew   kurtosis        se
# X11 -1.47406901 -0.1379059 1.336163 -0.18044085 -0.4962068 0.1003762
# X12 -0.02722788  1.9447004 1.971928  0.06475812 -1.3692748 0.2028947

# %%
gg <- ggplot(tab,aes(x=group1,y=mean))

# %%
gg + geom_bar(position = position_dodge(), stat="identity") + geom_errorbar(aes(ymin=mean-2*se, ymax=mean+2*se, width=0.1))
# Out:
# plot without title

# %% [markdown]
#  - 비계층적군집분석
#   - 군집 개수 1~5까지를 사용해 k-means clustering을 시행하고 얻은 within-group sum of squares를 저장하고 그래프로 표현하여 적절한 군집 개수를 판단하시오.
#   - K-means clustering을 이용해 2개의 집단으로 군집화하고 그 결과를 1번의 B, C와 같이 탐색하시오.

# %%
result <- c()
for(i in 1:5){
    km <- kmeans(jet[,-c(1,7)],i)
    result[i] <- sum(km$withinss)
}

# %%
options(repr.plot.width=5,repr.plot.height=5)
plot(result,type="l")
points(result)
# Out:
# plot without title

# %%
library(mclust)

# %% [markdown]
#  - 표준화를 할 것인지 안할 것인지를 정해야 한다.
#  - 표준화를 하지 않고 각 디멘젼의 분산을 구하게 된다면 오차가 생길 확률이 있지만 현재는 문제가 없을 것이라고 얘기함.

# %%
head(USArrests)
# Out:
#            Murder Assault UrbanPop Rape
# Alabama      13.2     236       58 21.2
# Alaska       10.0     263       48 44.5
# Arizona       8.1     294       80 31.0
# Arkansas      8.8     190       50 19.5
# California    9.0     276       91 40.6
# Colorado      7.9     204       78 38.7

# %%
mc = Mclust(USArrests)
mc
# Out:
# 'Mclust' model object:
#  best model: diagonal, equal shape (VEI) with 3 components

# %%
summary(mc)
# Out:
# ----------------------------------------------------
# Gaussian finite mixture model fitted by EM algorithm
# ----------------------------------------------------
#
# Mclust VEI (diagonal, equal shape) model with 3 components:
#
#  log.likelihood  n df       BIC       ICL
#       -757.5611 50 20 -1593.363 -1597.743
#
# Clustering table:
#  1  2  3
# 20 20 10

# %% [markdown]
#  - 각 모델의 BIC를 측정.
#  - X 축 : 그룹의 수
#  - Y 축 : BIC

# %%
plot(mc)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %% [markdown]
#  - 함수 내에 Cluster수를 지정해줄 수 있다.
#  - plot을 그린다면 지정된 수의 plot만 그려진다.

# %%
mc = Mclust(USArrests,4)

# %%
plot(mc)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %%
mc$classification
# Out:
#        Alabama         Alaska        Arizona       Arkansas     California
#              1              2              2              3              2
#       Colorado    Connecticut       Delaware        Florida        Georgia
#              2              4              3              1              1
#         Hawaii          Idaho       Illinois        Indiana           Iowa
#              3              4              1              3              4
#         Kansas       Kentucky      Louisiana          Maine       Maryland
#              3              3              1              4              1
#  Massachusetts       Michigan      Minnesota    Mississippi       Missouri
#              3              2              4              1              3
#        Montana       Nebraska         Nevada  New Hampshire     New Jersey
#              3              3              2              4              3
#     New Mexico       New York North Carolina   North Dakota           Ohio
#              2              1              1              4              3
#       Oklahoma         Oregon   Pennsylvania   Rhode Island South Carolina
#              3              3              3              3              1
#   South Dakota      Tennessee          Texas           Utah        Vermont
#              4              1              1              3              4
#       Virginia     Washington  West Virginia      Wisconsin        Wyoming
#              3              3              4              4              3

# %%
options(repr.plot.width=8,repr.plot.height=6)
par(mfrow=c(2,2))
for(i in 1:4){
    boxplot(USArrests[,i]~mc$classification, main=names(USArrests)[i])
}
# Out:
# Plot with title "Rape"

# %%
USArrests_s = as.data.frame(scale(USArrests))

# %%
options(repr.plot.width=8,repr.plot.height=8)
par(mfrow=c(3,1))
for(i in 1:3){
    boxplot(USArrests_s[mc$classification==i,],ylim=c(-3,3))
}
# Out:
# plot without title

# %%
library(psych)

# %%
result = describeBy(USArrests[,1],group=mc$classification,mat=T)

# %%
result
# Out:
#     item group1 vars  n      mean       sd median   trimmed     mad  min  max
# X11    1      1    1 12 13.633333 2.154629  13.20 13.580000 2.96520 10.4 17.4
# X12    2      2    1  7 10.100000 1.833030  10.00 10.100000 2.81694  7.9 12.2
# X13    3      3    1 20  6.250000 1.884424   6.15  6.231250 1.85325  3.2  9.7
# X14    4      4    1 11  2.736364 1.241187   2.60  2.622222 0.74130  0.8  5.7
#     range        skew   kurtosis        se
# X11   7.0  0.13273824 -1.3015688 0.6219877
# X12   4.3 -0.01210775 -1.9978893 0.6928203
# X13   6.5  0.10107316 -1.1001959 0.4213699
# X14   4.9  0.91868644  0.5653512 0.3742320

# %%
options(repr.plot.width=5,repr.plot.height=5)

# %%
library(ggplot2)

# %%
gg <- ggplot(result, aes(x=group1,y=mean,fill=group1))

# %%
gg + geom_bar(position = position_dodge(), stat="identity") + geom_errorbar(aes(ymin=mean-2*se,ymax=mean +2*se, width=0.1))
# Out:
# plot without title

# %% [markdown]
#  - 비교하고 싶은 대상을 어떠한 기준으로 비교 할것인가
#  - Degree of Freedom : 비교하고 싶은 대상 ( 그룹 ) - 1 개가 나와야 한다.
#  - 4집단의 평균이 같다 라는 것이 $H_0$ 귀무 가설
#  - 4개 중 하나라도 평균이 다르다 라는 것이 $H_1$이 대립가설

# %%
model = aov(USArrests$Murder~factor(mc$classification))
summary(model)
# Out:
#                           Df Sum Sq Mean Sq F value Pr(>F)
# factor(mc$classification)  3  775.5  258.48   77.16 <2e-16 ***
# Residuals                 46  154.1    3.35
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %% [markdown]
#  - 귀무 가설이 기각이 된다면 어떤 집단 평균이 다른가?
#   - 사후 검정(Tukey Test)

# %% [markdown]
#  - TukeyHSD 를 통해 비교 결과를 추출
#   - P-value와 앞의 비교 대상 List Check

# %%
TukeyHSD(model)
# Out:
#   Tukey multiple comparisons of means
#     95% family-wise confidence level
#
# Fit: aov(formula = USArrests$Murder ~ factor(mc$classification))
#
# $`factor(mc$classification)`
#           diff        lwr       upr     p adj
# 2-1  -3.533333  -5.853615 -1.213052 0.0010537
# 3-1  -7.383333  -9.164780 -5.601887 0.0000000
# 4-1 -10.896970 -12.933451 -8.860488 0.0000000
# 3-2  -3.850000  -5.992502 -1.707498 0.0001019
# 4-2  -7.363636  -9.722454 -5.004819 0.0000000
# 4-3  -3.513636  -5.344993 -1.682280 0.0000347

# %% [markdown]
# ## Practice 5
#  - 모형기반 군집화를 통해 비행기를 군집화 해봐라

# %%
jet <- read.csv("jet.csv", stringsAsFactors = T)

# %%
str(jet)
# Out:
# 'data.frame':	22 obs. of  7 variables:
#  $ X  : Factor w/ 22 levels "F-100A","F-101A",..: 19 20 9 17 12 14 10 21 18 1 ...
#  $ FFD: int  82 89 101 107 115 122 127 137 147 166 ...
#  $ SPR: num  1.47 1.6 2.17 2.05 2.47 ...
#  $ RGF: num  3.3 3.64 4.87 4.72 4.11 3.75 3.97 4.65 3.84 4.92 ...
#  $ PLF: num  0.166 0.154 0.177 0.275 0.298 0.15 0 0.117 0.155 0.138 ...
#  $ SLF: num  0.1 0.1 2.9 1.1 1 0.9 2.4 1.8 2.3 3.2 ...
#  $ CAR: Factor w/ 2 levels "no","yes": 1 1 2 1 2 1 2 1 1 2 ...

# %%
mc_jet = Mclust(jet[,2:5])
mc_jet
# Out:
# 'Mclust' model object:
#  best model: ellipsoidal multivariate normal (XXX) with 1 components

# %%
plot(mc_jet)
# Out:
# Plot with title ""
# Warning message:
# In min(r, na.rm = TRUE): min에 전달되는 인자들 중 누락이 있어 Inf를 반환합니다Warning message:
# In max(r, na.rm = TRUE): max에 전달되는 인자들 중 누락이 있어 -Inf를 반환합니다Warning message:
# In min(r, na.rm = TRUE): min에 전달되는 인자들 중 누락이 있어 Inf를 반환합니다
# Error in rgb(x[1L, ], x[2L, ], x[3L, ], x[4L, ]): 알파레벨이 [0,1] 내에 있어야 하는데 nan를 가집니다.
# Traceback:
#
# 1. plot(mc_jet)
# 2. plot.Mclust(mc_jet)
# 3. plot.Mclust.uncertainty(...)
# 4. coordProj(data = data, what = "uncertainty", parameters = object$parameters,
#  .     z = object$z, dimens = dimens[c(j, i)], main = FALSE, addEllipses = addEllipses,
#  .     xaxt = "n", yaxt = "n", ...)
# 5. plot(data[, 1], data[, 2], pch = 19, main = "", xlab = xlab,
#  .     ylab = ylab, xlim = xlim, ylim = ylim, cex = b$cex, col = mapply(adjustcolor,
#  .         col = colors[cl], alpha.f = b$alpha), ...)
# 6. plot.default(data[, 1], data[, 2], pch = 19, main = "", xlab = xlab,
#  .     ylab = ylab, xlim = xlim, ylim = ylim, cex = b$cex, col = mapply(adjustcolor,
#  .         col = colors[cl], alpha.f = b$alpha), ...)
# 7. plot.xy(xy, type, ...)
# 8. mapply(adjustcolor, col = colors[cl], alpha.f = b$alpha)
# 9. (function (col, alpha.f = 1, red.f = 1, green.f = 1, blue.f = 1,
#  .     offset = c(0, 0, 0, 0), transform = diag(c(red.f, green.f,
#  .         blue.f, alpha.f)))
#  . {
#  .     stopifnot(length(offset)%%4L == 0L, !is.null(d <- dim(transform)),
#  .         d == c(4L, 4L))
#  .     x <- col2rgb(col, alpha = TRUE)/255
#  .     x[] <- pmax(0, pmin(1, transform %*% x + matrix(offset, nrow = 4L,
#  .         ncol = ncol(x))))
#  .     rgb(x[1L, ], x[2L, ], x[3L, ], x[4L, ])
#  . })(col = dots[[1L]][[1L]], alpha.f = dots[[2L]][[1L]])
# 10. rgb(x[1L, ], x[2L, ], x[3L, ], x[4L, ])
# Plot with title ""
# plot without title

# %%
summary(mc_jet)
# Out:
# ----------------------------------------------------
# Gaussian finite mixture model fitted by EM algorithm
# ----------------------------------------------------
#
# Mclust XXX (ellipsoidal multivariate normal) model with 1 component:
#
#  log.likelihood  n df       BIC       ICL
#       -152.7171 22 14 -348.7089 -348.7089
#
# Clustering table:
#  1
# 22

# %%
mc_jet2 = Mclust(jet[,2:5],2)
mc_jet2
# Out:
# 'Mclust' model object:
#  best model: diagonal, equal volume and shape (EEI) with 2 components

# %%
summary(mc_jet2)
# Out:
# ----------------------------------------------------
# Gaussian finite mixture model fitted by EM algorithm
# ----------------------------------------------------
#
# Mclust EEI (diagonal, equal volume and shape) model with 2 components:
#
#  log.likelihood  n df       BIC       ICL
#       -156.4029 22 13 -352.9894 -353.9347
#
# Clustering table:
#  1  2
# 15  7

# %%
plot(mc_jet2)
# Out:
# Plot with title ""
# Plot with title ""
# Plot with title ""
# Plot with title ""

# %%
mc_jet3 = Mclust(jet[,2:5],3)
mc_jet3
# Out:
# 'Mclust' model object:
#  best model: diagonal, equal volume, varying shape (EVI) with 3 components

# %%
summary(mc_jet3)
# Out:
# ----------------------------------------------------
# Gaussian finite mixture model fitted by EM algorithm
# ----------------------------------------------------
#
# Mclust EVI (diagonal, equal volume, varying shape) model with 3 components:
#
#  log.likelihood  n df       BIC       ICL
#       -139.3663 22 24 -352.9176 -352.9397
#
# Clustering table:
#  1  2  3
#  9 11  2

# %%
plot(mc_jet3)
# Out:
# Plot with title ""
# Plot with title ""

# %%
mc_jet = Mclust(jet,4,modelNames = "VEI")
mc_jet
# Out:
# 'Mclust' model object:
#  best model: diagonal, equal shape (VEI) with 4 components

# %%
mc_jet$classification
# Out:
#  [1] 1 1 2 2 2 2 2 2 2 3 3 3 3 3 3 3 3 3 3 3 4 4

# %%
head(jet)
# Out:
#       X FFD   SPR  RGF   PLF SLF CAR
# 1  FH-1  82 1.468 3.30 0.166 0.1  no
# 2  FJ-1  89 1.605 3.64 0.154 0.1  no
# 3 F-86A 101 2.168 4.87 0.177 2.9 yes
# 4 F9F-2 107 2.054 4.72 0.275 1.1  no
# 5 F-94A 115 2.467 4.11 0.298 1.0 yes
# 6 F3D-1 122 1.294 3.75 0.150 0.9  no

# %%
par(mfrow=c(1,4))
for(i in 1:4){
    boxplot(jet[mc_jet$classification==i,])
}
# Out:
# plot without title
