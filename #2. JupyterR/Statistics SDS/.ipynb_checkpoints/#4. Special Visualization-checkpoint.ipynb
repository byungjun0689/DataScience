# %% [markdown]
# # Special Visualization
#  - 특별한 시각화

# %% [markdown]
# ## GoogleVis

# %%
install.packages("googleVis", repos="http://cran.us.r-project.org")
# Out:
# Installing package into 'C:/Users/byung/Documents/R/win-library/3.3'
# (as 'lib' is unspecified)
# package 'googleVis' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\byung\AppData\Local\Temp\Rtmp6JztBw\downloaded_packages

# %%
library(googleVis)

# %%
data(Fruits)

# %%
Fruits <- Fruits

# %%
str(Fruits)
# Out:
# 'data.frame':	9 obs. of  7 variables:
#  $ Fruit   : Factor w/ 3 levels "Apples","Bananas",..: 1 1 1 3 2 3 2 3 2
#  $ Year    : num  2008 2009 2010 2008 2008 ...
#  $ Location: Factor w/ 2 levels "East","West": 2 2 2 1 1 1 1 1 1
#  $ Sales   : num  98 111 89 96 85 93 94 98 81
#  $ Expenses: num  78 79 76 81 76 80 78 91 71
#  $ Profit  : num  20 32 13 15 9 13 16 7 10
#  $ Date    : Date, format: "2008-12-31" "2009-12-31" ...

# %%
M1 <- gvisMotionChart(Fruits, idvar="Fruit", timevar="Year")
plot(M1)  # R-studio 에서 하면 웹에서 가동이된다.

# %%
library("IRdisplay")
display_png(file="2.png")

# %%
data(Exports)

# %%
G1 <- gvisGeoChart(Exports,locationvar = 'Country', colorvar = 'Profit')

# %%
plot(G1)

# %%
display_png(file="1.png")

# %% [markdown]
# ### 특정 지역 그래프 그리기

# %%
G2<-gvisGeoChart(Exports,locationvar ='Country',colorvar='Profit',options=list(region="150"))
plot(G2)

# %%
display_png(file="3.png")

# %% [markdown]
# ## 파이차트 그리기
#  - 최근 30일 동안발생한 지진 데이터

# %%
eq<-read.csv("http://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_month.csv")
eq$loc = paste(eq$latitude,eq$longitude,sep=":")
G9<-gvisGeoChart(eq,"loc","depth","mag",options=list(displayMode="Markers",colorAxis="{colors:['purple','red','orange','grey']}"
                                                           ,backgroundColor="lightblue"),chartid="EQ")
plot(G9)

# %%
display_png(file="4.png")
