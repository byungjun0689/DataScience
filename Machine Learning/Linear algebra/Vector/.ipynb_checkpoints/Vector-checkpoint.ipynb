# %%
library("IRdisplay")
display_png(file="Chapter 1.PNG")
display_png(file="Chapter 2_1.PNG")
display_png(file="Chapter 2_2.PNG")
display_png(file="Chapter 3.PNG")
display_png(file="Chapter 4.PNG")
display_png(file="Chapter 5_1.PNG")
display_png(file="Chapter 5_2.PNG")
display_png(file="Chapter 5_3.PNG")
display_png(file="Chapter 5_4.PNG")
