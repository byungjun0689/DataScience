# %% [markdown]
# # Supervised Learning

# %%
from IPython.display import Image
Image(filename="1.PNG", width = 700)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-0ce9142f5f52> in <module>()
#       1 from IPython.display import Image
# ----> 2 Image(filename="1.PNG", width = 700)
#
# C:\Anaconda3\envs\work\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#     755         self.unconfined = unconfined
#     756         self.metadata = metadata
# --> 757         super(Image, self).__init__(data=data, url=url, filename=filename)
#     758
#     759         if retina:
#
# C:\Anaconda3\envs\work\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename)
#     392         self.filename = None if filename is None else unicode_type(filename)
#     393
# --> 394         self.reload()
#     395         self._check_data()
#     396
#
# ...
