# %% [markdown]
# # 실습

# %%
from IPython.display import Image

# %% [markdown]
# ### ETC 소리.
#  - 데이터 전처리 소요시간 70~90% 정도가 소요된다.
#  - 견(見) 관(觀) 진(診)

# %% [markdown]
# ## qGIS 실습
#  - 1. 원하는 곳 어디든 QGIS 폴더 생성
#  - 2. rather, test, vector 폴더 생성 (한글 폴더 사용을 하지 않기 위해)
#  - 3. 실습 데이터 전체를 Vector폴더에 넣는다. ( 지도를 그리기 위한 재료라고 생각하면 된다. )
#   - 데이터 분석하면서 가장 많이 사용할 메뉴는 벡터와 레스터이다.
#  - 4. 레스터에 온도지도가 필요하다( 설치 필요 )
#   - 옆 플러그인으로 설치 영어로 TMS for Korea ( 구글/다음/네이버 지도를 바로 사용하게 하는 )
#   - 온도 지도 검색 -> 활성화 -> 다시 레스터 메뉴 클릭 (생성되어있음)

# %%
Image(filename="img/1.PNG", width=300)

# %% [markdown]
#  - 벡터에 필요 요소.

# %%
Image(filename="img/2.PNG", width=300)

# %% [markdown]
# ### 1. 지도 그리기
#   - Vector 레이어에 넣기 클릭( 왼쪽 작은 메뉴 중 첫번째 )

# %%
Image(filename="img/3.PNG", width = 300)

# %%
Image(filename="img/4.PNG", width = 700)

# %% [markdown]
#  - 지도를 불러오고 Label을 불러오기 위해서 속성을 확인해야한다. 속성테이블 Open(그림을 표현하는 패널에서 오른쪽 마우스 (속성테이블 클릭))
# 	1. sgg_nm을 선택해야한다.
# 	2. 레이블 더블클릭( 라벨) 또는 속성을 열거나.
# 	3. 창에서 라벨.
#     4. show-label 이후 확인.

# %%
Image(filename="img/5.PNG", width=600)

# %% [markdown]
#  - 왼쪽 Layers Panel 리스트에서 위로 올수록 위로 보인다. 데이터를 불러 순서에 맞게 출력시킨다.
#  - 구 + 동 데이터를 합치려고 한다. 동 정보에서 구별로 테두리를 칠 수 있는 방법
#         1. no-labels (안달겠다)
#         2. show-label(두번째꺼 클릭)
#         3. Label with 컬럼명 하면 해당부분에 컬럼이 나온다.
#         4. 버퍼를 클릭 -> 텍스트버퍼그리기 -> 색상 파레트가 나온다. (텍스트에 하얀색 테두리가 보인다)
#          - 뭐 이건 패스 확인해보는걸로.
#         5. 벡터 레이어 추가하기 ( 구를 다뤘으니 ) 동을 다룬다.
#         6. 동시에 2개 레이어를 넣는다. (동데이터 + sensours 2015어쩌구저쩌구)
#         7. 옆에 레이어의 순서대로 위부터 아래로 내려간다.
#         8. 구를 위로 올리고 불투명을 투명으로 바꾸고 경계선을 진하게 하면 표현이 더 좋다.
#         9. 구 라벨에서 속성으로 들어와서 스타일으로 들어간다.
#         10. 단순체우기를 클릭. 안채움으로 바꾼다. 버더 두깨를 두껍게 바꾼다.

# %%
Image(filename="img/6.PNG", width=600)

# %% [markdown]
#  - 스타벅스 2006 / 15 데이터 넣고 라벨 추가 해보기.
# #### 2006 스타벅스 위치

# %%
Image(filename="img/7.PNG", width=700)

# %% [markdown]
# #### 2015 스타벅스 위치

# %%
Image(filename="img/8.PNG", width=700)

# %% [markdown]
# #### 2015 스타벅스 위치 + 은행 위치

# %%
Image(filename="img/9.PNG", width=700)

# %% [markdown]
# ### 온도지도 그리기
#
# 	1. 2005년 스타벅스 데이터만 남기고 나머지 없앤다.(구/동은 그대로 두고)
#     2. 온도지도 클릭. -> 플러그인이라는 창이 뜬다. 뭘로 그릴지 선택한다. 2006년 스타벅스 데이터 클릭.
# 	3. 지도의 이름을 정해서 저장한다. ... 클릭 raster 폴더 안에 파일을 만든다. heat_2006
# 	4. 반지름 1500으로 1500m
# 	5. 고급 클릭 => 셀로 10으로 입력.(X에 입력하면 자동으로 Y로 바뀐다) 확인클릭.
# 	6. 레이어에 heat_2006이 생긴다. 속성으로 간다. 스타일로 간다 => 단일밴드 가상색채 => 색상표에서 선택하면 되지만 젤 아래있는 오랜지 선택. (아래에서 두번째)
# 	7. 모드 등간격으로 변경. => 클래스5가 되어있고 분류를 클릭. 5개 등급으로 오랜지 톤이 들어갔다.

# %%
Image(filename="img/10.PNG", width=700)
