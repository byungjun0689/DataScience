# %% [markdown]
# # 토픽분석
#
# ### gensim 설치

# %% [markdown]
# ## Topic model
#  - 텍스트의 주제(Topic)을 분석하기 위한 모형
#  -  Latent Dirichlet Allocation

# %% [markdown]
# ### LDA 어렵게보기
# ![img1](img/1.PNG)

# %% [markdown]
# ### LDA 쉽게 보기
#  - Bag of Words
# ![img2](img/2.PNG)
# ![img2](img/3.PNG)

# %% [markdown]
#  - Word Counts
#   - 예) 은행 : 먹는 은행, 시중 은행 2개의 경우가 있다.
#   - Bag of words의 경우 은행을 파악할 수 없다.
#   - But 주제 별로 보게 된다면 은행은 시중 은행이라는 것을 알 수 있다.
#
# ![img4](img/4.PNG)

# %% [markdown]
# ## LDA 확장
#  - Correlated topic models
#  - Dynamic topic models & measuring scholarly impact
#  - Supervised topic models
#  - Relational topic models
#  - Ideal point topic models
#  - Collaborative topic models

# %%
#!conda install -y gensim

# %% [markdown]
# ## 데이터 불러오기

# %%
import numpy as np

# %%
tdm = np.load('tdm_small.npy')

# %%
tdm # 5347개의 기사 중에 1000개 단어를 뽑아서 TDM형태로 만들었다.
# Out:
# <5347x1000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 652672 stored elements in Compressed Sparse Column format>

# %%
tdm = tdm.tolist()

# %%
with open('words_small.txt', encoding='utf8') as f:
    words = f.read().splitlines()

# %%
words[:10]
# Out:
# ['출시', '제품', '제공', '시장', '사용', '서비스', '게임', '기능', '판매', '국내']

# %% [markdown]
# ### gensim 포맷으로 바꾸기

# %%
from gensim.matutils import Sparse2Corpus
# Out:
# C:\Anaconda3\envs\py35\lib\site-packages\gensim\utils.py:855: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
corpus = Sparse2Corpus(tdm.T) # dtm형태로 변환.

# %%
corpus

# %% [markdown]
# ## Latent Dirichelt Allocation
# <a href="https://radimrehurek.com/gensim/models/ldamodel.html"> LdaModel 문서 </a>

# %%
from gensim.models.ldamodel import LdaModel

# %% [markdown]
#  - enumerate : 리스트를 넣어주게 되면 앞에 숫자를 붙여준다.

# %%
dict(enumerate(['a','b','c']))
# Out:
# {0: 'a', 1: 'b', 2: 'c'}

# %%
dict(enumerate(words))
# Out:
# {0: '출시',
#  1: '제품',
#  2: '제공',
#  3: '시장',
#  4: '사용',
#  5: '서비스',
#  6: '게임',
#  7: '기능',
#  8: '판매',
#  9: '국내',
#  10: '고객',
#  11: '모델',
#  12: '상품',
#  13: '가격',
#  14: '기자',
#  15: '이번',
#  16: '적용',
#  17: '브랜드',
#  18: '기존',
#  19: '디자인',
#  20: '개발',
#  21: '진행',
#  22: '스마트폰',
#  23: '모바일',
#  24: '소비자',
#  25: '이상',
#  26: '기술',
#  27: '피부',
#  28: '지원',
#  29: '이용',
#  30: '예정',
#  31: '최대',
#  32: '이벤트',
#  33: '인기',
#  34: '시스템',
#  35: '관계자',
#  36: '가지',
#  37: '구성',
#  38: '경우',
#  39: '올해',
#  40: '대표',
#  41: '최근',
#  42: '중국',
#  43: '한국',
#  44: '추가',
#  45: '특징',
#  46: '기업',
#  47: '지난해',
#  48: '성능',
#  49: '신제품',
#  50: '삼성전자',
#  51: '때문',
#  52: '업계',
#  53: '활용',
#  54: '시리즈',
#  55: '구매',
#  56: '효과',
#  57: '탑재',
#  58: '업체',
#  59: '한편',
#  60: '계획',
#  61: '공개',
#  62: '세계',
#  63: '프리미엄',
#  64: '시작',
#  65: '시간',
#  66: '강화',
#  67: '애플',
#  68: '카드',
#  69: '최고',
#  70: '미국',
#  71: '글로벌',
#  72: '관련',
#  73: '사진',
#  74: '최초',
#  75: '할인',
#  76: '아이폰',
#  77: '확인',
#  78: '선택',
#  79: '사업',
#  80: '컬러',
#  81: '확대',
#  82: '가입',
#  83: '투자',
#  84: '아이',
#  85: '기사',
#  86: '사용자',
#  87: '라인',
#  88: '대비',
#  89: '기대',
#  90: '전문',
#  91: '건강',
#  92: '필요',
#  93: '세트',
#  94: '이후',
#  95: '공식',
#  96: '방식',
#  97: '캐릭터',
#  98: '기념',
#  99: '성장',
#  100: '설명',
#  101: '대출',
#  102: '코리아',
#  103: '관리',
#  104: '매출',
#  105: '배포',
#  106: '정보',
#  107: '데이터',
#  108: '메뉴',
#  109: '매장',
#  110: '금융',
#  111: '금지',
#  112: '포함',
#  113: '개선',
#  114: '소재',
#  115: '스마트',
#  116: '무단',
#  117: '전략',
#  118: '차량',
#  119: '증가',
#  120: '전망',
#  121: '전재',
#  122: '패키지',
#  123: '대상',
#  124: '기준',
#  125: '기반',
#  126: '혜택',
#  127: 'LG전자',
#  128: '회사',
#  129: '요금',
#  130: '고급',
#  131: '수준',
#  132: '온라인',
#  133: '성분',
#  134: '동시',
#  135: '마케팅',
#  136: '기록',
#  137: '뉴스',
#  138: '안전',
#  139: '기간',
#  140: '관심',
#  141: '환경',
#  142: '하나',
#  143: '유지',
#  144: '행사',
#  145: '버전',
#  146: '전국',
#  147: '전용',
#  148: '지역',
#  149: '선물',
#  150: '여성',
#  151: '스타일',
#  152: '일반',
#  153: '지속',
#  154: '분기',
#  155: '자동차',
#  156: '콘텐츠',
#  157: '색상',
#  158: '예상',
#  159: '해외',
#  160: '솔루션',
#  161: '유저',
#  162: '제작',
#  163: '결제',
#  164: '생산',
#  165: '무료',
#  166: '신규',
#  167: '기본',
#  168: '준비',
#  169: '홈페이지',
#  170: '동안',
#  171: '활동',
#  172: '경쟁',
#  173: '기기',
#  174: '규모',
#  175: '상황',
#  176: '분석',
#  177: '전체',
#  178: '운영',
#  179: '아이템',
#  180: '정도',
#  181: '영상',
#  182: '이용자',
#  183: '카메라',
#  184: '안정',
#  185: '사람',
#  186: '장착',
#  187: '이미지',
#  188: '부분',
#  189: '갤럭시S',
#  190: '연결',
#  191: '처음',
#  192: '삼성',
#  193: '발표',
#  194: '충전',
#  195: '은행',
#  196: '크림',
#  197: '포인트',
#  198: '인치',
#  199: '자동',
#  200: '플랫폼',
#  201: '일본',
#  202: '실적',
#  203: '주행',
#  204: '공간',
#  205: '시즌',
#  206: '증정',
#  207: '향상',
#  208: '현대차',
#  209: '개월',
#  210: '엔진',
#  211: '블랙',
#  212: '서울',
#  213: '사랑',
#  214: '만큼',
#  215: '모드',
#  216: '금리',
#  217: '평가',
#  218: '속도',
#  219: '카카오',
#  220: '설계',
#  221: '형태',
#  222: '저작권',
#  223: '배터리',
#  224: '다음',
#  225: '함유',
#  226: '펀드',
#  227: '구입',
#  228: '편리',
#  229: '라면',
#  230: '편의',
#  231: '보험',
#  232: '효율',
#  233: '예약',
#  234: '부담',
#  235: '가운데',
#  236: '화면',
#  237: '보안',
#  238: '커피',
#  239: '세대',
#  240: '강조',
#  241: '구현',
#  242: '스포츠',
#  243: '수익',
#  244: '내용',
#  245: '플러스',
#  246: '품질',
#  247: '지급',
#  248: '산업',
#  249: '공급',
#  250: '내년',
#  251: '해당',
#  252: '참여',
#  253: '사전',
#  254: '인증',
#  255: '자연',
#  256: '비용',
#  257: '경험',
#  258: '성공',
#  259: '중심',
#  260: '차별',
#  261: '페이',
#  262: '신형',
#  263: '상태',
#  264: '주목',
#  265: '자신',
#  266: '도움',
#  267: '도어',
#  268: '확보',
#  269: '자체',
#  270: '업그레이드',
#  271: '출력',
#  272: '우수',
#  273: '최적',
#  274: '버거',
#  275: '단계',
#  276: '디스플레이',
#  277: '문제',
#  278: 'SK텔레콤',
#  279: '판매량',
#  280: '보호',
#  281: '발생',
#  282: '용량',
#  283: '플레이',
#  284: '영업',
#  285: '결과',
#  286: '달러',
#  287: '센터',
#  288: '티볼리',
#  289: '프로그램',
#  290: '혁신',
#  291: '부문',
#  292: '라인업',
#  293: '보장',
#  294: '통합',
#  295: '우리',
#  296: '모습',
#  297: '컬렉션',
#  298: '목표',
#  299: '아웃',
#  300: '생각',
#  301: '음료',
#  302: '마련',
#  303: '반응',
#  304: '스토리',
#  305: '완성',
#  306: '공유',
#  307: '소개',
#  308: '정식',
#  309: '경제',
#  310: '등록',
#  311: '광고',
#  312: '하이브리드',
#  313: '차지',
#  314: '장점',
#  315: '변화',
#  316: '한정',
#  317: '최신',
#  318: '페이스북',
#  319: '분야',
#  320: '반영',
#  321: '무선',
#  322: '자랑',
#  323: '연출',
#  324: '설치',
#  325: '촬영',
#  326: '밴드',
#  327: '위치',
#  328: '이동',
#  329: '자리',
#  330: '공략',
#  331: '엣지',
#  332: '크기',
#  333: '최소',
#  334: '금액',
#  335: '미니',
#  336: '실시간',
#  337: '클라우드',
#  338: '유럽',
#  339: '도입',
#  340: '느낌',
#  341: '화장품',
#  342: '체험',
#  343: '각종',
#  344: '생활',
#  345: '바탕',
#  346: '구조',
#  347: '등장',
#  348: '블루',
#  349: '주택',
#  350: '개인',
#  351: '집중',
#  352: '자사',
#  353: '네이버',
#  354: '카페',
#  355: '수입',
#  356: '골프',
#  357: '조사',
#  358: '진출',
#  359: '웨어',
#  360: '방지',
#  361: '여행',
#  362: '실시',
#  363: '선정',
#  364: '애플리케이션',
#  365: '전환',
#  366: '수분',
#  367: '수요',
#  368: '고려',
#  369: '별도',
#  370: '테스트',
#  371: '감소',
#  372: '골드',
#  373: '파워',
#  374: '표현',
#  375: '과정',
#  376: '유통',
#  377: '결합',
#  378: '안드로이드',
#  379: '대형',
#  380: '사양',
#  381: '터치',
#  382: '적극',
#  383: '그룹',
#  384: '연비',
#  385: '변경',
#  386: '누구',
#  387: '트렌드',
#  388: '계약',
#  389: '친환경',
#  390: '워치',
#  391: '인터넷',
#  392: '비교',
#  393: '가입자',
#  394: '향후',
#  395: '조절',
#  396: '의미',
#  397: '구축',
#  398: '남성',
#  399: '여름',
#  400: '확장',
#  401: '여기',
#  402: '재미',
#  403: '다운',
#  404: '채널',
#  405: '레드',
#  406: '제한',
#  407: '설정',
#  408: '노력',
#  409: '다운로드',
#  410: '단말기',
#  411: '이날',
#  412: '케이스',
#  413: '사장',
#  414: '쌍용차',
#  415: 'LG유플러스',
#  416: '이유',
#  417: '식품',
#  418: '타입',
#  419: '구글',
#  420: '음악',
#  421: '과일',
#  422: '패션',
#  423: '가치',
#  424: '상승',
#  425: '달성',
#  426: '전면',
#  427: '이름',
#  428: '실제',
#  429: '일부',
#  430: '경쟁력',
#  431: '보유',
#  432: '가족',
#  433: '선사',
#  434: '영화',
#  435: '이달',
#  436: '사운드',
#  437: '기아차',
#  438: '화이트',
#  439: '내부',
#  440: '하루',
#  441: '사이즈',
#  442: '업무',
#  443: '정부',
#  444: '와인',
#  445: '갤럭시노트',
#  446: '지원금',
#  447: '프로',
#  448: '사이',
#  449: '오픈',
#  450: '업데이트',
#  451: '테크',
#  452: '이익',
#  453: '신청',
#  454: '노트북',
#  455: '영양',
#  456: '치즈',
#  457: '돌파',
#  458: '전투',
#  459: '디젤',
#  460: '휴대',
#  461: '작업',
#  462: '네트워크',
#  463: '현지',
#  464: '이전',
#  465: '국민',
#  466: '핵심',
#  467: '지난달',
#  468: '거리',
#  469: '겨울',
#  470: '안심',
#  471: '입력',
#  472: '하반기',
#  473: '내장',
#  474: '프로모션',
#  475: '천연',
#  476: '자유',
#  477: '패턴',
#  478: '주년',
#  479: '복합',
#  480: '편안',
#  481: '외부',
#  482: '방법',
#  483: '연금',
#  484: '전년',
#  485: '요소',
#  486: '디지털',
#  487: '메이크업',
#  488: '통신',
#  489: '블루투스',
#  490: '회장',
#  491: '스토어',
#  492: '스타',
#  493: '소형',
#  494: '지금',
#  495: '요리',
#  496: '매력',
#  497: '순위',
#  498: '친구',
#  499: '처리',
#  500: '센서',
#  501: '세단',
#  502: '수수료',
#  503: '에디션',
#  504: '특허',
#  505: '재료',
#  506: '거래',
#  507: '방문',
#  508: '버튼',
#  509: '에너지',
#  510: '제거',
#  511: '슈퍼',
#  512: '차단',
#  513: '딸기',
#  514: '기회',
#  515: '전원',
#  516: '방송',
#  517: '동영상',
#  518: '기획',
#  519: '호텔',
#  520: '메모리',
#  521: '전문가',
#  522: '문화',
#  523: '일정',
#  524: '전기차',
#  525: '장비',
#  526: '만족',
#  527: '종류',
#  528: '평균',
#  529: '오일',
#  530: '제휴',
#  531: '합리',
#  532: '상반기',
#  533: '비중',
#  534: '출고',
#  535: '액션',
#  536: '착용',
#  537: '분위기',
#  538: '재킷',
#  539: '전통',
#  540: '마스크',
#  541: '영웅',
#  542: '사실',
#  543: '보습',
#  544: '어린이',
#  545: '국가',
#  546: '가정',
#  547: '감성',
#  548: '주력',
#  549: '시대',
#  550: '연구',
#  551: '제조',
#  552: '역할',
#  553: '극대',
#  554: '계좌',
#  555: '무게',
#  556: '전달',
#  557: '가전',
#  558: '코스',
#  559: '소비',
#  560: '자극',
#  561: '전력',
#  562: '가량',
#  563: '기술력',
#  564: '대신',
#  565: '활성',
#  566: '저장',
#  567: '협력',
#  568: '마음',
#  569: '현대',
#  570: '바디',
#  571: '인도',
#  572: '대부분',
#  573: '모니터',
#  574: '프로세서',
#  575: '현재',
#  576: '스피커',
#  577: '상환',
#  578: '우유',
#  579: '조작',
#  580: '교육',
#  581: '완벽',
#  582: '뷰티',
#  583: '추천',
#  584: '추첨',
#  585: '자금',
#  586: '그래픽',
#  587: '어디',
#  588: '음성',
#  589: '조건',
#  590: '수출',
#  591: '부품',
#  592: '등급',
#  593: '원료',
#  594: '공장',
#  595: '모바일 게임',
#  596: '실내',
#  597: '미래',
#  598: '사이트',
#  599: '신작',
#  600: '차세대',
#  601: '주문',
#  602: '점유',
#  603: '인식',
#  604: '마력',
#  605: '성과',
#  606: '태블릿',
#  607: '서버',
#  608: '추출물',
#  609: '획득',
#  610: '환자',
#  611: '탄생',
#  612: '공격',
#  613: '프로젝트',
#  614: '협업',
#  615: '화질',
#  616: '오디오',
#  617: '기관',
#  618: '모양',
#  619: '포트',
#  620: '디저트',
#  621: '라이트',
#  622: '방향',
#  623: '적립',
#  624: '조합',
#  625: '연동',
#  626: '사항',
#  627: '요구',
#  628: '영향',
#  629: '택시',
#  630: '개최',
#  631: '당시',
#  632: '러브',
#  633: '개념',
#  634: '종합',
#  635: '치킨',
#  636: '채택',
#  637: '공기',
#  638: '시행',
#  639: '인텔',
#  640: '운용',
#  641: '홍보',
#  642: '멀티',
#  643: '작년',
#  644: '상용',
#  645: '정책',
#  646: '제어',
#  647: '오프라인',
#  648: '대응',
#  649: '공동',
#  650: '소프트웨어',
#  651: '시트',
#  652: '사업자',
#  653: '커버',
#  654: '결정',
#  655: '가솔린',
#  656: '하락',
#  657: '창업',
#  658: '갤럭시',
#  659: '자산',
#  660: '문의',
#  661: '빙수',
#  662: '경기',
#  663: '회원',
#  664: '핑크',
#  665: '흡수',
#  666: '건조',
#  667: '독일',
#  668: '가구',
#  669: '샤오',
#  670: '고민',
#  671: '제주',
#  672: '허니',
#  673: '내구',
#  674: '통화',
#  675: '누적',
#  676: '능력',
#  677: '쿠폰',
#  678: '소스',
#  679: '보급',
#  680: '상당',
#  681: '주식',
#  682: '클럽',
#  683: '에어',
#  684: '눈길',
#  685: 'LTE-A',
#  686: '발전',
#  687: '키즈',
#  688: '전자',
#  689: '쏘나타',
#  690: '이외',
#  691: '중형',
#  692: '반면',
#  693: '장기',
#  694: '모듈',
#  695: '증권',
#  696: '프리',
#  697: '주가',
#  698: '추진',
#  699: '온도',
#  700: '해결',
#  701: '측면',
#  702: '치료',
#  703: '화소',
#  704: '할부',
#  705: '전세계',
#  706: '선호',
#  707: '한정판',
#  708: '실용',
#  709: '지수',
#  710: '장치',
#  711: '전화',
#  712: '접속',
#  713: '아시아',
#  714: '통신사',
#  715: '운전자',
#  716: '위험',
#  717: '검색',
#  718: '해상도',
#  719: '맥주',
#  720: '작품',
#  721: '특유',
#  722: '입장',
#  723: '렌즈',
#  724: '탄력',
#  725: '감각',
#  726: '모두',
#  727: '현장',
#  728: '비즈니스',
#  729: '충족',
#  730: '하이',
#  731: '첨단',
#  732: '초기',
#  733: '키보드',
#  734: '전기',
#  735: '연속',
#  736: '발효',
#  737: '쿠션',
#  738: '휴대폰',
#  739: '그동안',
#  740: '화제',
#  741: '가맹점',
#  742: '박스',
#  743: '넥슨',
#  744: '국산',
#  745: '방침',
#  746: '제약',
#  747: '보험료',
#  748: '토크',
#  749: '자료',
#  750: '특성',
#  751: '상대',
#  752: '담당',
#  753: '보조금',
#  754: '콘셉트',
#  755: '에이',
#  756: '특화',
#  757: '동급',
#  758: '롯데리아',
#  759: '영역',
#  760: '슬림',
#  761: '리스',
#  762: '용품',
#  763: '터보',
#  764: '스페셜',
#  765: '직원',
#  766: '제시',
#  767: '조화',
#  768: '이야기',
#  769: '시기',
#  770: '캐주얼',
#  771: '영국',
#  772: '가죽',
#  773: '통장',
#  774: '사회',
#  775: '경영',
#  776: '연간',
#  777: '페이지',
#  778: '경량',
#  779: '맞춤',
#  780: '레벨',
#  781: '번호',
#  782: '선도',
#  783: '편의점',
#  784: '완료',
#  785: '프랑스',
#  786: '사고',
#  787: '인하',
#  788: '부족',
#  789: '차종',
#  790: '디바이스',
#  791: '오후',
#  792: '이하',
#  793: '개성',
#  794: '선수',
#  795: '만기',
#  796: '오전',
#  797: '한도',
#  798: '고유',
#  799: '법인',
#  800: '연계',
#  801: '인상',
#  802: '푸드',
#  803: '에센스',
#  804: '전 세계',
#  805: '제품군',
#  806: '우려',
#  807: '조정',
#  808: '콜라보레이션',
#  809: '본부장',
#  810: '초콜릿',
#  811: '트위터',
#  812: '에어컨',
#  813: '스킨',
#  814: '음식',
#  815: '재생',
#  816: '치료제',
#  817: '이동통신',
#  818: '학습',
#  819: '행복',
#  820: '지적',
#  821: '도시',
#  822: '현상',
#  823: '바이오',
#  824: '옵션',
#  825: '윈도우',
#  826: '패널',
#  827: '부사장',
#  828: '바람',
#  829: '섭취',
#  830: '추구',
#  831: '멤버',
#  832: '망고',
#  833: '공시',
#  834: '제도',
#  835: '클래식',
#  836: '헤드',
#  837: '듀얼',
#  838: '얼굴',
#  839: '대용량',
#  840: '노하우',
#  841: '게이머',
#  842: '소식',
#  843: '회복',
#  844: '케이크',
#  845: '작동',
#  846: '취향',
#  847: '규제',
#  848: '흥행',
#  849: '가방',
#  850: '절감',
#  851: '추세',
#  852: '교체',
#  853: '베이스',
#  854: '여부',
#  855: '몬스터',
#  856: '소니',
#  857: '리터',
#  858: '오브',
#  859: '독자',
#  860: '물량',
#  861: '크리스마스',
#  862: '단독',
#  863: '조명',
#  864: '작용',
#  865: '연말',
#  866: '투어',
#  867: '방수',
#  868: '매체',
#  869: '차이',
#  870: '주도',
#  871: '부산',
#  872: '년대',
#  873: '대로',
#  874: '부착',
#  875: '두께',
#  876: '애플 앱스토어',
#  877: '액세서리',
#  878: '개국',
#  879: '필수',
#  880: '풍미',
#  881: '메탈',
#  882: '보상',
#  883: '무엇',
#  884: '겨냥',
#  885: '북미',
#  886: '상담',
#  887: '국제',
#  888: '설립',
#  889: '메시지',
#  890: '제외',
#  891: '베스트',
#  892: '완화',
#  893: '백화점',
#  894: '의견',
#  895: '소득',
#  896: '오늘',
#  897: '케이블',
#  898: '범위',
#  899: '넷마블',
#  900: '과거',
#  901: '제보',
#  902: '미디어',
#  903: '블로그',
#  904: '히트',
#  905: '예방',
#  906: '필터',
#  907: '불편',
#  908: '첨가',
#  909: '니즈',
#  910: '손실',
#  911: '스킬',
#  912: '형성',
#  913: '전송',
#  914: '감상',
#  915: '측정',
#  916: '트림',
#  917: '아기',
#  918: '운동',
#  919: '이스',
#  920: '조기',
#  921: '워터',
#  922: '전시',
#  923: '보관',
#  924: '스마트워치',
#  925: '중저가',
#  926: '카카오톡',
#  927: '조리',
#  928: '판단',
#  929: '전작',
#  930: '그레이',
#  931: '체결',
#  932: '스파',
#  933: '아주경제',
#  934: '비타민',
#  935: '상위',
#  936: '야외',
#  937: '상품권',
#  938: '럭셔리',
#  939: '쇼핑',
#  940: '참석',
#  941: '동작',
#  942: '보조',
#  943: '팀장',
#  944: '소프트',
#  945: '하드웨어',
#  946: '대전',
#  947: '버터',
#  948: '영어',
#  949: '인테리어',
#  950: '날씨',
#  951: '감지',
#  952: '홍삼',
#  953: '5종',
#  954: '보온',
#  955: '추출',
#  956: '장르',
#  957: '헬스',
#  958: '신용',
#  959: '인수',
#  960: '개발자',
#  961: '외관',
#  962: '표준',
#  963: '본사',
#  964: '호응',
#  965: '우리나라',
#  966: '클렌징',
#  967: '발휘',
#  968: '월드',
#  969: '피자',
#  970: '버스',
#  971: '캠페인',
#  972: '경품',
#  973: '움직임',
#  974: '코어',
#  975: '비율',
#  976: '소음',
#  977: '아이스크림',
#  978: '로봇',
#  979: '분리',
#  980: '종목',
#  981: '심플',
#  982: '윈도',
#  983: '마힌드라',
#  984: '파티',
#  985: '새해',
#  986: '진단',
#  987: '세탁기',
#  988: '의료',
#  989: '특정',
#  990: '오렌지',
#  991: '적금',
#  992: '발급',
#  993: '방안',
#  994: '인프라',
#  995: '게이밍',
#  996: '도전',
#  997: '구글 플레이',
#  998: '식물',
#  999: '충격'}

# %% [markdown]
#  - 주제 지정 : num_topics  100~200
#  - 주제를 많게 하면 크기가 작아지고
#  - 주제를 적게 하면 크기가 커져버린다.
#   - 문서가 10개밖에 없는데 주제가 1000개면 안되니깐.
#  - id2word : tdm에 실제론 단어가 없다. 단어목록이 필요하다. 그걸 매칭 시켜서 넣어주는 역할을 하는 것.

# %%
lda = LdaModel(corpus=corpus, num_topics=100,
               id2word=dict(enumerate(words)), random_state=1234)

# %% [markdown]
# ### Topic 보기

# %%
lda.show_topic(0) # 0번째 토픽의 내용. 많이 쓰이는 단어들.
# Out:
# [('엔진', 0.035598300668395588),
#  ('모델', 0.022061465894983666),
#  ('터보', 0.021861394456765257),
#  ('쏘나타', 0.01996068072556503),
#  ('출시', 0.018864108929341733),
#  ('주행', 0.017581164097096785),
#  ('성능', 0.015605642117549516),
#  ('시장', 0.015313583378759826),
#  ('현대차', 0.015135502378449871),
#  ('연비', 0.0137427918782684)]

# %%
lda.show_topic(1) # 1번째 토픽의 내용.
# Out:
# [('기술', 0.014133614534345387),
#  ('제공', 0.012383979812783753),
#  ('지원', 0.011869751556929591),
#  ('제품', 0.01128101295511668),
#  ('상품', 0.011035554493394188),
#  ('확대', 0.010133016933681535),
#  ('키보드', 0.0099974017176328225),
#  ('인증', 0.0084583665725528681),
#  ('출시', 0.0083868389641043352),
#  ('개발', 0.0083003654066913998)]

# %%
result_sum = 0
for topic in lda.show_topic(1):
    result_sum += topic[1]

result_sum
# Out:
# 0.10597990294723256

# %% [markdown]
# ### 문서의 topic 확인
# #### 문서 변환

# %%
doc = [(i, tdm[0,i]) for i in range(1000)]

# %%
doc[:10]
# Out:
# [(0, 6),
#  (1, 0),
#  (2, 13),
#  (3, 0),
#  (4, 2),
#  (5, 1),
#  (6, 37),
#  (7, 1),
#  (8, 2),
#  (9, 0)]

# %% [markdown]
# ### 문서에서 가장 많이 쓰인 단어들 보기

# %%
doc_words = [(words[i], n) for i,n in doc]

# %%
doc_words[:10]
# Out:
# [('출시', 6),
#  ('제품', 0),
#  ('제공', 13),
#  ('시장', 0),
#  ('사용', 2),
#  ('서비스', 1),
#  ('게임', 37),
#  ('기능', 1),
#  ('판매', 2),
#  ('국내', 0)]

# %%
sorted(doc_words, key=lambda x:x[1], reverse=True)[:10]
# Out:
# [('게임', 37),
#  ('이벤트', 31),
#  ('아이템', 26),
#  ('진행', 16),
#  ('제공', 13),
#  ('접속', 9),
#  ('최대', 8),
#  ('동안', 8),
#  ('지급', 8),
#  ('이상', 7)]

# %% [markdown]
# ### 문서의 TOPIC

# %%
lda.get_document_topics(doc) # 0번의 뉴스기사는 7번 토픽이 50프로 40버닝 45프로
# Out:
# [(7, 0.50037888840330613),
#  (40, 0.45461820734352415),
#  (47, 0.023145983481028452),
#  (84, 0.020021356718605568)]

# %%
lda.show_topic(7)
# Out:
# [('게임', 0.07978134686807592),
#  ('출시', 0.019118233242111433),
#  ('캐릭터', 0.01753932935494356),
#  ('모바일', 0.016401619836328814),
#  ('콘텐츠', 0.015679694293999676),
#  ('유저', 0.014825264635199797),
#  ('진행', 0.014671920870461558),
#  ('개발', 0.014088483608665381),
#  ('플레이', 0.012352623748539081),
#  ('공개', 0.011440371837632891)]

# %%
lda.show_topic(40)
# Out:
# [('이벤트', 0.044510703076266367),
#  ('진행', 0.036636096002987915),
#  ('행사', 0.030709145787182871),
#  ('할인', 0.03022527283363045),
#  ('구매', 0.019143617972028973),
#  ('제공', 0.015832552597364311),
#  ('출시', 0.014558022680202766),
#  ('이번', 0.013844299670335312),
#  ('증정', 0.013542478560328497),
#  ('고객', 0.012398309133169794)]

# %% [markdown]
# ### 1번 문서 확인

# %%
doc2 = [(i, tdm[1,i]) for i in range(1000)]

# %%
doc_words2 = [(words[i], n) for i,n in doc2]

# %%
doc_words2[:10]
# Out:
# [('출시', 2),
#  ('제품', 0),
#  ('제공', 3),
#  ('시장', 6),
#  ('사용', 7),
#  ('서비스', 0),
#  ('게임', 0),
#  ('기능', 0),
#  ('판매', 3),
#  ('국내', 16)]

# %%
sorted(doc_words2, key=lambda x:x[1], reverse=True)[:10]
# Out:
# [('국내', 16),
#  ('사용', 7),
#  ('삼성전자', 7),
#  ('시장', 6),
#  ('구매', 6),
#  ('조사', 6),
#  ('구글', 6),
#  ('때문', 5),
#  ('해외', 5),
#  ('노트북', 5)]

# %%
lda.get_document_topics(doc2)
# Out:
# [(2, 0.073015649341465566),
#  (6, 0.21647387917760486),
#  (9, 0.13948775326893287),
#  (10, 0.075272218416022857),
#  (62, 0.074565573474988267),
#  (73, 0.033603901246643898),
#  (91, 0.13477736710417146),
#  (92, 0.06288602499264645),
#  (93, 0.087325398204761651),
#  (95, 0.086876725155613621)]

# %%
lda.show_topic(6)
# Out:
# [('라면', 0.036101703364220847),
#  ('제품', 0.030964482955675526),
#  ('출시', 0.022574154175568451),
#  ('시장', 0.020560352254626563),
#  ('사용', 0.013833931051527476),
#  ('프로그램', 0.013468088383134215),
#  ('스마트폰', 0.0085064125544441083),
#  ('소비자', 0.0084995035738467985),
#  ('클라우드', 0.0075079381027734118),
#  ('개발', 0.0074793654848847296)]

# %%
lda.show_topic(9)
# Out:
# [('사업', 0.022719728121037674),
#  ('서비스', 0.021818036470741198),
#  ('기업', 0.016281058526879916),
#  ('시장', 0.01529662443761105),
#  ('산업', 0.011993140693420027),
#  ('지원', 0.0098383042622658592),
#  ('올해', 0.0095429328723263002),
#  ('대표', 0.009535026261915526),
#  ('국내', 0.0089783325940691223),
#  ('중국', 0.0088921796739220727)]

# %% [markdown]
# - 활용 방법
#  - 우리가 알고 싶어하는 토픽을 지정해서 글전체를 크롤링해서 전체를 LDA하고 해당 토픽의 비율을 본다.

# %% [markdown]
# ### LDA 모델 저장하기

# %%
lda.save("20170429.lda")

# %% [markdown]
# ### LDA 모델 불러오기

# %%
lda = LdaModel.load('20170429.lda')

# %%
lda.show_topic(0)
# Out:
# [('엔진', 0.035598300668395588),
#  ('모델', 0.022061465894983666),
#  ('터보', 0.021861394456765257),
#  ('쏘나타', 0.01996068072556503),
#  ('출시', 0.018864108929341733),
#  ('주행', 0.017581164097096785),
#  ('성능', 0.015605642117549516),
#  ('시장', 0.015313583378759826),
#  ('현대차', 0.015135502378449871),
#  ('연비', 0.0137427918782684)]

# %% [markdown]
# # 활용

# %%
from collections import Counter

# %%
total = Counter()

# %%
c['hello']
# Out:
# 0

# %%
num = tdm.shape[0]
for n in range(num):
    doc = [(i, tdm[n,i]) for i in range(1000)]
    topics = lda.get_document_topics(doc)
    for topic,ratio in topics:
        total[topic] += ratio

# %%
sorted(total.items(), key=lambda x:x[1], reverse=True)
# Out:
# [(32, 202.78014104375407),
#  (79, 167.74914840218051),
#  (7, 166.80911793056117),
#  (11, 159.95557287684784),
#  (93, 153.0666518836766),
#  (31, 143.11022616581292),
#  (2, 140.14239807758253),
#  (13, 133.73390824916973),
#  (86, 130.24482950827132),
#  (70, 122.6605213860264),
#  (96, 115.44204603395912),
#  (99, 113.46904844949606),
#  (9, 112.41780059621331),
#  (65, 107.19216960860311),
#  (94, 103.78042957205663),
#  (90, 96.715107877705009),
#  (39, 95.856365634742446),
#  (4, 81.386896651397123),
#  (0, 80.209839175981188),
#  (27, 79.381601060274207),
#  (40, 78.735038526934545),
#  (84, 75.52996333346691),
#  (24, 73.905554257718123),
#  (92, 72.955444332903852),
#  (95, 72.883672837479921),
#  (49, 71.918165394410792),
#  (89, 71.365543635210145),
#  (44, 69.800972983793713),
#  (29, 68.958289573362848),
#  (72, 65.857647321001664),
#  (20, 65.348286850617512),
#  (15, 63.982122355376632),
#  (67, 62.51011778722409),
#  (10, 61.885198532764917),
#  (73, 60.516298931380504),
#  (30, 59.785933178505751),
#  (36, 59.130762806194276),
#  (66, 59.032847649797269),
#  (59, 58.887016808716361),
#  (8, 58.487302573267648),
#  (87, 55.961253088630976),
#  (25, 55.632160178839527),
#  (17, 55.342363031083771),
#  (54, 53.256956892191148),
#  (61, 50.726886004198775),
#  (23, 50.726500516800172),
#  (14, 50.493078891776896),
#  (91, 49.663971055651928),
#  (46, 48.327541497825251),
#  (76, 46.314395794762554),
#  (62, 45.642454486454497),
#  (82, 44.339463725674491),
#  (57, 41.671996390844129),
#  (64, 41.150349751694314),
#  (48, 40.095670884518356),
#  (50, 38.988578409140985),
#  (19, 38.378279720085814),
#  (88, 38.120357893825556),
#  (53, 37.351773509389758),
#  (35, 37.0109208949997),
#  (75, 36.560879897360955),
#  (97, 34.933982465236845),
#  (74, 33.998905316079245),
#  (26, 33.416031335312219),
#  (34, 31.622883209543179),
#  (41, 30.779017449034281),
#  (5, 28.467335281012712),
#  (80, 25.292602623251224),
#  (47, 25.129013749883704),
#  (38, 22.73495480763248),
#  (37, 21.00898746599912),
#  (6, 20.280506783296204),
#  (21, 19.270360379852665),
#  (85, 18.919925941446927),
#  (28, 17.970297997952859),
#  (63, 17.815460090736352),
#  (58, 16.575557896354066),
#  (68, 14.86328573797247),
#  (33, 13.869099839206367),
#  (71, 10.960594468159359),
#  (51, 10.7179499576213),
#  (69, 9.9590614792634131),
#  (77, 8.8844949665385453),
#  (81, 8.8299807409862883),
#  (83, 8.2092192935615476),
#  (56, 6.0126643779877584),
#  (60, 5.8372553740717219),
#  (1, 4.732929220047807),
#  (12, 4.0670997615309226),
#  (78, 3.2111586109798242),
#  (52, 2.7798214918122359),
#  (18, 2.6687072631362541),
#  (16, 2.6167195177692055),
#  (42, 2.1662632049354582),
#  (45, 2.0633406075411629),
#  (3, 1.816312973207671),
#  (22, 1.7189000229644948),
#  (55, 0.66685950930237881),
#  (98, 0.5604412239705201),
#  (43, 0.015649899970607048)]

# %%
lda.show_topic(32)
# Out:
# [('상품', 0.039365202104657375),
#  ('금융', 0.034608988327784078),
#  ('고객', 0.026587372964526464),
#  ('가입', 0.024567468069202045),
#  ('계좌', 0.019564046102156431),
#  ('보험', 0.018872026170587329),
#  ('은행', 0.018649599905942192),
#  ('연금', 0.014788980364521073),
#  ('출시', 0.014184595131843003),
#  ('서비스', 0.013778103148236871)]

# %%
lda.show_topic(79)
# Out:
# [('적용', 0.035615205970862686),
#  ('시스템', 0.0278502756901765),
#  ('디자인', 0.022165810300190953),
#  ('모델', 0.022102134774972568),
#  ('주행', 0.019219508630231384),
#  ('최고', 0.014828876969073873),
#  ('엔진', 0.014337227426088152),
#  ('안전', 0.014026648837611892),
#  ('기능', 0.013393785366017456),
#  ('출시', 0.013215409451121939)]
