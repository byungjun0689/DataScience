# %% [markdown]
# # Twitter

# %%
import twitter

# %%
CONSUMER_KEY = 'J6Y4NEAl5mubjrHQ28kFbWAsw'
CONSUMER_SECRET = 'qbnzZOVPcQjAU0MbKbFybEw5jtcrZTlhs1djEi0Xaix9Ev1gxH'
OAUTH_TOKEN = '896621426-KC4s40IVAlYWhrL61N6RGkxlUMfkirUjGFdvZaju'
OAUTH_TOKEN_SECRET = 'JQ9ZT8j2VY2wKZiehy2IKU5toSkcnfhHevpx0x0Hq6Jn0'

# %%
auth = twitter.oauth.OAuth(OAUTH_TOKEN,OAUTH_TOKEN_SECRET,CONSUMER_KEY,CONSUMER_SECRET)
twitter_api = twitter.Twitter(auth=auth)

# %%
print twitter_api

# %% [markdown]
# ## Example 2. Retrieving trends ( 유행하는 주제 분석 )

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

print world_trends
print
print us_trends
# Out:
# [{u'created_at': u'2016-09-28T14:52:56Z', u'trends': [{u'url': u'http://twitter.com/search?q=Lolla', u'query': u'Lolla', u'tweet_volume': 36773, u'name': u'Lolla', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23PrecisamosFalarSobreAborto', u'query': u'%23PrecisamosFalarSobreAborto', u'tweet_volume': 17580, u'name': u'#PrecisamosFalarSobreAborto', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23FelizMiercoles', u'query': u'%23FelizMiercoles', u'tweet_volume': 39505, u'name': u'#FelizMiercoles', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23DemiLovatoEuVou', u'query': u'%23DemiLovatoEuVou', u'tweet_volume': None, u'name': u'#DemiLovatoEuVou', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23WednesdayWisdom', u'query': u'%23WednesdayWisdom', u'tweet_volume': 43747, u'name': u'#WednesdayWisdom', u'promoted_content': None}, {u'url': u'http://twitter.com/search?q=%23MH17', u'query': u'%23MH17', u'twee
# ...

# %% [markdown]
# ## Example 3. Transform api data to JSON

# %%
import json

print json.dumps(world_trends, indent=1)
print
print json.dumps(us_trends, indent=1)
# Out:
# [
#  {
#   "created_at": "2016-09-28T14:52:56Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=Lolla",
#     "query": "Lolla",
#     "tweet_volume": 36773,
#     "name": "Lolla",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23PrecisamosFalarSobreAborto",
#     "query": "%23PrecisamosFalarSobreAborto",
#     "tweet_volume": 17580,
#     "name": "#PrecisamosFalarSobreAborto",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23FelizMiercoles",
#     "query": "%23FelizMiercoles",
#     "tweet_volume": 39505,
#     "name": "#FelizMiercoles",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23DemiLovatoEuVou",
#     "query": "%23DemiLovatoEuVou",
#     "tweet_volume": null,
#     "name": "#DemiLovatoEuVou",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23WednesdayWisdom",
# ...
