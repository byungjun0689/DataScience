# %% [markdown]
# # Cryer & Chan (2008) Dataset

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %% [markdown]
# ## airmiles
#  - Monthly U.S. airline passenger-miles
#  - 01/1996–05/2005
#  - Source:
#   www.bts.gov/xml/air_traffic/src/index.xml#MonthlySystem

# %%
df = pd.read_csv("Datasets/airmiles.dat")

# %%
df.index = pd.date_range('01/1996', '05/2005', freq='MS')

# %%
df.head()
# Out:
#             airmiles
# 1996-01-01  30983174
# 1996-02-01  32147663
# 1996-03-01  38342975
# 1996-04-01  35969113
# 1996-05-01  36474391

# %%
df.plot()

# %% [markdown]
# ## airpass
#  - Monthly total international airline passengers
#  - 01/1960-12/1971
#  - Source: Box, G. E. P., Jenkins, G. M., and Reinsel, G. C.,Time Series Analysis: Forecasting and Control, second edition, Prentice-Hall, Engelwood Cliffs, NJ, 1994.

# %%
df = pd.read_csv("Datasets/airpass.dat", header=None)
df.index = pd.date_range("01/1960", "12/1971", freq="MS")
df.columns = ["airpass"]

# %%
df.head()
# Out:
#             airpass
# 1960-01-01      112
# 1960-02-01      118
# 1960-03-01      132
# 1960-04-01      129
# 1960-05-01      121

# %%
df.plot()

# %% [markdown]
# ## beersales
#  - Monthly U.S. beer sales (in millions of barrels)
#  - 01/1975–12/1990
#  - Source: Frees, E. W., Data Analysis Using Regression Models, Prentice-Hall, Engelwood Cliffs, NJ, 1996.

# %%
df = pd.read_csv("Datasets/beersales.dat")
df.index = pd.date_range("01/1975", "12/1990", freq="MS")

# %%
df.head()
# Out:
#             beersales
# 1975-01-01    11.1179
# 1975-02-01     9.8413
# 1975-03-01    11.5732
# 1975-04-01    13.0097
# 1975-05-01    13.4182

# %%
df.plot()

# %% [markdown]
# ## bluebird
#  - Weekly unit sales of Bluebird standard potato chips (New Zealand) and their price for 104 weeks
#  - Source: www.stat.auckland.ac.nz/~balemi/Assn3.xls

# %%
df = pd.read_csv('Datasets/bluebird.dat', sep=' ')

# %%
df.tail()
# Out:
#      log.sales  price
# 99    11.28409   1.63
# 100   10.96279   1.83
# 101   11.32806   1.77
# 102   11.53034   1.82
# 103   11.39859   1.73

# %%
plt.subplot(211)
df["log.sales"].plot()
plt.subplot(212)
df.price.plot()

# %% [markdown]
# ## bluebirdlite
#  - Weekly unit sales of Bluebird Lite standard potato chips (New Zealand) and their price for 104 weeks

# %%
df = pd.read_csv('Datasets/bluebirdlite.dat', sep = ' ', header=None)
df.columns = ['log.sales','price']
df.head()
# Out:
#    log.sales  price
# 0    10.1509   1.75
# 1    10.2646   1.69
# 2    10.5188   1.62
# 3    10.4293   1.64
# 4    10.0794   1.67

# %%
plt.subplot(211)
df["log.sales"].plot()
plt.subplot(212)
df.price.plot()

# %% [markdown]
# ## electricity
#  - Monthly U.S. electricity generation (in millions of kilowatt hours) of all types: coal, natural gas, nuclear, petroleum, and wind
#  - 01/1973–12/2005

# %%
df = pd.read_csv('Datasets/electricity.dat')
df.index = pd.date_range('01/1973','12/2005', freq='MS')

# %%
df.head()
# Out:
#             electricity
# 1973-01-01       160218
# 1973-02-01       143539
# 1973-03-01       148158
# 1973-04-01       139589
# 1973-05-01       147395

# %%
df.plot()
