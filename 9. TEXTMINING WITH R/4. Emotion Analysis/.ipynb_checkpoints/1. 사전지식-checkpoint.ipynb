# %% [markdown]
# # 사전 지식
# ### 감정분석: 문장에 사용된 단어로 감정을 예측
# - 예 ) "이 영화는 좀 길지만 재미있고 신난다"
#  - 길다 -> 부정
#  - 재미있다 -> 긍정
#  - 신나다 -> 긍정

# %% [markdown]
# ## 예측분석
#  - 선형회구분석 : 사전 기반
#   - 선형성을 가정한다.
#  - SVM
#  - RandomForest
#  - Deep Learning
#
#  다양한 분석이 가능하다.

# %% [markdown]
# ### 회귀분석(선형, 직선모형)
#  - 키가 1cm증가할때마다 몸무게가 1kg 증가한다.
#  - 월소득이 100만원 증가할 때마다 몸무게가 1kg 감소
#  - 부정단어가 1개 증가할 때 마다 평점 .1 점 감점
#  - 긍정단어가 1개 증가할 때 마다 평점 .1 점 증가
#
# ### 회귀분석의 문제
#  - 변수가 많아지면 과적합(overfitting)이 발생
#   - 적은 수의 단어도 넣게 된다면 회귀계수가 적더라도 영향을 미친다. R-Square 증가
#  - 회귀계수가 극단적으로 커지거나 작아짐
#  - 예측력이 떨어짐
#  - 과적합을 막아주는 방법이 필요.

# %% [markdown]
# ### 과적합을 막는 법
#  - Lasso : 작은 회귀계수를 0으로 만듬.
#   - 상관관계가 높은 두단어가 있으면 하나는 없어지는 경우가 생긴다.
#  - Ridge : 전반적으로 회귀계수를 줄여줌
#  - Elastic net : Lasso + Ridge
#  - 감정분석에서 Lasso를 쓰면 감정 단어만 추출됨. -> 중립적인 단어들이 사라진다.

# %%
mobile <- read.csv('mobile2014.csv', stringsAsFactors = F)

# %%
dim(mobile)
# Out:
# [1] 1999    7

# %%
names(mobile)
# Out:
# [1] "X"         "Title"     "Author"    "ReviewID"  "Texts"     "YMD"
# [7] "Sentiment"

# %%
head(mobile)
# Out:
#        X                                                             Title
# 1 127335 Ripoff don't buy it. Would like to know how to get my money back.
# 2 161579                               I am not satisfied with the product
# 3 152064                                      Stay away buy something else
# 4 180094                                                         wondering
# 5 180037                                                             virus
# 6 137918                                                   Sprint Error 34
#                     Author       ReviewID
# 1             Alex Cropper R112X6CB1GTVF7
# 2           Monica Heredia R3MQ3FY4PWPQFM
# 3 Mark Ducette monte carlo R1QVAAZ9DWLN5Q
# 4                  eaamber R3AR8LYIC3BOI9
# 5                   pamela  RCYC822DI3R6K
# 6             Jane Paulson  R9C4R6HIQLKM2
#                                                                                                                                                                                                                                                                                                                                      Texts
# 1                                                                                                                                                                                                             Phone does not work. Does not allow outgoing text . Incoming calls. Would not disable South African settings. Waste of money
# 2                                  I am not satisfied with the iPhone 5s, because I bought an unlocked iPhone but the one that I recieved is not unlocked, I am not any more in the US, could you tell me how Will you solve this problem.In despiste of your decision, I want yo tell you I am completely not satisfied with the product.
# 3                                                                                                                                                                                                       EATS BATTERIES, BRAND NEW BATTERIES IT EATS FASTER, LG KNOWN PROBLEM WITH THIS MODEL THOUGHT IT WAS MY DAUGHTER, BOY WAS I  WRONG.
# 4                                                                                                                                                                I'm wondering if this phone is good or bad I just bought him and there's good reviews and bad and does it take att go phone sim card or a special kind please let me know
# 5                                                                                                                                                                                                                                          When i got the phone it had a virus on it within 3 days the phone stopped working all together.
# 6 Have the phone with Verizon and Sprint. Sprint has said they have a text issue (Error 34) that there are delays / complete shut downs along the network. It varies among phones and the Samsung (on the Sprint network) appears to be more prone to this issue than other manufacturers - love the phone on Verizon - hate it on Sprint.
#       YMD Sentiment
# 1 1/14/14         0
# 2  1/7/14         0
# 3 1/28/14         0
# 4 1/15/14         0
# 5 1/10/14         0
# 6  1/3/14         0

# %%
mobile[2,]
mobile[1035,]
# Out:
#        X                               Title         Author       ReviewID
# 2 161579 I am not satisfied with the product Monica Heredia R3MQ3FY4PWPQFM
#                                                                                                                                                                                                                                                                                                     Texts
# 2 I am not satisfied with the iPhone 5s, because I bought an unlocked iPhone but the one that I recieved is not unlocked, I am not any more in the US, could you tell me how Will you solve this problem.In despiste of your decision, I want yo tell you I am completely not satisfied with the product.
#      YMD Sentiment
# 2 1/7/14         0
#          X Title        Author       ReviewID
# 1035 41535 works Noah Crabtree R384KSITCNYYVL
#                                                                                                        Texts
# 1035 Another way to pay then having to go to wal mart or deal with the straight talk website or the phone :)
#          YMD Sentiment
# 1035 1/21/14         1

# %%
table(mobile$Sentiment) # 부정적인것 0 긍정적인것 1
# Out:
#    0    1
#  999 1000

# %% [markdown]
# ## DocumentTermMatrix 만들기

# %%
library(tm)

# %%
#stopwords() # 제거해야될 단어.

# %%
#stopwords("SMART") # 리스트가 적을 수도 있다. 조금 더 많은 양의 단어.

# %% [markdown]
#  - weightTfIdf : TermFrequency 에서 보정. (SNS에 설명이 더 있다. )

# %%
mobile$Texts <- iconv(mobile$Texts,"UTF-8","CP949")

# %%
corpus <- Corpus(VectorSource(mobile$Texts))

# %%
dtm <- DocumentTermMatrix(corpus,
                         control = list(tolower = T, 
                                       removePunctuation = T,
                                       removeNumbers = T,
                                       stopwords=stopwords("SMART"),
                                       weighting=weightTfIdf))
# Out:
# Warning message:
# In weighting(x): empty document(s): 119 122 172 231 250 264 320 380 451 534 735 763 920 1073 1131 1139 1147 1212 1298 1306 1434 1458 1669 1715 1729 1795 1802 1813 1879 1947 1962

# %%
dtm
# Out:
# <<DocumentTermMatrix (documents: 1999, terms: 6486)>>
# Non-/sparse entries: 43511/12922003
# Sparsity           : 100%
# Maximal term length: 27
# Weighting          : term frequency - inverse document frequency (normalized) (tf-idf)

# %% [markdown]
# ## 회귀분석으로 감정 사전 만들기

# %%
library(glmnet)
# Out:
# Warning message:
# : package 'glmnet' was built under R version 3.3.2Loading required package: Matrix
# Loading required package: foreach
# Loaded glmnet 2.0-5

# %%
X <- as.matrix(dtm)
Y <- mobile$Sentiment

# %%
X[1:5,1:5] # 첫번째 사람이 말했던 5개 단어에서
# Out:
#     Terms
# Docs   african     calls  disable  incoming    money
#    1 0.8304219 0.3486419 0.679809 0.6637552 0.268633
#    2 0.0000000 0.0000000 0.000000 0.0000000 0.000000
#    3 0.0000000 0.0000000 0.000000 0.0000000 0.000000
#    4 0.0000000 0.0000000 0.000000 0.0000000 0.000000
#    5 0.0000000 0.0000000 0.000000 0.0000000 0.000000

# %%
dim(X)
# Out:
# [1] 1999 6486

# %%
Y[1:5] # 부정
# Out:
# [1] 0 0 0 0 0

# %%
Y[1001:1005] # 긍정
# Out:
# [1] 1 1 1 1 1

# %% [markdown]
# ### 회귀분석

# %%
res.lm <- glmnet(X, Y, family = "binomial", lambda = 0) # family : 두가지 값일때는 binomial, 일반적 회귀분석에선 lambda = 0

# %%
res.lm
# Out:
# Call:  glmnet(x = X, y = Y, family = "binomial", lambda = 0)
#
#        Df   %Dev Lambda
# [1,] 6486 0.9848      0

# %%
summary(res.lm)
# Out:
#            Length Class     Mode
# a0            1   -none-    numeric
# beta       6486   dgCMatrix S4
# df            1   -none-    numeric
# dim           2   -none-    numeric
# lambda        1   -none-    numeric
# dev.ratio     1   -none-    numeric
# nulldev       1   -none-    numeric
# npasses       1   -none-    numeric
# jerr          1   -none-    numeric
# offset        1   -none-    logical
# classnames    2   -none-    character
# call          5   -none-    call
# nobs          1   -none-    numeric

# %%
coef.lm <- coef(res.lm)[,1]
pos.lm <- coef.lm[coef.lm > 0]
neg.lm <- coef.lm[coef.lm < 0]
pos.lm <- sort(pos.lm, decreasing = T) # 정렬
neg.lm <- sort(neg.lm, decreasing = F) # 정렬

# %%
coef.lm[1:5] # 8453단어 중에서 5개만.
# Out:
# (Intercept)     african       calls     disable    incoming
#   0.3253662 -13.3546460 -10.3577317   3.5555547   6.5794482

# %%
pos.lm[1:5]
# Out:
# accommodate beautifully    improves  accurately     blazing
#   261.74471   176.54411   119.85143    96.45786    91.16412

# %%
neg.lm[1:5]
# Out:
#   accesses    adverse        amp unreliable      ainol
#  -222.4002  -184.4769  -168.0390  -133.5880  -111.8530

# %%
length(pos.lm) + length(neg.lm) # 회귀계수가 0인게 없다. 어느 선에서 끊을 것인가를 정해야 된다. Lasso를 이용하면 알아서 0으로 만들어준다.
# Out:
# [1] 6487

# %% [markdown]
# ## Lambda (패널티) 이해하기
# ![overfitting](1.PNG)
# - 가장 예측이 잘된 것이 녹색선에 잘맞게 된 것.
# - M : 차항
# - 차항이 너무 높아지면 Overfitting이 일어난다.

# %% [markdown]
# ![overfitting](2.PNG)
#  - 제약을 키우게 된다면 Training에서는 에러가 늘어나겠지만은 Test에서는 줄어들게 된다.
#  - 하지만 일정 수준을 넘어서게 된다면 에러가 둘 다 높아진다.

# %% [markdown]
# ### Lasso vs Ridge
# ![LassoRidge](3.PNG)
#  - Lasso는 마름모와 등고선이 맞나는 지점에서 정해진다.
#   - $\beta_1$ 값이 0이 되버린다.
#  - Ridge는 원과 만나는 점에서 정해진다.
#   - $\beta$ 값들이 줄어든다.

# %%
res.lasso <- glmnet(X,Y,family = "binomial", alpha=1)

# %%
res.lasso
# Out:
# Call:  glmnet(x = X, y = Y, family = "binomial", alpha = 1)
#
#          Df      %Dev   Lambda
#   [1,]    0 3.155e-14 0.158100
#   [2,]    1 6.419e-03 0.150900
#   [3,]    1 1.232e-02 0.144100
#   [4,]    1 1.779e-02 0.137500
#   [5,]    1 2.289e-02 0.131300
#  [80,]  863 8.657e-01 0.004009
#  [81,]  881 8.712e-01 0.003827
#  [82,]  889 8.764e-01 0.003653
#  [83,]  907 8.814e-01 0.003487
#  [84,]  921 8.861e-01 0.003328
#  [85,]  922 8.907e-01 0.003177
#  [86,]  938 8.950e-01 0.003033
#  [87,]  951 8.991e-01 0.002895
#  [88,]  958 9.031e-01 0.002763
#  [89,]  968 9.068e-01 0.002638
#  [90,]  983 9.104e-01 0.002518
#  [91,]  987 9.138e-01 0.002403
#  [92,]  991 9.171e-01 0.002294
#  [93,] 1006 9.202e-01 0.002190
#  [94,] 1009 9.231e-01 0.002090
#  [95,] 1020 9.260e-01 0.001995
#  [96,] 1033 9.287e-01 0.001905
#  [97,] 1026 9.312e-01 0.001818
#  [98,] 1035 9.337e-01 0.001735
#  [99,] 1041 9.360e-01 0.001656
# [100,] 1046 9.383e-01 0.001581

# %% [markdown]
#  - 오른쪽으로 갈수록 람다가 커진다.
#  - 각각 단어들의 회귀계수를 표현한다.
#  - 람다 커질수록 회귀계수가 줄어든다.
#  - 람다에 따라서 의미있는 단어 개수가 위에 표현이 된다.

# %% [markdown]
#  - 그럼 어떤 람다를 사용해야할까?

# %%
plot(res.lasso, xvar="lambda")
# Out:
# plot without title

# %% [markdown]
# ### 람다 선택
#  - CrossValidation

# %%
set.seed(12345)

# %%
res.lasso <- cv.glmnet(X,Y,family = "binomial", alpha=1, nfolds=4,
                   type.measure="class")

# %%
res.lasso
# Out:
# $lambda
#  [1] 0.158119345 0.150932577 0.144072458 0.137524143 0.131273458 0.125306877
#  [7] 0.119611486 0.114174959 0.108985531 0.104031971 0.099303557 0.094790057
# [13] 0.090481703 0.086369170 0.082443558 0.078696371 0.075119499 0.071705202
# [19] 0.068446090 0.065335109 0.062365528 0.059530918 0.056825146 0.054242356
# [25] 0.051776957 0.049423614 0.047177235 0.045032957 0.042986139 0.041032353
# [31] 0.039167369 0.037387152 0.035687848 0.034065780 0.032517438 0.031039470
# [37] 0.029628678 0.028282009 0.026996548 0.025769513 0.024598249 0.023480221
# [43] 0.022413009 0.021394303 0.020421899 0.019493692 0.018607674 0.017761926
# [49] 0.016954619 0.016184005 0.015448417 0.014746263 0.014076023 0.013436246
# [55] 0.012825548 0.012242607 0.011686161 0.011155007 0.010647995 0.010164027
# [61] 0.009702056 0.009261083 0.008840152 0.008438354 0.008054818 0.007688714
# [67] 0.007339250 0.007005670 0.006687251 0.006383305 0.006093174 0.005816230
# [73] 0.005551873 0.005299532 0.005058660 0.004828736 0.004609263 0.004399765
# [79] 0.004199789 0.004008902 0.003826691 0.003652762 0.003486738 0.003328261
# [85] 0.003176986 0.003032587 0.002894751 0.002763180 0.002637590 0.002517707
# [91] 0.002403273 0.002294041 0.002189773 0.002090245 0.001995240 0.001904553
# [97] 0.001817988 0.001735358 0.001656483
#
# $cvm
#  [1] 0.4762381 0.4047024 0.3641821 0.3626813 0.3626813 0.3601801 0.3546773
#  [8] 0.3481741 0.3371686 0.3261631 0.3211606 0.3176588 0.3121561 0.3086543
#  [67,]  702 7.637e-01 0.007339
#  [68,]  723 7.740e-01 0.007006
#  [69,]  752 7.839e-01 0.006687
#  [70,]  761 7.932e-01 0.006383
#  [71,]  770 8.022e-01 0.006093
#  [72,]  791 8.106e-01 0.005816
#  [73,]  789 8.187e-01 0.005552
#  [74,]  807 8.264e-01 0.005300
#  [75,]  821 8.338e-01 0.005059
#  [76,]  825 8.408e-01 0.004829
#  [77,]  839 8.475e-01 0.004609
#  [78,]  848 8.538e-01 0.004400
#  [79,]  856 8.599e-01 0.004200
#  [80,]  863 8.657e-01 0.004009
#  [81,]  881 8.712e-01 0.003827
#  [82,]  889 8.764e-01 0.003653
#  [83,]  907 8.814e-01 0.003487
#  [84,]  921 8.861e-01 0.003328
#  [85,]  922 8.907e-01 0.003177
#  [86,]  938 8.950e-01 0.003033
#  [87,]  951 8.991e-01 0.002895
#  [88,]  958 9.031e-01 0.002763
#  [89,]  968 9.068e-01 0.002638
#  [90,]  983 9.104e-01 0.002518
#  [91,]  987 9.138e-01 0.002403
#  [92,]  991 9.171e-01 0.002294
#  [93,] 1006 9.202e-01 0.002190
#  [94,] 1009 9.231e-01 0.002090
#  [95,] 1020 9.260e-01 0.001995
#  [96,] 1033 9.287e-01 0.001905
#  [97,] 1026 9.312e-01 0.001818
#  [98,] 1035 9.337e-01 0.001735
#  [99,] 1041 9.360e-01 0.001656
# [100,] 1046 9.383e-01 0.001581
#
# $lambda.min
# [1] 0.01115501
#
# $lambda.1se
# [1] 0.01474626
#
# attr(,"class")
# [1] "cv.glmnet"

# %%
plot(res.lasso)
# Out:
# plot without title

# %%
log(0.01054217)
# Out:
# [1] -4.552372

# %%
plot(res.lasso$glmnet.fit, xvar = "lambda") # 위와 동일한 모양.
# Out:
# plot without title

# %%
options(scipen = 100)

# %%
coef.lasso <- coef(res.lasso, s="lambda.min")[,1]

# %%
coef.lasso[1:10]
# Out:
# (Intercept)     african       calls     disable    incoming       money
# -0.26569180  0.00000000 -1.93155149  0.00000000  0.00000000 -3.30005752
#    outgoing       phone    settings       south
#  0.00000000 -0.02083245  0.00000000  0.00000000

# %%
pos.lasso <- coef.lasso[coef.lasso>0]
neg.lasso <- coef.lasso[coef.lasso<0]

# %%
pos.lasso <- sort(pos.lasso, decreasing = T)
neg.lasso <- sort(neg.lasso, decreasing = F)

# %%
pos.lasso[1:5]
# Out:
#      ugly     title   typical     great      love
# 38.262176 35.553740 18.108717  9.094434  6.688951

# %%
neg.lasso[1:5]
# Out:
#     pushed  promising  addresses     return repeatedly
#  -7.647248  -6.022731  -5.590882  -4.871807  -4.781535

# %% [markdown]
# ## Ridge Regression

# %%
set.seed(12345)

# %%
res.ridge <- cv.glmnet(X,Y,family="binomial",alpha=0, nfolds=4, type.measure = "class")

# %%
res.ridge
# Out:
# $lambda
#  [1] 158.119345 150.932577 144.072458 137.524143 131.273458 125.306877
#  [7] 119.611486 114.174959 108.985531 104.031971  99.303557  94.790057
# [13]  90.481703  86.369170  82.443558  78.696371  75.119499  71.705202
#  [44,] 6486 0.08466000000000000  21.390
#  [45,] 6486 0.08814000000000000  20.420
#  [46,] 6486 0.09175000000000000  19.490
#  [47,] 6486 0.09548000000000000  18.610
#  [48,] 6486 0.09933000000000000  17.760
#  [49,] 6486 0.10330000000000000  16.950
#  [50,] 6486 0.10750000000000000  16.180
#  [51,] 6486 0.11169999999999999  15.450
#  [52,] 6486 0.11609999999999999  14.750
#  [53,] 6486 0.12070000000000000  14.080
#  [54,] 6486 0.12529999999999999  13.440
#  [55,] 6486 0.13020000000000001  12.830
#  [56,] 6486 0.13519999999999999  12.240
#  [57,] 6486 0.14030000000000001  11.690
#  [58,] 6486 0.14560000000000001  11.160
#  [59,] 6486 0.15070000000000000  10.650
#  [60,] 6486 0.15629999999999999  10.160
#  [61,] 6486 0.16200000000000001   9.702
#  [62,] 6486 0.16789999999999999   9.261
#  [63,] 6486 0.17390000000000000   8.840
#  [64,] 6486 0.18010000000000001   8.438
#  [65,] 6486 0.18650000000000000   8.055
#  [66,] 6486 0.19300000000000000   7.689
#  [67,] 6486 0.19960000000000000   7.339
#  [68,] 6486 0.20640000000000000   7.006
#  [69,] 6486 0.21340000000000001   6.687
#  [70,] 6486 0.22050000000000000   6.383
#  [71,] 6486 0.22780000000000000   6.093
#  [72,] 6486 0.23519999999999999   5.816
#  [73,] 6486 0.24279999999999999   5.552
#  [74,] 6486 0.25050000000000000   5.300
#  [75,] 6486 0.25829999999999997   5.059
#  [76,] 6486 0.26629999999999998   4.829
#  [77,] 6486 0.27439999999999998   4.609
#  [78,] 6486 0.28260000000000002   4.400
#  [79,] 6486 0.29099999999999998   4.200
#  [80,] 6486 0.29940000000000000   4.009
#  [81,] 6486 0.30800000000000000   3.827
#  [82,] 6486 0.31669999999999998   3.653
#  [83,] 6486 0.32550000000000001   3.487
#  [84,] 6486 0.33439999999999998   3.328
#  [85,] 6486 0.34329999999999999   3.177
#  [86,] 6486 0.35239999999999999   3.033
#  [87,] 6486 0.36149999999999999   2.895
#  [88,] 6486 0.37069999999999997   2.763
#  [89,] 6486 0.37990000000000002   2.638
#  [90,] 6486 0.38929999999999998   2.518
#  [91,] 6486 0.39860000000000001   2.403
#  [92,] 6486 0.40799999999999997   2.294
#  [93,] 6486 0.41739999999999999   2.190
#  [94,] 6486 0.42690000000000000   2.090
#  [95,] 6486 0.43640000000000001   1.995
#  [96,] 6486 0.44590000000000002   1.905
#  [97,] 6486 0.45540000000000003   1.818
#  [98,] 6486 0.46479999999999999   1.735
#  [99,] 6486 0.47430000000000000   1.656
# [100,] 6486 0.48380000000000001   1.581
#
# $lambda.min
# [1] 1.735358
#
# $lambda.1se
# [1] 3.032587
#
# attr(,"class")
# [1] "cv.glmnet"

# %%
log( 1.71811) # 최적의 람다.
# Out:
# [1] 0.5412248

# %%
plot(res.ridge)
# Out:
# plot without title

# %%
plot(res.ridge$glmnet.fit, xvar = "lambda")
# Out:
# plot without title

# %%
coef.ridge <- coef(res.ridge, s = "lambda.min")[,1]

# %%
pos.ridge <- coef.ridge[coef.ridge > 0]
neg.ridge <- coef.ridge[coef.ridge < 0]

# %%
pos.ridge <- sort(pos.ridge, decreasing = T)
neg.ridge <- sort(neg.ridge, decreasing = F)

# %%
pos.ridge[1:5]
# Out:
#   acurate  arguably   artwork barometer     bland
#  3.031918  3.031841  3.031757  3.031668  3.031575

# %%
neg.ridge[1:5]
# Out:
#             cal            maze             org    recalibrated soooooooooooooo
#       -1.883683       -1.883645       -1.883609       -1.883556       -1.883525

# %% [markdown]
# ## 엘라스틱넷.
#  - 사랑한다. 사모한다 이와같이 비슷한 단어가 나오면 라소는 하나만 선택한다.
#  - 릿지는 두 단어다 선택이 된다.
#  - Lasso의 장점(필요 없는 것은 0)과 Ridge(비슷한 단어 두개다 선택이 가능)의 장점.

# %%
set.seed(12345)

# %%
res.elastic <- cv.glmnet(X, Y, family = "binomial", alpha = .5,
                         nfolds = 4, type.measure="class") # 알파 0.5 >> 조절가능.

# %%
res.elastic
# Out:
# $lambda
#  [1] 0.316238690 0.301865153 0.288144916 0.275048285 0.262546916 0.250613754
#  [7] 0.239222972 0.228349918 0.217971062 0.208063941 0.198607114 0.189580114
# [13] 0.180963405 0.172738339 0.164887115 0.157392741 0.150238998 0.143410404
# [19] 0.136892180 0.130670219 0.124731056 0.119061837 0.113650293 0.108484711
# [25] 0.103553914 0.098847229 0.094354469 0.090065913 0.085972278 0.082064706
# [31] 0.078334738 0.074774303 0.071375696 0.068131560 0.065034876 0.062078940
# [37] 0.059257357 0.056564018 0.053993096 0.051539027 0.049196499 0.046960442
# [43] 0.044826017 0.042788606 0.040843797 0.038987384 0.037215347 0.035523852
# [49] 0.033909238 0.032368011 0.030896835 0.029492526 0.028152045 0.026872491
# [55] 0.025651095 0.024485213 0.023372323 0.022310014 0.021295990 0.020328054
# [61] 0.019404113 0.018522166 0.017680305 0.016876708 0.016109635 0.015377428
# [67] 0.014678500 0.014011339 0.013374502 0.012766610 0.012186348 0.011632460
# [73] 0.011103747 0.010599064 0.010117320 0.009657473 0.009218526 0.008799529
# [79] 0.008399577 0.008017803 0.007653382 0.007305524 0.006973477 0.006656521
# [85] 0.006353972 0.006065174 0.005789503 0.005526361 0.005275179 0.005035414
# [91] 0.004806547 0.004588082 0.004379547 0.004180489 0.003990480 0.003809106
# [97] 0.003635976 0.003470716 0.003312966
#
# $cvm
#  [1] 0.4777389 0.4077039 0.3656828 0.3641821 0.3631816 0.3596798 0.3541771
#  [8] 0.3426713 0.3356678 0.3226613 0.3191596 0.3141571 0.3116558 0.3061531
# [15] 0.2931466 0.2836418 0.2696348 0.2641321 0.2576288 0.2506253 0.2461231
# [22] 0.2416208 0.2361181 0.2316158 0.2226113 0.2171086 0.2086043 0.2041021
# [29] 0.2016008 0.1975988 0.1915958 0.1915958 0.1875938 0.1810905 0.1780890
# [36] 0.1745873 0.1705853 0.1695848 0.1660830 0.1605803 0.1545773 0.1505753
# [43] 0.1470735 0.1450725 0.1410705 0.1370685 0.1340670 0.1295648 0.1275638
# [50] 0.1280640 0.1295648 0.1275638 0.1265633 0.1275638 0.1240620 0.1240620
#  [71,]  961 0.78610000000000002 0.012190
#  [72,]  979 0.79490000000000005 0.011630
#  [73,] 1002 0.80340000000000000 0.011100
#  [74,] 1034 0.81150000000000000 0.010600
#  [75,] 1051 0.81920000000000004 0.010120
#  [76,] 1071 0.82660000000000000 0.009657
#  [77,] 1094 0.83370000000000000 0.009219
#  [78,] 1117 0.84040000000000004 0.008800
#  [79,] 1133 0.84689999999999999 0.008400
#  [80,] 1152 0.85299999999999998 0.008018
#  [81,] 1173 0.85890000000000000 0.007653
#  [82,] 1186 0.86450000000000005 0.007306
#  [83,] 1213 0.86990000000000001 0.006973
#  [84,] 1251 0.87500000000000000 0.006657
#  [85,] 1255 0.87990000000000002 0.006354
#  [86,] 1262 0.88460000000000005 0.006065
#  [87,] 1273 0.88910000000000000 0.005790
#  [88,] 1299 0.89339999999999997 0.005526
#  [89,] 1319 0.89739999999999998 0.005275
#  [90,] 1322 0.90129999999999999 0.005035
#  [91,] 1351 0.90500000000000003 0.004807
#  [92,] 1354 0.90859999999999996 0.004588
#  [93,] 1361 0.91190000000000004 0.004380
#  [94,] 1392 0.91520000000000001 0.004180
#  [95,] 1400 0.91820000000000002 0.003990
#  [96,] 1419 0.92120000000000002 0.003809
#  [97,] 1436 0.92400000000000004 0.003636
#  [98,] 1447 0.92669999999999997 0.003471
#  [99,] 1461 0.92920000000000003 0.003313
# [100,] 1472 0.93169999999999997 0.003162
#
# $lambda.min
# [1] 0.02032805
#
# $lambda.1se
# [1] 0.03552385
#
# attr(,"class")
# [1] "cv.glmnet"

# %%
log(0.02424186)
# Out:
# [1] -3.719674

# %%
plot(res.elastic)
# Out:
# plot without title

# %% [markdown]
#  - Lasso와 비슷하게 나오나 조금 차이는 있다.

# %%
plot(res.elastic$glmnet.fit, xvar = "lambda")
# Out:
# plot without title

# %%
coef.elastic <- coef(res.elastic, s = "lambda.min")[,1]

# %%
pos.elastic <- coef.elastic[coef.elastic > 0]
neg.elastic <- coef.elastic[coef.elastic < 0]

# %%
pos.elastic <- sort(pos.elastic, decreasing = T)
neg.elastic <- sort(neg.elastic, decreasing = F)

# %% [markdown]
# ## 감정사전 저장하기.

# %% [markdown]
#  - 일반 회귀분석 : 모든단어들이 포함.

# %%
length(pos.lm)
length(neg.lm)
# Out:
# [1] 3113
# [1] 3374

# %% [markdown]
#  - Lasso : 많이 줄었다.

# %%
length(pos.lasso)
length(neg.lasso)
# Out:
# [1] 243
# [1] 232

# %% [markdown]
#  - Ridge : 일반적인 회귀와 비슷하게 대부분의 단어가 사용 된다.

# %%
length(pos.ridge)
length(neg.ridge)
# Out:
# [1] 3483
# [1] 3004

# %% [markdown]
# - Elastic : Lasso와 비슷하게 나왔다.

# %%
length(pos.elastic)
length(neg.elastic)
# Out:
# [1] 296
# [1] 303

# %%
write.csv(pos.lm, "pos.lm.csv")
write.csv(neg.lm, "neg.lm.csv")
write.csv(pos.lasso, "pos.lasso.csv")
write.csv(neg.lasso, "neg.lasso.csv")
write.csv(pos.ridge, "pos.ridge.csv")
write.csv(neg.ridge, "neg.ridge.csv")
write.csv(pos.elastic, "pos.elastic.csv")
write.csv(neg.elastic, "neg.elastic.csv")

# %% [markdown]
# ## 감정사전을 이용한 감정분석
#
# ### Sentiment Indicators^2
# $p$ : 긍정단어 갯수 <br>
# $n$ : 부정단어 갯수
# $$ Polarity = {{p-n} \over {p+n}}$$
# $$ Subjectivity = {{n+p} \over {N}}$$
# $$ Pos\_refs\_per\_ref = {{P} \over {N}}$$
# $$ Neg\_refs\_per\_ref = {{n} \over {N}}$$
# $$ Senti\_diffs\_per\_ref = {{p-n} \over {N}}$$

# %%
library(tm.plugin.sentiment)

# %%
senti.lm <- polarity(dtm, names(pos.lm), names(neg.lm))

# %%
senti.lm[1:10]
# Out:
#           1           2           3           4           5           6
# -0.04879898 -0.22801155 -0.25146264 -0.28694339 -0.22588880 -0.25092104
#           7           8           9          10
# -0.46396956 -0.35839275 -0.02246738 -0.08394105

# %%
senti.lasso <- polarity(dtm, names(pos.lasso), names(neg.lasso))

# %%
senti.lasso[1:10]
# Out:
#          1          2          3          4          5          6          7
# -1.0000000 -0.3013307 -1.0000000 -0.3073848 -1.0000000 -0.8974652 -0.8537635
#          8          9         10
# -0.8124093 -0.4464414 -0.1801721

# %%
senti.ridge <- polarity(dtm, names(pos.ridge), names(neg.ridge))

# %%
senti.ridge[1:10]
# Out:
#           1           2           3           4           5           6
# -1.00000000 -0.41433872 -0.58299650 -0.66338517 -1.00000000 -0.77062297
#           7           8           9          10
# -0.62796936 -0.73954913  0.05850395 -0.39252263

# %%
senti.elastic <- polarity(dtm, names(pos.elastic), names(neg.elastic))

# %%
senti.elastic[1:10]
# Out:
#          1          2          3          4          5          6          7
# -1.0000000 -0.6034383 -1.0000000 -0.3073848 -1.0000000 -0.8974652 -0.8537635
#          8          9         10
# -0.8124093 -0.3292037 -0.1995697

# %% [markdown]
#  - CSV파일 데이터로 하기. ( 굳이 할 필요 없다.)

# %%
#pos.lm.csv <- read.csv('pos.lm.csv')
#neg.lm.csv <- read.csv('neg.lm.csv')
#pos.lasso.csv <- read.csv('pos.lasso.csv')
#neg.lasso.csv <- read.csv('neg.lasso.csv')
#senti.lm <- polarity(dtm, pos.lm.csv[,1], neg.lm.csv[,1])
#senti.lasso <- polarity(dtm, pos.lasso.csv[,1], neg.lasso.csv[,1])

# %% [markdown]
# ## 감정분석이 얼마나 정확한가?

# %% [markdown]
# #### 극(polarity) 감정 점수 0 or 1로 변환하기

# %%
senti.lm.b <- ifelse(senti.lm > 0, 1, 0)
senti.lasso.b <- ifelse(senti.lasso > 0, 1, 0)
senti.ridge.b <- ifelse(senti.ridge > 0, 1, 0)
senti.elastic.b <- ifelse(senti.elastic > 0, 1, 0)

# %% [markdown]
# #### 정확도 계산하기.

# %%
library(caret)

# %%
confusionMatrix(senti.lm.b, mobile$Sentiment)
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction   0   1
#          0 898 117
#          1 101 883
#
#                Accuracy : 0.8909
#                  95% CI : (0.8765, 0.9043)
#     No Information Rate : 0.5003
#     P-Value [Acc > NIR] : <0.0000000000000002
#
#                   Kappa : 0.7819
#  Mcnemar's Test P-Value : 0.3097
#
#             Sensitivity : 0.8989
#             Specificity : 0.8830
#          Pos Pred Value : 0.8847
#          Neg Pred Value : 0.8974
#              Prevalence : 0.4997
#          Detection Rate : 0.4492
#    Detection Prevalence : 0.5078
#       Balanced Accuracy : 0.8909
#
#        'Positive' Class : 0

# %%
confusionMatrix(senti.lasso.b, mobile$Sentiment)
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction   0   1
#          0 978  77
#          1  21 923
#
#                Accuracy : 0.951
#                  95% CI : (0.9406, 0.96)
#     No Information Rate : 0.5003
#     P-Value [Acc > NIR] : < 0.00000000000000022
#
#                   Kappa : 0.902
#  Mcnemar's Test P-Value : 0.00000002763
#
#             Sensitivity : 0.9790
#             Specificity : 0.9230
#          Pos Pred Value : 0.9270
#          Neg Pred Value : 0.9778
#              Prevalence : 0.4997
#          Detection Rate : 0.4892
#    Detection Prevalence : 0.5278
#       Balanced Accuracy : 0.9510
#
#        'Positive' Class : 0

# %%
confusionMatrix(senti.ridge.b, mobile$Sentiment)
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction   0   1
#          0 978  40
#          1  21 960
#
#                Accuracy : 0.9695
#                  95% CI : (0.961, 0.9766)
#     No Information Rate : 0.5003
#     P-Value [Acc > NIR] : < 0.0000000000000002
#
#                   Kappa : 0.939
#  Mcnemar's Test P-Value : 0.02119
#
#             Sensitivity : 0.9790
#             Specificity : 0.9600
#          Pos Pred Value : 0.9607
#          Neg Pred Value : 0.9786
#              Prevalence : 0.4997
#          Detection Rate : 0.4892
#    Detection Prevalence : 0.5093
#       Balanced Accuracy : 0.9695
#
#        'Positive' Class : 0

# %%
confusionMatrix(senti.elastic.b, mobile$Sentiment)
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction   0   1
#          0 983  68
#          1  16 932
#
#                Accuracy : 0.958
#                  95% CI : (0.9482, 0.9663)
#     No Information Rate : 0.5003
#     P-Value [Acc > NIR] : < 0.00000000000000022
#
#                   Kappa : 0.916
#  Mcnemar's Test P-Value : 0.00000002628
#
#             Sensitivity : 0.9840
#             Specificity : 0.9320
#          Pos Pred Value : 0.9353
#          Neg Pred Value : 0.9831
#              Prevalence : 0.4997
#          Detection Rate : 0.4917
#    Detection Prevalence : 0.5258
#       Balanced Accuracy : 0.9580
#
#        'Positive' Class : 0

# %% [markdown]
# ### 더 엄밀한 정확도를 구하기 위해 TEST 데이터 불러오기

# %%
mobile.test <- read.csv("mobile2014_test.csv",stringsAsFactors=F)

# %%
dim(mobile.test)
# Out:
# [1] 1000    7

# %%
names(mobile.test)
# Out:
# [1] "X"         "Title"     "Author"    "ReviewID"  "Texts"     "YMD"
# [7] "Sentiment"

# %%
mobile.test$Texts <- iconv(mobile.test$Texts,"UTF-8","CP949")

# %%
corpus <- Corpus(VectorSource(mobile.test$Texts))

# %%
dtm.test <- DocumentTermMatrix(corpus,
                          control = list(tolower = T,
                                         removePunctuation = T,
                                         removeNumbers = T,
                                         stopwords = stopwords("SMART"),
                                         weighting = weightTfIdf,
                                         dictionary = Terms(dtm)))
# Out:
# Warning message:
# In weighting(x): empty document(s): 464 883 944Warning message:
# In weighting(x): unreferenced term(s): wendy williams tracphone unaccepable scrapes itand soda spit sticky specifications gears imposible randomlly rude solely diferent imed ittt asia blanks pinch traveling definite displayed age concern depend eager emerging financial health helping holder hopelessly kids needing notes notified notifying thrilled understandable unhelpful insert continually disconnect looser rebooted reconnect bin bothered human ivr unbranded accomplish accurate annoyance annoys anxiously brakes complaint deliberately dozen expires finger flying habit icon ideal involved judging lag lap lastly layout manages materials measly mellow melody misunderstands navigate neat pedals personal rid rubberized shiny simpler slides slightest slightly slips smooth surface synced synched translates trial ughhh zillion alternate gambled inability leather partially ships technically touching disaster indication denied imposibel italian rober affects sticks visuals effective liberated manufactures pedi responses describing ipod saleing promised airplane cables mod callnot gplacing holdhanging reliablei honored honors justice soooo systematically observed vga brain furry fuzzy mechanism dated dating relie stalled duped indicating red stripes admit bandwagon blamed closing coding culprit developer dryers effects events execution faltered fanboy inch intercepting leaned narrowed observation overlay pinpointed poorly programming range refrigerators relief sluggishness stall teams thread touchwiz transition washers woes ossue direction duplex locate nyc paste rectify rhyme speakerphone spinning station subway unread debated bla cousin earlier reture ain iever spreading heck kill bringing characteristics added craps dissatisfied incase lake lowes michigan pier satisfaction screwing simm protectors register cap dug aclarar clarify compra demora esta estraviado estravioi iso llegado mano mas mese mis por problema producto resolver bugs lasting breakdown convinced icloud itunes struggling annoy arrives bait event incorrect manufacture oem quadruple upcoming phn powers fall hoax isolated reassembled thay fire row mfg caught center centers created eastern england forgotten geeksquad grey minumum mywishlist proper reactivation region stateside thins nadien designated encountered engineering manageable paltry partitioned unpublished unremovable verified crapped disabling maxx europeans redline browser exits overheats struggles balance contracting entered fired gov healthcare nevermind numbing occurred phonesucks poof provoke script stellar colour lovers outrageous snobs spectacular arrgggghhhhhh class collar deletion depresses engineers exploration heat inadvertently misdeal pants print prototypes rub suits surly testing waking wan wear min august october stealing techgiant pull dinosaur hubby longevity replaceable wages ware determined trips camer cloned loo delayed velis burner disconnected earpiece maintain riding assistance effect energy fiasco history unnecessary coincidence doubtful pricey turkey umm avid dissappointed intentiontions unsure upser grossly albeit backwards dots escape fingerprint godsend impressed lightweight notable pauses sensor servers steep strong wellcons debt serius yearly damm mbc witch merchandise ocntrario released verisonsold attentive foot frustrations iit learnt miracle router bands desbloqeado insastifecha audible icons squares blurry naive crag lights flick gotta bits bolts colored disclosed drawn facts impression marketing mix sales separately strategy tax uneven angola attempted marked permanently admitted admitting bold goods lodged mistakes seals skybox tampering young consume meager meh stare reccommend alarmed automated custom listing modifications modified signing upgrades languages blame notifies tainted wet invoice ito kirch kreech facing cdma contrto graciasd gsms technology garbled peoples tin burning evidence dislike girlfriend bestbuy refurbish target tomorrow estafadora estafadores recommendes ...

# %%
dtm.test
# Out:
# <<DocumentTermMatrix (documents: 1000, terms: 6486)>>
# Non-/sparse entries: 21688/6464312
# Sparsity           : 100%
# Maximal term length: 27
# Weighting          : term frequency - inverse document frequency (normalized) (tf-idf)

# %% [markdown]
#  - 테스트 데이터 Ploarity 감정 점수 계산

# %%
senti.lm.test <- polarity(dtm.test, names(pos.lm), names(neg.lm))
senti.lasso.test <- polarity(dtm.test, names(pos.lasso), names(neg.lasso))
senti.ridge.test <- polarity(dtm.test, names(pos.ridge), names(neg.ridge))
senti.elastic.test <- polarity(dtm.test, names(pos.elastic), names(neg.elastic))

# %% [markdown]
#  - 감정점수 0 or 1로 변환하기

# %%
senti.lm.b.test <- ifelse(senti.lm.test > 0, 1, 0)
senti.lasso.b.test <- ifelse(senti.lasso.test > 0, 1, 0)
senti.ridge.b.test <- ifelse(senti.ridge.test > 0, 1, 0)
senti.elastic.b.test <- ifelse(senti.elastic.test > 0, 1, 0)

# %%
confusionMatrix(senti.lm.b.test, mobile.test$Sentiment)
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction   0   1
#          0 358 277
#          1 142 223
#
#                Accuracy : 0.581
#                  95% CI : (0.5497, 0.6118)
#     No Information Rate : 0.5
#     P-Value [Acc > NIR] : 0.00000016809411
#
#                   Kappa : 0.162
#  Mcnemar's Test P-Value : 0.00000000005897
#
#             Sensitivity : 0.7160
#             Specificity : 0.4460
#          Pos Pred Value : 0.5638
#          Neg Pred Value : 0.6110
#              Prevalence : 0.5000
#          Detection Rate : 0.3580
#    Detection Prevalence : 0.6350
#       Balanced Accuracy : 0.5810
#
#        'Positive' Class : 0

# %%
confusionMatrix(senti.lasso.b.test, mobile.test$Sentiment)
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction   0   1
#          0 430 425
#          1  70  75
#
#                Accuracy : 0.505
#                  95% CI : (0.4735, 0.5364)
#     No Information Rate : 0.5
#     P-Value [Acc > NIR] : 0.388
#
#                   Kappa : 0.01
#  Mcnemar's Test P-Value : <0.0000000000000002
#
#             Sensitivity : 0.8600
#             Specificity : 0.1500
#          Pos Pred Value : 0.5029
#          Neg Pred Value : 0.5172
#              Prevalence : 0.5000
#          Detection Rate : 0.4300
#    Detection Prevalence : 0.8550
#       Balanced Accuracy : 0.5050
#
#        'Positive' Class : 0

# %%
confusionMatrix(senti.ridge.b.test, mobile.test$Sentiment)
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction   0   1
#          0 483 455
#          1  17  45
#
#                Accuracy : 0.528
#                  95% CI : (0.4965, 0.5593)
#     No Information Rate : 0.5
#     P-Value [Acc > NIR] : 0.04097
#
#                   Kappa : 0.056
#  Mcnemar's Test P-Value : < 0.0000000000000002
#
#             Sensitivity : 0.9660
#             Specificity : 0.0900
#          Pos Pred Value : 0.5149
#          Neg Pred Value : 0.7258
#              Prevalence : 0.5000
#          Detection Rate : 0.4830
#    Detection Prevalence : 0.9380
#       Balanced Accuracy : 0.5280
#
#        'Positive' Class : 0

# %%
confusionMatrix(senti.elastic.b.test, mobile.test$Sentiment)
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction   0   1
#          0 439 441
#          1  61  59
#
#                Accuracy : 0.498
#                  95% CI : (0.4666, 0.5295)
#     No Information Rate : 0.5
#     P-Value [Acc > NIR] : 0.5628
#
#                   Kappa : -0.004
#  Mcnemar's Test P-Value : <0.0000000000000002
#
#             Sensitivity : 0.8780
#             Specificity : 0.1180
#          Pos Pred Value : 0.4989
#          Neg Pred Value : 0.4917
#              Prevalence : 0.5000
#          Detection Rate : 0.4390
#    Detection Prevalence : 0.8800
#       Balanced Accuracy : 0.4980
#
#        'Positive' Class : 0
