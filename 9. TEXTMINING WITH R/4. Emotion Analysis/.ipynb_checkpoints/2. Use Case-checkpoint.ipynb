# %% [markdown]
# # 1. Table Data

# %%
library(tm)
library(tm.plugin.sentiment)
library(glmnet)

# %% [markdown]
# ## 총 정리 및 복습.

# %%
mobile <- read.csv("mobile2014.csv", stringsAsFactors = F, encoding="UTF-8")

# %%
corpus <- Corpus(VectorSource(mobile$Texts))

# %%
dtm <- DocumentTermMatrix(corpus,
                          control = list(tolower = T,
                                         removePunctuation = T,
                                         removeNumbers = T,
                                         stopwords = stopwords("SMART"),
                                         weighting = weightTfIdf))
# Out:
# Warning message:
# In weighting(x): empty document(s): 534 1947

# %%
my.stopwords <- c(stopwords("SMART"), "aaa")

# %%
X <- as.matrix(dtm)
Y <- mobile$Sentiment

# %%
res.lm <- glmnet(X, Y, family = 'binomial', lambda = 0)
coef.lm <- coef(res.lm)[,1]

pos.lm <- coef.lm[coef.lm > 0]
neg.lm <- coef.lm[coef.lm < 0]

pos.lm <- sort(pos.lm, decreasing = T)
neg.lm <- sort(neg.lm, decreasing = F)

# %%
res.lasso <- glmnet(X, Y, family = 'binomial', alpha = 1)
set.seed(12345)
res.lasso <- cv.glmnet(X, Y, family = 'binomial', alpha = 1,
                       nfolds = 4, type.measure = 'class')

# %%
coef.lasso <- coef(res.lasso, s = 'lambda.min')[,1]
pos.lasso <- coef.lasso[coef.lasso > 0]
neg.lasso <- coef.lasso[coef.lasso < 0]
pos.lasso <- sort(pos.lasso, decreasing = T)
neg.lasso <- sort(neg.lasso, decreasing = F)

# %%
set.seed(12345)
res.ridge <- cv.glmnet(X, Y, family = 'binomial', alpha = 0,
                       nfolds = 4, type.measure = 'class')
coef.ridge <- coef(res.ridge, s = 'lambda.min')[,1]
pos.ridge <- coef.ridge[coef.ridge > 0]
neg.ridge <- coef.ridge[coef.ridge < 0]
pos.ridge <- sort(pos.ridge, decreasing = T)
neg.ridge <- sort(neg.ridge, decreasing = F)

# %%
set.seed(12345)
res.elastic <- cv.glmnet(X, Y, family = 'binomial', alpha = .5,
                         nfolds = 4, type.measure = 'class')
coef.elastic <- coef(res.elastic, s = 'lambda.min')[,1]
pos.elastic <- coef.elastic[coef.elastic > 0]
neg.elastic <- coef.elastic[coef.elastic < 0]
pos.elastic <- sort(pos.elastic, decreasing = T)
neg.elastic <- sort(neg.elastic, decreasing = F)

# %%
data.test <- read.csv('tablet2014_test.csv', stringsAsFactors = F, encoding="UTF-8")

# %%
head(data.test,2)
# Out:
#        X              Title        Author       ReviewID
# 1 118530   do not reccomend   April Tyler R3GRP77KRB556H
# 2  49108 Very poor product! YVONNE BOWDEN R27E8KSLJMUQZV
#                                                                                                                                                                                                                                                                                                               Texts
# 1                                                                                                                                                                           Did not meet expectations.  Slow did not work well with wi-fi at all. Slow downloads, games, apps....was returned day after Christmas:(
# 2 I would advise you not purchase this product.  I bought three of them for my grandchildren, and they are all a problem.  The screen blacks out, chargers don't work, and if you do get it charged, it lasts for maybe 45 minutes.  If it was jus one of them, maybe just a defective item, but all three are bad.
#       YMD Sentiment
# 1  1/2/14         0
# 2 1/16/14         0

# %%
corpus <- Corpus(VectorSource(data.test$Texts))

# %%
Terms(dtm)
# Out:
#    [1] "african"                      "calls"
#    [3] "disable"                      "incoming"
#    [5] "money"                        "outgoing"
#    [7] "phone"                        "settings"
#    [9] "south"                        "text"
#   [11] "waste"                        "work"
#   [13] "bought"                       "completely"
#   [15] "decision"                     "despiste"
#   [17] "iphone"                       "problem"
#   [19] "product"                      "recieved"
#   [21] "satisfied"                    "solve"
#   [23] "unlocked"                     "batteries"
#   [25] "boy"                          "brand"
#   [27] "daughter"                     "eats"
#   [29] "faster"                       "model"
#   [31] "thought"                      "wrong"
#   [33] "att"                          "bad"
#   [35] "card"                         "good"
#   [37] "kind"                         "reviews"
#   [39] "sim"                          "special"
#   [41] "wondering"                    "days"
#   [43] "stopped"                      "virus"
#   [45] "working"                      "appears"
#   [47] "complete"                     "delays"
#   [49] "downs"                        "error"
#   [51] "hate"                         "issue"
#   [53] "love"                         "manufacturers"
#   [55] "network"                      "phones"
#   [57] "prone"                        "samsung"
#   [59] "shut"                         "sprint"
#   [61] "varies"                       "verizon"
#   [63] "activate"                     "activated"
#   [65] "call"                         "find"
#   [67] "great"                        "hope"
#   [69] "looked"                       "lost"
#   [71] "process"                      "received"
#   [73] "return"                       "shape"
#   [75] "stolen"                       "bluetooth"
#   [77] "broad"                        "carma"
#   [79] "doesn"                        "drop"
#   [81] "key"                          "locked"
#   [83] "volume"                       "average"
#   [85] "back"                         "bill"
#   [87] "camera"                       "cheaper"
#   [89] "data"                         "date"
#   [91] "easier"                       "features"
#   [93] "fun"                          "learned"
#   [95] "lesson"                       "longer"
#   [97] "map"                          "mention"
#   [99] "mobile"                       "month"
#  [101] "months"                       "nice"
#  [103] "paid"                         "price"
#  [105] "purchase"                     "read"
#  [107] "reviewers"                    "stop"
#  [109] "system"                       "turn"
#  [111] "turned"                       "virgin"
#  [113] "warranty"                     "amazon"
#  [115] "big"                          "called"
#  [117] "experts"                      "give"
#  [119] "htc"                          "itry"
#  [121] "listen"                       "personalize"
#  [123] "policy"                       "preset"
#  [125] "problems"                     "radio"
#  [127] "replace"                      "reported"
#  [129] "ring"                         "saved"
#  [131] "sends"                        "solution"
#  [133] "song"                         "stations"
#  [135] "thing"                        "tone"
#  [137] "update"                       "updated"
#  [139] "won"                          "wont"
#  [141] "workable"                     "automatically"
#  [143] "bit"                          "box"
#  [145] "charged"                      "happen"
#  [147] "opened"                       "put"
#  [149] "seconds"                      "stay"
#  [151] "worked"                       "apps"
#  [153] "awful"                        "borrowing"
#  [155] "clear"                        "enjoy"
#  [157] "friends"                      "person"
#  [159] "pictures"                     "savvy"
#  [161] "tech"                         "tips"
#  [163] "tricks"                       "alot"
#  [165] "book"                         "couldn"
#  [167] "experience"                   "figure"
#  [169] "found"                        "frustrating"
#  [171] "minder"                       "minute"
#  [173] "online"                       "prime"
#  [175] "purchased"                    "sending"
#  [177] "set"                          "sound"
#  [179] "version"                      "bring"
#  [181] "long"                         "message"
#  [183] "order"                        "time"
#  [185] "vidpysuyut"                   "advertised"
#  [187] "gsm"                          "make"
#  [189] "mms"                          "ordered"
#  [191] "perfect"                      "seller"
#  [193] "texting"                      "cheap"
#  [195] "deal"                         "family"
#  [197] "hated"                        "horrible"
#  [199] "service"                      "slow"
#  [201] "wifi"                         "boyfriend"
#  [203] "chinese"                      "clone"
#  [205] "company"                      "delivered"
#  [207] "fear"                         "gift"
#  [209] "notice"                       "original"
#  [211] "yesterday"                    "hook"
#  [213] "metro"                        "number"
#  [215] "wasting"                      "cell"
#  [217] "defect"                       "equipment"
#  [219] "expectations"                 "failure"
#  [221] "fulfilled"                    "management"
#  [223] "manufacturing"                "memory"
#  [225] "models"                       "present"
#  [227] "recommend"                    "accept"
#  [229] "anymore"                      "attempt"
#  [231] "badly"                        "battery"
#  [233] "charge"                       "charging"
#  [235] "concerned"                    "couple"
#  [237] "didn"                         "digicel"
#  [239] "disappointed"                 "ebay"
#  [241] "economy"                      "fix"
#  [243] "freeze"                       "hard"
#  [245] "hopeful"                      "hoping"
#  [247] "hour"                         "hours"
#  [249] "hurt"                         "initial"
#  [251] "jamaica"                      "left"
#  [253] "liable"                       "living"
#  [255] "makes"                        "minutes"
#  [257] "moment"                       "mother"
#  [259] "offered"                      "office"
#  [261] "overheat"                     "part"
#  [263] "parts"                        "presently"
#  [265] "products"                     "promises"
#  [267] "purchasing"                   "quality"
#  [269] "rating"                       "recently"
#  [271] "reflects"                     "refused"
#  [273] "remained"                     "replacement"
#  [275] "returned"                     "sell"
#  [277] "services"                     "show"
#  [279] "star"                         "started"
#  [281] "stated"                       "stuck"
#  [283] "takes"                        "taking"
#  [285] "tested"                       "unfortunate"
#  [287] "usa"                          "vacation"
#  [289] "website"                      "year"
#  [291] "callers"                      "frequently"
#  [293] "hear"                         "made"
#  [295] "poor"                         "reset"
#  [297] "speaker"                      "device"
#  [299] "intuitively"                  "obvious"
#  [301] "prior"                        "sheet"
#  [303] "smartphone"                   "asked"
#  [305] "case"                         "cheating"
#  [307] "court"                        "raise"
#  [309] "apple"                        "guaranty"
#  [311] "loss"                         "mic"
#  [313] "sold"                         "store"
#  [315] "told"                         "works"
#  [317] "buy"                          "damaged"
#  [319] "don"                          "expected"
#  [321] "hair"                         "honor"
#  [323] "indicators"                   "precautions"
#  [325] "properties"                   "pulling"
#  [327] "repair"                       "resistant"
#  [329] "run"                          "sealed"
#  [331] "sony"                         "spite"
#  [333] "washed"                       "water"
#  [335] "advised"                      "confusing"
#  [337] "existent"                     "instructions"
#  [339] "life"                         "material"
#  [341] "practically"                  "spanish"
#  [343] "niece"                        "cards"
#  [345] "couldnt"                      "didnt"
#  [347] "knew"                         "bug"
#  [349] "download"                     "forever"
#  [351] "hang"                         "load"
#  [353] "people"                       "simple"
#  [355] "smart"                        "sucks"
#  [357] "wouldn"                       "china"
#  [359] "cover"                        "pay"
#  [361] "shipping"                     "terrible"
#  [363] "basis"                        "beware"
#  [365] "blames"                       "buyer"
#  [367] "code"                         "continues"
#  [369] "dealership"                   "defective"
#  [371] "directly"                     "happy"
#  [373] "located"                      "location"
#  [375] "lock"                         "low"
#  [377] "motorola"                     "place"
#  [379] "puk"                          "responsibility"
#  [381] "support"                      "texas"
#  [383] "unlock"                       "walk"
#  [385] "chews"                        "dead"
#  [387] "describe"                     "ends"
#  [389] "full"                         "hog"
#  [391] "idle"                         "initially"
#  [393] "morning"                      "overnight"
#  [395] "owned"                        "plugged"
#  [397] "pos"                          "power"
#  [399] "unused"                       "words"
#  [401] "doesnt"                       "expesive"
#  [403] "noney"                        "broken"
#  [405] "dissapointed"                 "lit"
#  [407] "screen"                       "wouldnt"
#  [409] "biggest"                      "finally"
#  [411] "frustration"                  "half"
#  [413] "internal"                     "lack"
#  [415] "market"                       "move"
#  [417] "quit"                         "room"
#  [419] "totally"                      "turns"
#  [421] "worth"                        "certified"
#  [423] "dont"                         "folks"
#  [425] "frm"                          "gamble"
#  [427] "items"                        "learn"
#  [429] "ohterwise"                    "sellers"
#  [431] "spending"                     "total"
#  [433] "vegas"                        "youre"
#  [435] "adefect"                      "calling"
#  [437] "change"                       "coz"
#  [439] "echo"                         "fails"
#  [441] "front"                        "rear"
#  [443] "restart"                      "restore"
#  [445] "series"                       "specially"
#  [447] "stops"                        "baterry"
#  [449] "functione"                    "recieve"
#  [451] "send"                         "upset"
#  [453] "buying"                       "putting"
#  [455] "question"                     "unhappy"
#  [457] "cellphones"                   "complain"
#  [459] "day"                          "lithium"
#  [461] "loose"                        "receive"
#  [463] "start"                        "taket"
#  [465] "absolutely"                   "angle"
#  [467] "connection"                   "difficult"
#  [469] "legit"                        "respond"
#  [471] "save"                         "slowly"
#  [473] "touch"                        "trust"
#  [475] "view"                         "christmas"
#  [477] "contacting"                   "correctly"
#  [479] "discovered"                   "early"
#  [481] "email"                        "essentially"
#  [483] "guarantee"                    "informed"
#  [485] "installed"                    "january"
#  [487] "late"                         "luck"
#  [489] "mark"                         "microsd"
#  [491] "nearby"                       "recognize"
#  [493] "september"                    "talking"
#  [495] "tree"                         "arrived"
#  [497] "conformed"                    "dual"
#  [499] "properly"                     "slot"
#  [501] "stable"                       "account"
#  [503] "cancels"                      "eligible"
#  [505] "evidently"                    "expect"
#  [507] "line"                         "multiple"
#  [509] "option"                       "orders"
#  [511] "plan"                         "ran"
#  [513] "relationship"                 "resubmit"
#  [515] "review"                       "sale"
#  [517] "ship"                         "shows"
#  [519] "status"                       "upgrade"
#  [521] "verify"                       "websites"
#  [523] "wireless"                     "freezing"
#  [525] "hanging"                      "pretty"
#  [527] "authenticate"                 "bellevue"
#  [529] "components"                   "dealz"
#  [531] "form"                         "match"
#  [533] "numbers"                      "serial"
#  [535] "serviceable"                  "software"
#  [537] "suspicious"                   "thousand"
#  [539] "actions"                      "locks"
#  [541] "returning"                    "sitting"
#  [543] "table"                        "trouble"
#  [545] "activitate"                   "altered"
#  [547] "owner"                        "unable"
#  [549] "apk"                          "cold"
#  [551] "consistently"                 "contract"
#  [553] "current"                      "defeats"
#  [555] "downloaded"                   "end"
#  [557] "fail"                         "files"
#  [559] "flash"                        "flaws"
#  [561] "forsaken"                     "god"
#  [563] "hardware"                     "higher"
#  [565] "idea"                         "include"
#  [567] "information"                  "install"
#  [569] "larger"                       "legitimate"
#  [571] "length"                       "markup"
#  [573] "mere"                         "merit"
#  [575] "messages"                     "micro"
#  [577] "occasionally"                 "occurs"
#  [579] "point"                        "previous"
#  [581] "proceeds"                     "purpose"
#  [583] "rate"                         "reason"
#  [585] "receiving"                    "responsive"
#  [587] "restarts"                     "simply"
#  [589] "skype"                        "small"
#  [591] "stars"                        "storage"
#  [593] "suck"                         "temperatures"
#  [595] "usage"                        "worse"
#  [597] "answered"                     "dec"
#  [599] "emailed"                      "area"
#  [601] "checked"                      "codes"
#  [603] "compatible"                   "list"
#  [605] "listened"                     "posted"
#  [607] "cellphone"                    "changed"
#  [609] "junk"                         "piece"
#  [611] "selling"                      "twicw"
#  [613] "chinesse"                     "extranged"
#  [615] "gps"                          "hasslefreecell"
#  [617] "nfc"                          "rooted"
#  [619] "expecting"                    "extra"
#  [621] "fixed"                        "inside"
#  [623] "lot"                          "open"
#  [625] "venezuela"                    "wich"
#  [627] "cam"                          "dollar"
#  [629] "galaxy"                       "trash"
#  [631] "utter"                        "caller"
#  [633] "garbage"                      "lousy"
#  [635] "speak"                        "ahhhh"
#  [637] "degrades"                     "fourth"
#  [639] "reboots"                      "results"
#  [641] "screeches"                    "shuts"
#  [643] "voice"                        "ago"
#  [645] "allover"                      "answer"
#  [647] "background"                   "candy"
#  [649] "charger"                      "contact"
#  [651] "crush"                        "damage"
#  [653] "default"                      "defected"
#  [655] "downloads"                    "drains"
#  [657] "facebook"                     "instance"
#  [659] "language"                     "manual"
#  [661] "noise"                        "noticed"
#  [663] "operate"                      "ordering"
#  [665] "placing"                      "programmed"
#  [667] "questions"                    "refund"
#  [669] "snapchat"                     "times"
#  [671] "tip"                          "user"
#  [673] "weeks"                        "attention"
#  [675] "comment"                      "wasted"
#  [677] "accepting"                    "earn"
#  [679] "port"                         "sloppy"
#  [681] "bounced"                      "button"
#  [683] "claimed"                      "connect"
#  [685] "connected"                    "contacts"
#  [687] "difficulty"                   "hooking"
#  [689] "inactive"                     "internet"
#  [691] "net"                          "paying"
#  [693] "pressed"                      "responded"
#  [695] "side"                         "sucked"
#  [697] "switch"                       "transfer"
#  [699] "wierdly"                      "depressing"
#  [701] "dollars"                      "madfe"
#  [703] "spent"                        "straight"
#  [705] "talk"                         "conversation"
#  [707] "country"                      "cpu"
#  [709] "establish"                    "interference"
#  [711] "lcd"                          "performance"
#  [713] "talkie"                       "walkie"
#  [715] "advertise"                    "advertising"
#  [717] "business"                     "crooks"
#  [719] "false"                        "fee"
#  [721] "opinion"                      "prepaid"
#  [723] "require"                      "stock"
#  [725] "description"                  "highly"
#  [727] "unsatisfied"                  "bay"
#  [729] "belongs"                      "bottom"
#  [731] "free"                         "lgc"
#  [733] "prefer"                       "dell"
#  [735] "faulty"                       "hangs"
#  [737] "broke"                        "condition"
#  [739] "dirty"                        "wall"
#  [741] "wasnt"                        "cord"
#  [743] "gave"                         "hold"
#  [745] "possibly"                     "refurbished"
#  [747] "showed"                       "strive"
#  [749] "turning"                      "wife"
#  [751] "years"                        "barely"
#  [753] "blury"                        "moves"
#  [755] "photos"                       "advertises"
#  [757] "basically"                    "places"
#  [759] "player"                       "veryy"
#  [761] "angry"                        "animal"
#  [763] "annoying"                     "apparently"
#  [765] "care"                         "constantly"
#  [767] "csi"                          "dropped"
#  [769] "entire"                       "feature"
#  [771] "flipping"                     "giving"
#  [773] "hand"                         "headphone"
#  [775] "headphones"                   "house"
#  [777] "idiots"                       "irrationally"
#  [779] "jack"                         "listening"
#  [781] "machine"                      "men"
#  [783] "pinky"                        "pocket"
#  [785] "prevents"                     "realize"
#  [787] "securely"                     "shorten"
#  [789] "smell"                        "stabilize"
#  [791] "sticking"                     "tangled"
#  [793] "upside"                       "week"
#  [795] "app"                          "darkens"
#  [797] "emails"                       "flickers"
#  [799] "guess"                        "haven"
#  [801] "ive"                          "lie"
#  [803] "plastic"                      "push"
#  [805] "randomly"                     "select"
#  [807] "worst"                        "android"
#  [809] "blocky"                       "child"
#  [811] "close"                        "compared"
#  [813] "feels"                        "firstly"
#  [815] "functionality"                "hit"
#  [817] "iosthe"                       "knockoffs"
#  [819] "lacking"                      "microsoft"
#  [821] "microsofts"                   "miss"
#  [823] "party"                        "plain"
#  [825] "playing"                      "saddled"
#  [827] "sadly"                        "selection"
#  [829] "stupid"                       "tiles"
#  [831] "twitter"                      "useless"
#  [833] "whatsapp"                     "yelp"
#  [835] "experienced"                  "gimmic"
#  [837] "loan"                         "package"
#  [839] "unprofessional"               "waited"
#  [841] "wasn"                         "asap"
#  [843] "failed"                       "label"
#  [845] "wait"                         "wanted"
#  [847] "beautiful"                    "fact"
#  [849] "impossible"                   "inaccurate"
#  [851] "phantom"                      "response"
#  [853] "touches"                      "touchscreen"
#  [855] "dontthink"                    "lemon"
#  [857] "picture"                      "white"
#  [859] "factory"                      "friend"
#  [861] "shutting"                     "messing"
#  [863] "similar"                      "important"
#  [865] "issues"                       "lots"
#  [867] "note"                         "replaced"
#  [869] "slowest"                      "speed"
#  [871] "trree"                        "versions"
#  [873] "activating"                   "blank"
#  [875] "blink"                        "dies"
#  [877] "opening"                      "previously"
#  [879] "scam"                         "cameras"
#  [881] "capable"                      "cellular"
#  [883] "cool"                         "dedicated"
#  [885] "hspa"                         "kludge"
#  [887] "predates"                     "random"
#  [889] "ready"                        "sea"
#  [891] "suppose"                      "symbian"
#  [893] "felt"                         "sand"
#  [895] "scraches"                     "making"
#  [897] "regret"                       "buzz"
#  [899] "constant"                     "happening"
#  [901] "hears"                        "changing"
#  [903] "check"                        "interior"
#  [905] "prepared"                     "suddenly"
#  [907] "supplier"                     "word"
#  [909] "duplicated"                   "achieve"
#  [911] "bother"                       "decent"
#  [913] "enemy"                        "horrid"
#  [915] "joke"                         "laptop"
#  [917] "mode"                         "noteworthy"
#  [919] "reliable"                     "remember"
#  [921] "standby"                      "stick"
#  [923] "tvs"                          "boot"
#  [925] "cannibalize"                  "loop"
#  [927] "mexico"                       "provide"
#  [929] "release"                      "amazom"
#  [931] "beating"                      "buttons"
#  [933] "corning"                      "cracked"
#  [935] "droid"                        "glass"
#  [937] "gorilla"                      "loved"
#  [939] "screan"                       "ultra"
#  [941] "bloatware"                    "difference"
#  [943] "exchanging"                   "international"
#  [945] "mine"                         "sgh"
#  [947] "therefor"                     "updates"
#  [949] "allowed"                      "customs"
#  [951] "destroyed"                    "knowing"
#  [953] "watch"                        "wrist"
#  [955] "bloody"                       "boris"
#  [957] "chrips"                       "countries"
#  [959] "dial"                         "fine"
#  [961] "glad"                         "guysi"
#  [963] "nither"                       "peple"
#  [965] "perfectly"                    "phoning"
#  [967] "puprpose"                     "situation"
#  [969] "speaking"                     "supported"
#  [971] "downloadcamera"               "games"
#  [973] "glitchesbad"                  "graphics"
#  [975] "horriblein"                   "horriblephone"
#  [977] "suckssome"                    "voices"
#  [979] "drops"                        "middle"
#  [981] "carrier"                      "ability"
#  [983] "apn"                          "applications"
#  [985] "begs"                         "blackberry"
#  [987] "blows"                        "break"
#  [989] "calculator"                   "chore"
#  [991] "compare"                      "continue"
#  [993] "disappointment"               "doug"
#  [995] "downhill"                     "drive"
#  [997] "ears"                         "easily"
#  [999] "finished"                     "goodbye"
# [1001] "heads"                        "historic"
# [1003] "home"                         "interface"
# [1005] "itll"                         "keyboards"
# [1007] "mad"                          "main"
# [1009] "nag"                          "past"
# [1011] "percentage"                   "physical"
# [1013] "press"                        "quickly"
# [1015] "qwerty"                       "ridiculed"
# [1017] "smaller"                      "specific"
# [1019] "steam"                        "sumatra"
# [1021] "swipe"                        "tedious"
# [1023] "tiny"                         "upwards"
# [1025] "visiting"                     "webpage"
# [1027] "window"                       "wiped"
# [1029] "grrrrrrrrrrr"                 "freezes"
# [1031] "shocked"                      "speechless"
# [1033] "compact"                      "crap"
# [1035] "excuse"                       "managing"
# [1037] "minuets"                      "music"
# [1039] "notification"                 "real"
# [1041] "rings"                        "ringtone"
# [1043] "school"                       "thick"
# [1045] "till"                         "waiting"
# [1047] "wallpapers"                   "announces"
# [1049] "anuncia"                      "aparte"
# [1051] "como"                         "equipos"
# [1053] "estan"                        "fault"
# [1055] "llamas"                       "nuevos"
# [1057] "remanofacturados"             "son"
# [1059] "vende"                        "짹ados"
# [1061] "cost"                         "grrr"
# [1063] "item"                         "needless"
# [1065] "ups"                          "evil"
# [1067] "grab"                         "plate"
# [1069] "signal"                       "bloquea"
# [1071] "celular"                      "crashes"
# [1073] "english"                      "este"
# [1075] "funciona"                     "idioma"
# [1077] "ingles"                       "injustificadamentethis"
# [1079] "malo"                         "mara"
# [1081] "pasa"                         "pass"
# [1083] "terriblemente"                "terribly"
# [1085] "unreasonably"                 "짹al"
# [1087] "쩌nico"                       "agree"
# [1089] "badplease"                    "butts"
# [1091] "camperthis"                   "charges"
# [1093] "dang"                         "fing"
# [1095] "idk"                          "kyocera"
# [1097] "nowi"                         "optimus"
# [1099] "phonebattery"                 "phonei"
# [1101] "phonemanthis"                 "pleased"
# [1103] "pleaseread"                   "sucksthis"
# [1105] "thisi"                        "traded"
# [1107] "wat"                          "workdont"
# [1109] "accessibility"                "click"
# [1111] "closed"                       "top"
# [1113] "customer"                     "literally"
# [1115] "abruptly"                     "address"
# [1117] "bedside"                      "bucks"
# [1119] "clock"                        "cut"
# [1121] "favor"                        "glitch"
# [1123] "needed"                       "supposed"
# [1125] "weren"                        "continuing"
# [1127] "rediculous"                   "resetting"
# [1129] "canada"                       "concludes"
# [1131] "moved"                        "pops"
# [1133] "listed"                       "listings"
# [1135] "duties"                       "experiencing"
# [1137] "loosing"                      "periods"
# [1139] "fraudulent"                   "immediately"
# [1141] "overheating"                  "running"
# [1143] "cheek"                        "hits"
# [1145] "programs"                     "accessories"
# [1147] "availability"                 "blu"
# [1149] "breed"                        "contacted"
# [1151] "evident"                      "glance"
# [1153] "manufacturer"                 "reimbursement"
# [1155] "searching"                    "seek"
# [1157] "sucking"                      "town"
# [1159] "blow"                         "control"
# [1161] "reccomend"                    "branch"
# [1163] "calderon"                     "centura"
# [1165] "claims"                       "executive"
# [1167] "karen"                        "lesser"
# [1169] "miami"                        "offer"
# [1171] "optioned"                     "prl"
# [1173] "proclaim"                     "recall"
# [1175] "refuse"                       "resolved"
# [1177] "talks"                        "technical"
# [1179] "tracfone"                     "cat"
# [1181] "clean"                        "concrete"
# [1183] "david"                        "design"
# [1185] "disposable"                   "door"
# [1187] "floor"                        "guy"
# [1189] "mail"                         "named"
# [1191] "referred"                     "scratch"
# [1193] "screws"                       "sink"
# [1195] "sweaty"                       "tabs"
# [1197] "bogus"                        "colorado"
# [1199] "cricket"                      "deals"
# [1201] "deceit"                       "flashed"
# [1203] "grandson"                     "job"
# [1205] "kansas"                       "lied"
# [1207] "live"                         "purposely"
# [1209] "sarcasm"                      "specifically"
# [1211] "surely"                       "type"
# [1213] "begin"                        "borrow"
# [1215] "car"                          "death"
# [1217] "discharges"                   "emergency"
# [1219] "fancy"                        "gbmy"
# [1221] "husband"                      "idleness"
# [1223] "kidding"                      "leave"
# [1225] "matter"                       "means"
# [1227] "moto"                         "night"
# [1229] "percent"                      "perform"
# [1231] "period"                       "plug"
# [1233] "pushed"                       "report"
# [1235] "rest"                         "search"
# [1237] "secret"                       "stranded"
# [1239] "unreliable"                   "ata"
# [1241] "pieces"                       "sells"
# [1243] "worki"                        "brought"
# [1245] "deserves"                     "discription"
# [1247] "greater"                      "networks"
# [1249] "penny"                        "puts"
# [1251] "reply"                        "searches"
# [1253] "sister"                       "teenage"
# [1255] "tmobile"                      "brazil"
# [1257] "document"                     "stores"
# [1259] "girl"                         "chooses"
# [1261] "crappy"                       "fitst"
# [1263] "bday"                         "provider"
# [1265] "electronic"                   "offline"
# [1267] "applied"                      "assume"
# [1269] "batterys"                     "caution"
# [1271] "disapointed"                  "fien"
# [1273] "normal"                       "stickers"
# [1275] "threw"                        "wind"
# [1277] "bars"                         "audio"
# [1279] "beats"                        "interested"
# [1281] "mistake"                      "processing"
# [1283] "slapped"                      "due"
# [1285] "goodphone"                    "moregave"
# [1287] "mymoney"                      "seas"
# [1289] "toits"                        "allot"
# [1291] "avalon"                       "believed"
# [1293] "bells"                        "catalina"
# [1295] "causing"                      "cheesy"
# [1297] "die"                          "distorted"
# [1299] "forward"                      "highest"
# [1301] "island"                       "keypad"
# [1303] "missed"                       "mom"
# [1305] "ocean"                        "older"
# [1307] "par"                          "pick"
# [1309] "realized"                     "reception"
# [1311] "satellite"                    "single"
# [1313] "slide"                        "sounds"
# [1315] "sparq"                        "throw"
# [1317] "topside"                      "video"
# [1319] "walked"                       "whistles"
# [1321] "attached"                     "coming"
# [1323] "holds"                        "panel"
# [1325] "snap"                         "alternative"
# [1327] "display"                      "heated"
# [1329] "light"                        "spend"
# [1331] "dose"                         "dosent"
# [1333] "exact"                        "interrupted"
# [1335] "kona"                         "page"
# [1337] "surf"                         "surfing"
# [1339] "web"                          "chipped"
# [1341] "count"                        "dents"
# [1343] "durable"                      "hasn"
# [1345] "land"                         "paint"
# [1347] "riddled"                      "space"
# [1349] "sucker"                       "unplugged"
# [1351] "acted"                        "suggestions"
# [1353] "dark"                         "aka"
# [1355] "blocked"                      "buts"
# [1357] "carries"                      "computer"
# [1359] "connections"                  "conswhat"
# [1361] "costs"                        "devices"
# [1363] "forget"                       "google"
# [1365] "iii"                          "includes"
# [1367] "including"                    "loud"
# [1369] "movie"                        "paranoid"
# [1371] "passwords"                    "portable"
# [1373] "pros"                         "public"
# [1375] "rarely"                       "recognized"
# [1377] "reflection"                   "repeat"
# [1379] "savings"                      "science"
# [1381] "security"                     "starts"
# [1383] "states"                       "studied"
# [1385] "surveillance"                 "united"
# [1387] "usb"                          "warns"
# [1389] "watching"                     "stil"
# ...
# [6447] "crank"                        "cyclone"
# [6449] "designs"                      "disks"
# [6451] "docs"                         "drainage"
# [6453] "driven"                       "earth"
# [6455] "evolutionary"                 "expandability"
# [6457] "experimented"                 "ext"
# [6459] "fitness"                      "garmin"
# [6461] "hasa"                         "host"
# [6463] "hosts"                        "hve"
# [6465] "infrared"                     "intl"
# [6467] "ironed"                       "iterated"
# [6469] "krait"                        "linkedin"
# [6471] "maturity"                     "mileage"
# [6473] "mindcamera"                   "misc"
# [6475] "moon"                         "moot"
# [6477] "msm"                          "nailing"
# [6479] "nature"                       "navigon"
# [6481] "ndisputed"                    "obsoletion"
# [6483] "offices"                      "oily"
# [6485] "perforated"                   "plethora"
# [6487] "podcasts"                     "preview"
# [6489] "prominently"                  "receivers"
# [6491] "regimen"                      "reputed"
# [6493] "sample"                       "sar"
# [6495] "sizes"                        "sophisticated"
# [6497] "space\xe2\u0080\xb0"          "specifics"
# [6499] "stats"                        "streamer"
# [6501] "stunning"                     "subsequently"
# [6503] "subsonic"                     "suggestion"
# [6505] "syndrome"                     "tactile"
# [6507] "tapatalk"                     "themes"
# [6509] "tom"                          "tweetcaster"
# [6511] "twit"                         "underrated"
# [6513] "upto"                         "variants"
# [6515] "voiceask"                     "walking"
# [6517] "graphically"                  "lightness"
# [6519] "ailments"                     "arthritis"
# [6521] "degeneration"                 "inlays"
# [6523] "macular"                      "microcell"
# [6525] "thous"                        "tones"
# [6527] "portion"                      "stylish"
# [6529] "tho"                          "antenna"
# [6531] "friedman"                     "gregg"
# [6533] "phonethough"                  "hectic"
# [6535] "spells"                       "workday"
# [6537] "est"                          "study"
# [6539] "conducts"                     "courteous"
# [6541] "resell"                       "compliments"
# [6543] "inevitable"                   "valuable"
# [6545] "ace"                          "beginners"
# [6547] "cosmetic"                     "seamlessly"
# [6549] "bless"                        "joy"
# [6551] "bean"                         "gpsnegative"
# [6553] "jelly"                        "okim"
# [6555] "whould"                       "kindle"
# [6557] "planning"                     "sporadic"
# [6559] "promissed"                    "sat"
# [6561] "anctipated"                   "repacement"
# [6563] "comapnies"                    "itime"
# [6565] "leek"                         "overal"
# [6567] "reseaching"                   "sinse"
# [6569] "sumsung"                      "conditionloads"
# [6571] "fastpictures"                 "greati"
# [6573] "hondurasperfect"              "assigned"
# [6575] "hurts"                        "medley"
# [6577] "comunicate"                   "nicelly"
# [6579] "effortless"                   "login"
# [6581] "geared"                       "mixed"
# [6583] "nifty"                        "inquiring"
# [6585] "motorolo"                     "risky"
# [6587] "classic"                      "confidence"
# [6589] "gents"                        "richness"
# [6591] "argentina"                    "lags"
# [6593] "smarttalk"                    "desing"
# [6595] "agitate"                      "hesitated"
# [6597] "planwhile"                    "disenchanted"
# [6599] "algo"                         "cancelar"
# [6601] "cantidad"                     "considerable"
# [6603] "costo"                        "deber"
# [6605] "desbloqueado"                 "desbloqueo"
# [6607] "fue"                          "justo"
# [6609] "ofertado"                     "ofertar"
# [6611] "parece"                       "parte"
# [6613] "recibido"                     "reembolsarme"
# [6615] "reimburse"                    "tuve"
# [6617] "htcdev"                       "gusta"
# [6619] "worksto"                      "batts"
# [6621] "finishing"                    "rates"
# [6623] "looksdecent"                  "priceunless"
# [6625] "upmid"                        "androids"
# [6627] "unbelievable"                 "utility"
# [6629] "첨책"                         "perfec"
# [6631] "selfie"                       "tobago"
# [6633] "adds"                         "audiothis"
# [6635] "batterysince"                 "behave"
# [6637] "behaviors"                    "benchmarks"
# [6639] "brights"                      "camerathis"
# [6641] "complains"                    "conclude"
# [6643] "conclusionthe"                "consequences"
# [6645] "consideration"                "deeper"
# [6647] "designthe"                    "displays"
# [6649] "equation"                     "executes"
# [6651] "fitting"                      "food"
# [6653] "frontal"                      "gains"
# [6655] "heaviest"                     "hipster"
# [6657] "lowest"                       "miscellaneoussomething"
# [6659] "modify"                       "optimization"
# [6661] "patterns"                     "personalization"
# [6663] "privileges"                   "prolly"
# [6665] "restricted"                   "resume"
# [6667] "sacrifices"                   "sanpdragon"
# [6669] "screenshots"                  "screenthe"
# [6671] "softwarehtc"                  "solved"
# [6673] "topic"                        "tricky"
# [6675] "ufocus"                       "uncomfortable"
# [6677] "interest"                     "batery"
# [6679] "migrating"                    "intensely"
# [6681] "venezuelan"                   "cheapest"
# [6683] "awesomely"                    "ice"
# [6685] "thinner"                      "motto"
# [6687] "rejecting"                    "sizeand"
# [6689] "uncommon"                     "commitment"
# [6691] "communicated"                 "reliability"
# [6693] "bud"                          "evrything"
# [6695] "constructed"                  "visual"
# [6697] "booster"                      "adn"
# [6699] "comercial"                    "extraordinary"
# [6701] "presentation"                 "promise"
# [6703] "todo"                         "decently"
# [6705] "enlarging"                    "handed"
# [6707] "phtablet"                     "toilet"
# [6709] "intending"                    "rules"
# [6711] "adapted"                      "community"
# [6713] "itwill"                       "mobilei"
# [6715] "osmmmm"                       "superbbbb"
# [6717] "challenged"                   "flips"
# [6719] "beatiful"                     "ciudad"
# [6721] "desde"                        "saludos"
# [6723] "powerfull"                    "amozon"
# [6725] "molested"                     "tailwind"
# [6727] "unrivaled"                    "batterly"
# [6729] "brighter"                     "overlays"
# [6731] "strings"                      "uninstalled"
# [6733] "amps"                         "aperture"
# [6735] "chamber"                      "ecstatic"
# [6737] "excessively"                  "focusing"
# [6739] "gathering"                    "micrometers"
# [6741] "muilti"                       "passion"
# [6743] "pasted"                       "portability"
# [6745] "sports"                       "tracks"
# [6747] "hurry"                        "takeover"
# [6749] "timme"                        "wit"
# [6751] "daugther"                     "diamond"
# [6753] "sparkles"                     "evolved"
# [6755] "fasination"                   "hammer"
# [6757] "niffty"                       "smash"
# [6759] "internets"                    "ins"
# [6761] "maxhernandes"                 "movilnet"
# [6763] "requesting"                   "venzuela"
# [6765] "aluminium"                    "cpuit"
# [6767] "criteria"                     "gravity"
# [6769] "iosit"                        "iphonefinally"
# [6771] "maine"                        "primeit"
# [6773] "ramit"                        "rural"
# [6775] "toughthe"                     "unlockedi"
# [6777] "drew"                         "goodreads"
# [6779] "heft"                         "illustra"
# [6781] "newststation"                 "amaze"
# [6783] "professionals"                "regarded"
# [6785] "speced"                       "bout"
# [6787] "sooof"                        "takin"
# [6789] "excelllent"                   "junkies"
# [6791] "trustworthiness"              "cliff"
# [6793] "finest"                       "inferior"
# [6795] "collect"                      "knowledgeable"
# [6797] "ofdifferent"                  "recharging"
# [6799] "realy"                        "corrections"
# [6801] "easeir"                       "eay"
# [6803] "prev"                         "produces"
# [6805] "deff"                         "adept"
# [6807] "acclaimed"                    "act"
# [6809] "animated"                     "creator"
# [6811] "displaymate"                  "ergonomically"
# [6813] "gif"                          "intend"
# [6815] "navigating"                   "outputs"
# [6817] "panorama"                     "pentax"
# [6819] "praised"                      "remotely"
# [6821] "sequence"                     "spherical"
# [6823] "surround"                     "universal"
# [6825] "viewer"                       "bueno"
# [6827] "agil"                         "agile"
# [6829] "alta"                         "ampliamente"
# [6831] "gama"                         "prestaciones"
# [6833] "rapido"                       "todos"
# [6835] "veloz"                        "abd"
# [6837] "anazon"                       "sonetines"
# [6839] "twenty"                       "defenitely"
# [6841] "recomended"                   "sturdily"
# [6843] "invisishield"                 "boosters"
# [6845] "elegance"                     "hdmi"
# [6847] "minimize"                     "miracast"
# [6849] "misunderstood"                "freezy"
# [6851] "shocking"                     "repent"
# [6853] "rain"                         "withstood"
# [6855] "drums"                        "sounding"
# [6857] "bandas"                       "liberado"
# [6859] "telofono"                     "gem"
# [6861] "peruse"                       "qualms"
# [6863] "endless"                      "jotting"
# [6865] "centro"                       "adapter\xe2\u0080◈\x81"
# [6867] "avoids"                       "collection"
# [6869] "onei"                         "ports"
# [6871] "quintupled"                   "receptacle"
# [6873] "simultaneously\xe2\u0080\xb0" "station\xe2\u0080\xb0"
# [6875] "acquainted"                   "breath"
# [6877] "browse"                       "viber"
# [6879] "whitedr"                      "arirang"
# [6881] "bumper"                       "killed"
# [6883] "swapping"                     "types"
# [6885] "underpowered"                 "malawi"
# [6887] "afffordable"                  "phiojnes"
# [6889] "temperature"                  "deliverance"
# [6891] "qualitative"                  "fingertips"
# [6893] "transfered"                   "confort"
# [6895] "bbs"                          "robust"
# [6897] "lovely"                       "nooooo"
# [6899] "ilove"                        "prox"
# [6901] "noproblems"                   "phoneand"
# [6903] "phoneslike"                   "pack"
# [6905] "caboose"                      "kickstand"
# [6907] "pointed"                      "savy"
# [6909] "sorted"                       "tilt"

# %%
dtm.test <- DocumentTermMatrix(corpus,
                               control = list(tolower = T,
                                              removePunctuation = T,
                                              removeNumbers = T,
                                              stopwords = stopwords("SMART"),
                                              weighting = weightTfIdf,
                                              dictionary = Terms(dtm)))
# Out:
# Error in tolower(txt): 'utf8towcs'내에 입력 'its a good good good good good product,sometimes little bit stuck<95>_<ce>all in all it's a good good product any more'이 잘못되었습니다
# Traceback:
#
# 1. DocumentTermMatrix(corpus, control = list(tolower = T, removePunctuation = T,
#  .     removeNumbers = T, stopwords = stopwords("SMART"), weighting = weightTfIdf,
#  .     dictionary = Terms(dtm)))
# 2. t(TermDocumentMatrix(x, control))
# 3. TermDocumentMatrix(x, control)
# 4. TermDocumentMatrix.SimpleCorpus(x, control)
# 5. tolower(txt)
