# %% [markdown]
# # 1. Table Data

# %%
library(tm)
library(tm.plugin.sentiment)
library(glmnet)

# %% [markdown]
# ## 총 정리 및 복습.

# %%
mobile <- read.csv("mobile2014.csv", stringsAsFactors = F, encoding="UTF-8")

# %%
corpus <- Corpus(VectorSource(mobile$Texts))

# %%
dtm <- DocumentTermMatrix(corpus,
                          control = list(tolower = T,
                                         removePunctuation = T,
                                         removeNumbers = T,
                                         wordLengths=c(2, 10),
                                         stopwords = stopwords("SMART"),
                                         weighting = weightTfIdf))
# Out:
# Warning message:
# In weighting(x): empty document(s): 534 1585

# %%
my.stopwords <- c(stopwords("SMART"), "aaa") # stopwords에 추가.

# %%
my.stopwords[1:10]
# Out:
#  [1] "a"           "a's"         "able"        "about"       "above"
#  [6] "according"   "accordingly" "across"      "actually"    "after"

# %%
X <- as.matrix(dtm)
Y <- mobile$Sentiment

# %%
res.lm <- glmnet(X, Y, family = 'binomial', lambda = 0)
coef.lm <- coef(res.lm)[,1]

pos.lm <- coef.lm[coef.lm > 0]
neg.lm <- coef.lm[coef.lm < 0]

pos.lm <- sort(pos.lm, decreasing = T)
neg.lm <- sort(neg.lm, decreasing = F)

# %%
res.lasso <- glmnet(X, Y, family = 'binomial', alpha = 1)
set.seed(12345)
res.lasso <- cv.glmnet(X, Y, family = 'binomial', alpha = 1,
                       nfolds = 4, type.measure = 'class') # 최적의 람다값을 찾기위해서 cv.glmnet 을 사용.

# nfodls : 훈련할 학습할 데이터와 검증할 데이터를 나누는 방법을 설정 
# 몇대 몇 : nfodls = 3:! 로 나눠서 트레이닝 및 테스트

# %%
coef.lasso <- coef(res.lasso, s = 'lambda.min')[,1]
pos.lasso <- coef.lasso[coef.lasso > 0]
neg.lasso <- coef.lasso[coef.lasso < 0]
pos.lasso <- sort(pos.lasso, decreasing = T)
neg.lasso <- sort(neg.lasso, decreasing = F)

# %%
set.seed(12345)
res.ridge <- cv.glmnet(X, Y, family = 'binomial', alpha = 0,
                       nfolds = 4, type.measure = 'class')
coef.ridge <- coef(res.ridge, s = 'lambda.min')[,1]
pos.ridge <- coef.ridge[coef.ridge > 0]
neg.ridge <- coef.ridge[coef.ridge < 0]
pos.ridge <- sort(pos.ridge, decreasing = T)
neg.ridge <- sort(neg.ridge, decreasing = F)

# %%
set.seed(12345)
res.elastic <- cv.glmnet(X, Y, family = 'binomial', alpha = .5,
                         nfolds = 4, type.measure = 'class')
coef.elastic <- coef(res.elastic, s = 'lambda.min')[,1]
pos.elastic <- coef.elastic[coef.elastic > 0]
neg.elastic <- coef.elastic[coef.elastic < 0]
pos.elastic <- sort(pos.elastic, decreasing = T)
neg.elastic <- sort(neg.elastic, decreasing = F)

# %%
data.test <- read.csv('tablet2014_test.csv', stringsAsFactors = F, encoding="UTF-8")

# %%
head(data.test,2)
# Out:
#        X              Title        Author       ReviewID
# 1 118530   do not reccomend   April Tyler R3GRP77KRB556H
# 2  49108 Very poor product! YVONNE BOWDEN R27E8KSLJMUQZV
#                                                                                                                                                                                                                                                                                                               Texts
# 1                                                                                                                                                                           Did not meet expectations.  Slow did not work well with wi-fi at all. Slow downloads, games, apps....was returned day after Christmas:(
# 2 I would advise you not purchase this product.  I bought three of them for my grandchildren, and they are all a problem.  The screen blacks out, chargers don't work, and if you do get it charged, it lasts for maybe 45 minutes.  If it was jus one of them, maybe just a defective item, but all three are bad.
#       YMD Sentiment
# 1  1/2/14         0
# 2 1/16/14         0

# %%
corpus <- Corpus(VectorSource(data.test$Texts))

# %%
Terms(dtm)
# Out:
#    [1] "african"               "calls"                 "disable"
#    [4] "incoming"              "money"                 "outgoing"
#    [7] "phone"                 "settings"              "south"
#   [10] "text"                  "waste"                 "work"
#   [13] "bought"                "completely"            "decision"
#   [16] "despiste"              "iphone"                "problem"
#   [19] "product"               "recieved"              "satisfied"
#   [22] "solve"                 "unlocked"              "yo"
#   [25] "batteries"             "boy"                   "brand"
#   [28] "daughter"              "eats"                  "faster"
#   [31] "lg"                    "model"                 "thought"
#   [34] "wrong"                 "att"                   "bad"
#   [37] "card"                  "good"                  "kind"
#   [40] "reviews"               "sim"                   "special"
#   [43] "wondering"             "days"                  "stopped"
#   [46] "virus"                 "working"               "appears"
#   [49] "complete"              "delays"                "downs"
#   [52] "error"                 "hate"                  "issue"
#   [55] "love"                  "network"               "phones"
#   [58] "prone"                 "samsung"               "shut"
#   [61] "sprint"                "varies"                "verizon"
#   [64] "activate"              "activated"             "call"
#   [67] "find"                  "great"                 "hope"
#   [70] "looked"                "lost"                  "process"
#   [73] "received"              "return"                "shape"
#   [76] "stolen"                "bluetooth"             "broad"
#   [79] "carma"                 "doesn"                 "drop"
#   [82] "key"                   "locked"                "volume"
#   [85] "average"               "back"                  "bill"
#   [88] "camera"                "cheaper"               "data"
#   [91] "date"                  "easier"                "features"
#   [94] "fun"                   "learned"               "lesson"
#   [97] "ll"                    "longer"                "map"
#  [100] "mention"               "mobile"                "month"
#  [103] "months"                "nice"                  "paid"
#  [106] "price"                 "purchase"              "read"
#  [109] "reviewers"             "stop"                  "system"
#  [112] "turn"                  "turned"                "ve"
#  [115] "virgin"                "warranty"              "amazon"
#  [118] "bb"                    "big"                   "called"
#  [121] "experts"               "give"                  "htc"
#  [124] "itry"                  "listen"                "os"
#  [127] "policy"                "preset"                "problems"
#  [130] "radio"                 "replace"               "reported"
#  [133] "ring"                  "saved"                 "sends"
#  [136] "solution"              "song"                  "stations"
#  [139] "thing"                 "tone"                  "update"
#  [142] "updated"               "won"                   "wont"
#  [145] "workable"              "bit"                   "box"
#  [148] "charged"               "happen"                "opened"
#  [151] "put"                   "seconds"               "stay"
#  [154] "worked"                "apps"                  "awful"
#  [157] "borrowing"             "clear"                 "enjoy"
#  [160] "friends"               "person"                "pictures"
#  [163] "savvy"                 "tech"                  "tips"
#  [166] "tricks"                "alot"                  "book"
#  [169] "couldn"                "experience"            "figure"
#  [172] "found"                 "minder"                "minute"
#  [175] "online"                "prime"                 "purchased"
#  [178] "sending"               "set"                   "sound"
#  [181] "version"               "bring"                 "long"
#  [184] "message"               "order"                 "time"
#  [187] "vidpysuyut"            "advertised"            "gsm"
#  [190] "make"                  "mms"                   "ordered"
#  [193] "perfect"               "seller"                "texting"
#  [196] "cheap"                 "deal"                  "family"
#  [199] "hated"                 "horrible"              "service"
#  [202] "slow"                  "wifi"                  "boyfriend"
#  [205] "chinese"               "clone"                 "company"
#  [208] "delivered"             "fear"                  "gift"
#  [211] "notice"                "original"              "yesterday"
#  [214] "hook"                  "metro"                 "number"
#  [217] "wasting"               "cell"                  "defect"
#  [220] "equipment"             "failure"               "fulfilled"
#  [223] "management"            "memory"                "models"
#  [226] "present"               "recommend"             "accept"
#  [229] "anymore"               "attempt"               "badly"
#  [232] "battery"               "charge"                "charging"
#  [235] "concerned"             "couple"                "didn"
#  [238] "digicel"               "ebay"                  "economy"
#  [241] "fix"                   "freeze"                "hard"
#  [244] "hopeful"               "hoping"                "hour"
#  [247] "hours"                 "hurt"                  "initial"
#  [250] "jamaica"               "left"                  "liable"
#  [253] "living"                "makes"                 "minutes"
#  [256] "moment"                "mother"                "offered"
#  [259] "office"                "overheat"              "part"
#  [262] "parts"                 "presently"             "products"
#  [265] "promises"              "purchasing"            "quality"
#  [268] "rating"                "recently"              "reflects"
#  [271] "refused"               "remained"              "returned"
#  [274] "sell"                  "services"              "show"
#  [277] "star"                  "started"               "stated"
#  [280] "stuck"                 "takes"                 "taking"
#  [283] "tested"                "usa"                   "vacation"
#  [286] "website"               "year"                  "callers"
#  [289] "frequently"            "hear"                  "made"
#  [292] "poor"                  "reset"                 "speaker"
#  [295] "device"                "obvious"               "prior"
#  [298] "sheet"                 "smartphone"            "asked"
#  [301] "case"                  "cheating"              "court"
#  [304] "raise"                 "apple"                 "guaranty"
#  [307] "loss"                  "mic"                   "sold"
#  [310] "store"                 "told"                  "works"
#  [313] "buy"                   "damaged"               "don"
#  [316] "expected"              "hair"                  "honor"
#  [319] "indicators"            "properties"            "pulling"
#  [322] "repair"                "resistant"             "run"
#  [325] "sealed"                "sony"                  "spite"
#  [328] "washed"                "water"                 "advised"
#  [331] "confusing"             "existent"              "life"
#  [334] "material"              "spanish"               "niece"
#  [337] "cards"                 "couldnt"               "didnt"
#  [340] "knew"                  "bug"                   "download"
#  [343] "forever"               "hang"                  "load"
#  [346] "people"                "simple"                "smart"
#  [349] "sucks"                 "wouldn"                "china"
#  [352] "cover"                 "pay"                   "shipping"
#  [355] "terrible"              "basis"                 "beware"
#  [358] "blames"                "buyer"                 "code"
#  [361] "continues"             "dealership"            "defective"
#  [364] "directly"              "happy"                 "located"
#  [367] "location"              "lock"                  "low"
#  [370] "motorola"              "place"                 "puk"
#  [373] "support"               "texas"                 "unlock"
#  [376] "walk"                  "chews"                 "dead"
#  [379] "describe"              "ends"                  "full"
#  [382] "hog"                   "idle"                  "initially"
#  [385] "morning"               "overnight"             "owned"
#  [388] "plugged"               "pos"                   "power"
#  [391] "unused"                "words"                 "doesnt"
#  [394] "expesive"              "noney"                 "broken"
#  [397] "lit"                   "screen"                "wouldnt"
#  [400] "biggest"               "finally"               "half"
#  [403] "internal"              "lack"                  "market"
#  [406] "move"                  "quit"                  "room"
#  [409] "sd"                    "totally"               "turns"
#  [412] "worth"                 "certified"             "dont"
#  [415] "folks"                 "frm"                   "gamble"
#  [418] "items"                 "learn"                 "ohterwise"
#  [421] "sellers"               "spending"              "total"
#  [424] "vegas"                 "youre"                 "adefect"
#  [427] "calling"               "change"                "coz"
#  [430] "echo"                  "fails"                 "front"
#  [433] "rear"                  "restart"               "restore"
#  [436] "series"                "specially"             "stops"
#  [439] "baterry"               "functione"             "recieve"
#  [442] "send"                  "upset"                 "buying"
#  [445] "putting"               "question"              "unhappy"
#  [448] "cellphones"            "complain"              "day"
#  [451] "lithium"               "loose"                 "receive"
#  [454] "start"                 "taket"                 "absolutely"
#  [457] "angle"                 "connection"            "difficult"
#  [460] "legit"                 "respond"               "save"
#  [463] "slowly"                "touch"                 "trust"
#  [466] "view"                  "christmas"             "contacting"
#  [469] "correctly"             "discovered"            "early"
#  [472] "email"                 "fi"                    "guarantee"
#  [475] "informed"              "installed"             "january"
#  [478] "late"                  "luck"                  "mark"
#  [481] "microsd"               "nearby"                "recognize"
#  [484] "september"             "talking"               "tree"
#  [487] "wi"                    "arrived"               "conformed"
#  [490] "dual"                  "properly"              "slot"
#  [493] "stable"                "account"               "cancels"
#  [496] "eligible"              "evidently"             "expect"
#  [499] "line"                  "multiple"              "option"
#  [502] "orders"                "plan"                  "ran"
#  [505] "resubmit"              "review"                "sale"
#  [508] "ship"                  "shows"                 "status"
#  [511] "upgrade"               "verify"                "websites"
#  [514] "wireless"              "freezing"              "hanging"
#  [517] "pretty"                "bellevue"              "components"
#  [520] "dealz"                 "form"                  "match"
#  [523] "numbers"               "serial"                "software"
#  [526] "suspicious"            "thousand"              "wa"
#  [529] "actions"               "locks"                 "returning"
#  [532] "sitting"               "table"                 "trouble"
#  [535] "activitate"            "altered"               "owner"
#  [538] "unable"                "apk"                   "cold"
#  [541] "contract"              "current"               "defeats"
#  [544] "downloaded"            "end"                   "fail"
#  [547] "files"                 "flash"                 "flaws"
#  [550] "forsaken"              "god"                   "hardware"
#  [553] "higher"                "idea"                  "include"
#  [556] "install"               "larger"                "legitimate"
#  [559] "length"                "markup"                "mere"
#  [562] "merit"                 "messages"              "micro"
#  [565] "occurs"                "point"                 "previous"
#  [568] "proceeds"              "purpose"               "rate"
#  [571] "reason"                "receiving"             "responsive"
#  [574] "restarts"              "simply"                "skype"
#  [577] "small"                 "stars"                 "storage"
#  [580] "suck"                  "usage"                 "worse"
#  [583] "answered"              "dec"                   "emailed"
#  [586] "area"                  "checked"               "codes"
#  [589] "compatible"            "list"                  "listened"
#  [592] "posted"                "cellphone"             "changed"
#  [595] "junk"                  "piece"                 "selling"
#  [598] "twicw"                 "chinesse"              "extranged"
#  [601] "gps"                   "nfc"                   "rooted"
#  [604] "expecting"             "extra"                 "fixed"
#  [607] "inside"                "lot"                   "open"
#  [610] "venezuela"             "wich"                  "cam"
#  [613] "dollar"                "galaxy"                "gs"
#  [616] "trash"                 "utter"                 "caller"
#  [619] "garbage"               "lousy"                 "speak"
#  [622] "ahhhh"                 "degrades"              "fourth"
#  [625] "reboots"               "results"               "screeches"
#  [628] "shuts"                 "voice"                 "ago"
#  [631] "allover"               "answer"                "background"
#  [634] "candy"                 "charger"               "contact"
#  [637] "crush"                 "damage"                "default"
#  [640] "defected"              "downloads"             "drains"
#  [643] "facebook"              "instance"              "language"
#  [646] "manual"                "noise"                 "noticed"
#  [649] "operate"               "ordering"              "placing"
#  [652] "programmed"            "questions"             "refund"
#  [655] "snapchat"              "times"                 "tip"
#  [658] "user"                  "weeks"                 "attention"
#  [661] "comment"               "wasted"                "accepting"
#  [664] "earn"                  "en"                    "port"
#  [667] "sloppy"                "bounced"               "button"
#  [670] "claimed"               "connect"               "connected"
#  [673] "contacts"              "difficulty"            "hooking"
#  [676] "inactive"              "internet"              "net"
#  [679] "paying"                "pressed"               "responded"
#  [682] "side"                  "sucked"                "switch"
#  [685] "transfer"              "wierdly"               "depressing"
#  [688] "dollars"               "madfe"                 "spent"
#  [691] "straight"              "talk"                  "country"
#  [694] "cpu"                   "establish"             "lcd"
#  [697] "talkie"                "walkie"                "advertise"
#  [700] "business"              "crooks"                "false"
#  [703] "fee"                   "opinion"               "prepaid"
#  [706] "require"               "stock"                 "highly"
#  [709] "im"                    "bay"                   "belongs"
#  [712] "bottom"                "free"                  "lgc"
#  [715] "prefer"                "dell"                  "faulty"
#  [718] "hangs"                 "broke"                 "condition"
#  [721] "dirty"                 "wall"                  "wasnt"
#  [724] "cord"                  "gave"                  "hold"
#  [727] "possibly"              "showed"                "strive"
#  [730] "turning"               "wife"                  "years"
#  [733] "barely"                "blury"                 "moves"
#  [736] "photos"                "advertises"            "basically"
#  [739] "mp"                    "places"                "player"
#  [742] "veryy"                 "angry"                 "animal"
#  [745] "annoying"              "apparently"            "care"
#  [748] "constantly"            "csi"                   "dropped"
#  [751] "entire"                "feature"               "flipping"
#  [754] "giving"                "hand"                  "headphone"
#  [757] "headphones"            "house"                 "idiots"
#  [760] "jack"                  "listening"             "machine"
#  [763] "men"                   "pinky"                 "pocket"
#  [766] "prevents"              "realize"               "securely"
#  [769] "shorten"               "smell"                 "stabilize"
#  [772] "sticking"              "tangled"               "upside"
#  [775] "week"                  "app"                   "darkens"
#  [778] "emails"                "flickers"              "guess"
#  [781] "haven"                 "ive"                   "lie"
#  [784] "plastic"               "push"                  "randomly"
#  [787] "select"                "worst"                 "android"
#  [790] "blocky"                "child"                 "close"
#  [793] "compared"              "fb"                    "feels"
#  [796] "firstly"               "hit"                   "iosthe"
#  [799] "knockoffs"             "lacking"               "microsoft"
#  [802] "microsofts"            "miss"                  "party"
#  [805] "plain"                 "playing"               "saddled"
#  [808] "sadly"                 "selection"             "stupid"
#  [811] "tiles"                 "twitter"               "ui"
#  [814] "useless"               "whatsapp"              "yelp"
#  [817] "gimmic"                "loan"                  "package"
#  [820] "waited"                "wasn"                  "asap"
#  [823] "failed"                "label"                 "wait"
#  [826] "wanted"                "beautiful"             "fact"
#  [829] "impossible"            "inaccurate"            "phantom"
#  [832] "response"              "touches"               "dontthink"
#  [835] "lemon"                 "picture"               "white"
#  [838] "factory"               "friend"                "shutting"
#  [841] "messing"               "similar"               "important"
#  [844] "issues"                "lots"                  "note"
#  [847] "replaced"              "slowest"               "speed"
#  [850] "trree"                 "versions"              "activating"
#  [853] "blank"                 "blink"                 "dies"
#  [856] "opening"               "previously"            "scam"
#  [859] "cameras"               "capable"               "cellular"
#  [862] "cool"                  "dedicated"             "hspa"
#  [865] "kludge"                "predates"              "random"
#  [868] "ready"                 "sea"                   "suppose"
#  [871] "symbian"               "felt"                  "nt"
#  [874] "sand"                  "scraches"              "making"
#  [877] "regret"                "buzz"                  "constant"
#  [880] "happening"             "hears"                 "id"
#  [883] "changing"              "check"                 "interior"
#  [886] "prepared"              "suddenly"              "supplier"
#  [889] "word"                  "duplicated"            "achieve"
#  [892] "bother"                "decent"                "enemy"
#  [895] "horrid"                "joke"                  "laptop"
#  [898] "mode"                  "noteworthy"            "reliable"
#  [901] "remember"              "standby"               "stick"
#  [904] "tv"                    "tvs"                   "boot"
#  [907] "loop"                  "mexico"                "provide"
#  [910] "release"               "amazom"                "beating"
#  [913] "buttons"               "corning"               "cracked"
#  [916] "droid"                 "glass"                 "gorilla"
#  [919] "loved"                 "screan"                "ultra"
#  [922] "bloatware"             "difference"            "exchanging"
#  [925] "mine"                  "sgh"                   "therefor"
#  [928] "updates"               "allowed"               "customs"
#  [931] "destroyed"             "knowing"               "watch"
#  [934] "wrist"                 "bloody"                "boris"
#  [937] "chrips"                "countries"             "dial"
#  [940] "fine"                  "glad"                  "guysi"
#  [943] "nither"                "peple"                 "perfectly"
#  [946] "phoning"               "puprpose"              "situation"
#  [949] "speaking"              "supported"             "games"
#  [952] "graphics"              "horriblein"            "suckssome"
#  [955] "voices"                "drops"                 "middle"
#  [958] "carrier"               "ability"               "apn"
#  [961] "begs"                  "blackberry"            "blows"
#  [964] "break"                 "calculator"            "chore"
#  [967] "compare"               "continue"              "doug"
#  [970] "downhill"              "drive"                 "ears"
#  [973] "easily"                "finished"              "goodbye"
#  [976] "heads"                 "historic"              "home"
#  [979] "interface"             "itll"                  "keyboards"
#  [982] "mad"                   "main"                  "nag"
#  [985] "past"                  "percentage"            "physical"
#  [988] "press"                 "quickly"               "qwerty"
#  [991] "ridiculed"             "smaller"               "specific"
#  [994] "steam"                 "sumatra"               "swipe"
#  [997] "tedious"               "tiny"                  "upwards"
# [1000] "visiting"              "webpage"               "window"
# [1003] "wiped"                 "freezes"               "shocked"
# [1006] "speechless"            "compact"               "crap"
# [1009] "excuse"                "managing"              "minuets"
# [1012] "music"                 "real"                  "rings"
# [1015] "ringtone"              "school"                "thick"
# [1018] "till"                  "waiting"               "wallpapers"
# [1021] "announces"             "anuncia"               "aparte"
# [1024] "como"                  "da"                    "equipos"
# [1027] "estan"                 "fault"                 "llamas"
# [1030] "nuevos"                "son"                   "vende"
# [1033] "짹ados"                "cost"                  "grrr"
# [1036] "item"                  "needless"              "ups"
# [1039] "evil"                  "grab"                  "plate"
# [1042] "signal"                "bloquea"               "celular"
# [1045] "crashes"               "de"                    "english"
# [1048] "es"                    "este"                  "funciona"
# [1051] "idioma"                "ingles"                "la"
# [1054] "malo"                  "mara"                  "pasa"
# [1057] "pass"                  "se"                    "su"
# [1060] "terribly"              "짹al"                  "쩌nico"
# [1063] "agree"                 "badplease"             "butts"
# [1066] "camperthis"            "charges"               "dang"
# [1069] "fing"                  "idk"                   "kyocera"
# [1072] "nowi"                  "optimus"               "phonei"
# [1075] "pleased"               "pleaseread"            "sucksthis"
# [1078] "thisi"                 "traded"                "wat"
# [1081] "workdont"              "click"                 "closed"
# [1084] "top"                   "customer"              "literally"
# [1087] "abruptly"              "address"               "bedside"
# [1090] "bucks"                 "clock"                 "cut"
# [1093] "favor"                 "glitch"                "needed"
# [1096] "supposed"              "weren"                 "continuing"
# [1099] "rediculous"            "resetting"             "canada"
# [1102] "concludes"             "moved"                 "pops"
# [1105] "listed"                "listings"              "duties"
# [1108] "loosing"               "periods"               "fraudulent"
# [1111] "running"               "cheek"                 "hits"
# [1114] "programs"              "blu"                   "breed"
# [1117] "contacted"             "evident"               "glance"
# [1120] "searching"             "seek"                  "sucking"
# [1123] "town"                  "blow"                  "control"
# [1126] "reccomend"             "branch"                "calderon"
# [1129] "centura"               "claims"                "executive"
# [1132] "fl"                    "karen"                 "lesser"
# [1135] "ma"                    "miami"                 "offer"
# [1138] "optioned"              "prl"                   "proclaim"
# [1141] "recall"                "refuse"                "resolved"
# [1144] "talks"                 "technical"             "tracfone"
# [1147] "cat"                   "clean"                 "concrete"
# [1150] "david"                 "design"                "disposable"
# [1153] "door"                  "floor"                 "guy"
# [1156] "mail"                  "named"                 "referred"
# [1159] "scratch"               "screws"                "sink"
# [1162] "sweaty"                "tabs"                  "bogus"
# [1165] "colorado"              "cricket"               "deals"
# [1168] "deceit"                "flashed"               "grandson"
# [1171] "job"                   "kansas"                "lied"
# [1174] "live"                  "purposely"             "sarcasm"
# [1177] "surely"                "type"                  "begin"
# [1180] "borrow"                "car"                   "death"
# [1183] "discharges"            "emergency"             "fancy"
# [1186] "gbmy"                  "husband"               "idleness"
# [1189] "kidding"               "leave"                 "matter"
# [1192] "means"                 "moto"                  "night"
# [1195] "percent"               "perform"               "period"
# [1198] "plug"                  "pushed"                "report"
# [1201] "rest"                  "search"                "secret"
# [1204] "stranded"              "unreliable"            "ata"
# [1207] "pieces"                "sells"                 "worki"
# [1210] "brought"               "deserves"              "greater"
# [1213] "networks"              "penny"                 "puts"
# [1216] "reply"                 "searches"              "sister"
# [1219] "teenage"               "tmobile"               "brazil"
# [1222] "document"              "stores"                "girl"
# [1225] "chooses"               "crappy"                "fitst"
# [1228] "bday"                  "provider"              "electronic"
# [1231] "offline"               "applied"               "assume"
# [1234] "batterys"              "caution"               "fien"
# [1237] "normal"                "stickers"              "threw"
# [1240] "wind"                  "bars"                  "audio"
# [1243] "beats"                 "interested"            "mistake"
# [1246] "processing"            "slapped"               "due"
# [1249] "goodphone"             "moregave"              "mymoney"
# [1252] "seas"                  "toits"                 "allot"
# [1255] "avalon"                "believed"              "bells"
# [1258] "catalina"              "causing"               "cheesy"
# [1261] "die"                   "distorted"             "forward"
# [1264] "highest"               "ii"                    "island"
# [1267] "keypad"                "missed"                "mom"
# [1270] "ocean"                 "older"                 "par"
# [1273] "pick"                  "realized"              "reception"
# [1276] "satellite"             "single"                "slide"
# [1279] "sounds"                "sparq"                 "throw"
# [1282] "topside"               "video"                 "walked"
# [1285] "whistles"              "attached"              "coming"
# [1288] "holds"                 "panel"                 "snap"
# [1291] "display"               "heated"                "light"
# [1294] "spend"                 "dose"                  "dosent"
# [1297] "exact"                 "kona"                  "page"
# [1300] "surf"                  "surfing"               "web"
# [1303] "chipped"               "count"                 "dents"
# [1306] "durable"               "hasn"                  "land"
# [1309] "paint"                 "riddled"               "space"
# [1312] "sucker"                "unplugged"             "acted"
# [1315] "dark"                  "aka"                   "blocked"
# [1318] "buts"                  "carries"               "computer"
# [1321] "conswhat"              "costs"                 "devices"
# [1324] "forget"                "google"                "hd"
# [1327] "iii"                   "includes"              "including"
# [1330] "loud"                  "movie"                 "paranoid"
# [1333] "passwords"             "portable"              "pros"
# [1336] "public"                "rarely"                "recognized"
# [1339] "reflection"            "repeat"                "savings"
# [1342] "science"               "security"              "starts"
# [1345] "states"                "studied"               "united"
# [1348] "usb"                   "warns"                 "watching"
# [1351] "stil"                  "boost"                 "loses"
# [1354] "molasses"              "numerous"              "occasions"
# [1357] "providers"             "risk"                  "switching"
# [1360] "anuncio"               "aqu"                   "calificaci"
# [1363] "cdma"                  "choose"                "compa"
# [1366] "con"                   "del"                   "devoluci"
# [1369] "devolverlo"            "dinero"                "el"
# [1372] "elijo"                 "esa"                   "eso"
# [1375] "esta"                  "garantiza"             "lado"
# [1378] "lo"                    "mi"                    "motivado"
# [1381] "motivated"             "ning"                  "ninguna"
# [1384] "odio"                  "perd"                  "pero"
# [1387] "poder"                 "por"                   "porque"
# [1390] "puedo"                 "quisiera"              "tanto"
# [1393] "technology"            "tecnolog"              "tel"
# [1396] "trabaja"               "usar"                  "usarlo"
# [1399] "채fono"                "body"                  "lens"
# [1402] "scratched"             "colors"                "customize"
# [1405] "gold"                  "gray"                  "silver"
# [1408] "died"                  "drawer"                "assuming"
# [1411] "blah"                  "delete"                "irritating"
# [1414] "pics"                  "randomness"            "size"
# [1417] "sorts"                 "texts"                 "things"
# [1420] "humming"               "additions"             "bloat"
# [1423] "incredibly"            "specs"                 "thanking"
# [1426] "zte"                   "fast"                  "imagine"
# [1429] "situations"            "adequate"              "ancient"
# [1432] "arrival"               "avoid"                 "bath"
# [1435] "bummed"                "choice"                "coffee"
# [1438] "convoluted"            "decade"                "fabulous"
# [1441] "flicker"               "flip"                  "frustrated"
# [1444] "heeded"                "holding"               "menu"
# [1447] "positive"              "record"                "request"
# [1450] "sick"                  "track"                 "warnings"
# [1453] "elite"                 "reverb"                "switched"
# [1456] "upgraded"              "addition"              "claim"
# [1459] "cloudy"                "extremely"             "fell"
# [1462] "film"                  "ringtones"             "short"
# [1465] "chance"                "cuz"                   "tons"
# [1468] "caused"                "cons"                  "disclaimer"
# [1471] "east"                  "goodvery"              "itit"
# [1474] "nicelite"              "ratings"               "screeni"
# [1477] "smashing"              "walls"                 "weak"
# [1480] "ac"                    "action"                "adapter"
# [1483] "ainol"                 "anywhereon"            "athe"
# [1486] "awake"                 "blood"                 "blutoothit"
# [1489] "build"                 "bull"                  "cash"
# [1492] "clarity"               "clue"                  "connector"
# [1495] "controls"              "cuts"                  "damn"
# [1498] "defects"               "driver"                "drivers"
# [1501] "editing"               "fair"                  "fedex"
# [1504] "fewit"                 "gb"                    "glory"
# [1507] "goo"                   "gpsthere"              "guys"
# [1510] "handy"                 "insists"               "isand"
# [1513] "large"                 "locally"               "marketed"
# [1516] "mass"                  "microsdit"             "mild"
# [1519] "minecraft"             "modded"                "nexus"
# [1522] "novo"                  "offit"                 "operating"
# [1525] "pad"                   "pain"                  "picked"
# [1528] "plays"                 "quadcore"              "ram"
# [1531] "rom"                   "romand"                "romcases"
# [1534] "round"                 "royal"                 "shadythe"
# [1537] "site"                  "sluggish"              "supports"
# [1540] "tablet"                "toolyou"               "trigger"
# [1543] "tweaked"               "unit"                  "usbit"
# [1546] "useit"                 "usps"                  "wellwifi"
# [1549] "wierd"                 "world"                 "xp"
# [1552] "broked"                "strap"                 "crash"
# [1555] "eventually"            "shot"                  "falling"
# [1558] "lifting"               "biased"                "research"
# [1561] "mini"                  "regular"               "accident"
# [1564] "correct"               "easy"                  "hell"
# [1567] "neva"                  "ova"                   "soo"
# [1570] "textin"                "wud"                   "camper"
# [1573] "kid"                   "xmas"                  "agreed"
# [1576] "functional"            "keyboard"              "keys"
# [1579] "letters"               "awesome"               "heading"
# [1582] "pricing"               "rip"                   "shock"
# [1585] "specialty"             "worthy"                "accessible"
# [1588] "registered"            "touched"               "appeared"
# [1591] "concluded"             "level"                 "trick"
# [1594] "generic"               "shotty"                "wavers"
# [1597] "rated"                 "huge"                  "beat"
# [1600] "expectinv"             "lose"                  "lyed"
# [1603] "purchases"             "recorded"              "si"
# [1606] "cache"                 "chrome"                "clearing"
# [1609] "crashed"               "crashing"              "gmail"
# [1612] "temporary"             "fully"                 "overheated"
# [1615] "recharge"              "recharged"             "adjust"
# [1618] "alerts"                "alpha"                 "beta"
# [1621] "blinding"              "brightness"            "catch"
# [1624] "dim"                   "fixes"                 "goodcons"
# [1627] "nit"                   "picky"                 "remove"
# [1630] "restarting"            "ringers"               "rooms"
# [1633] "root"                  "rundown"               "shadowed"
# [1636] "slew"                  "summary"               "underwater"
# [1639] "warning"               "bills"                 "sims"
# [1642] "edge"                  "hydro"                 "outdated"
# [1645] "super"                 "shockproof"            "waterproof"
# [1648] "mailbox"               "showing"               "bbb"
# [1651] "credit"                "cynthia"               "excited"
# [1654] "fraud"                 "generous"              "hare"
# [1657] "jan"                   "nightmare"             "password"
# [1660] "sign"                  "stating"               "tracking"
# [1663] "workers"               "tasks"                 "dialing"
# [1666] "incapble"              "scrached"              "ayer"
# [1669] "bajo"                  "concepto"              "detalla"
# [1672] "econ"                  "enga"                  "entienden"
# [1675] "esto"                  "fiasco"                "informaci"
# [1678] "ingl"                  "llego"                 "los"
# [1681] "mica"                  "mismo"                 "ni"
# [1684] "para"                  "pile"                  "publicidad"
# [1687] "recomiendo"            "siquiera"              "tiene"
# [1690] "una"                   "verdad"                "verdadero"
# [1693] "versi"                 "짤fono"                "짤s"
# [1696] "짹osa"                 "쩌n"                   "bar"
# [1699] "hot"                   "shame"                 "windows"
# [1702] "advanced"              "connecting"            "escalated"
# [1705] "function"              "lte"                   "team"
# [1708] "thousands"             "deadline"              "febuary"
# [1711] "tracing"               "customers"             "flimsy"
# [1714] "funny"                 "happened"              "launched"
# [1717] "shell"                 "surprise"              "surprised"
# [1720] "amazing"               "black"                 "face"
# [1723] "feel"                  "horribly"              "loudest"
# [1726] "pushing"               "quiet"                 "setting"
# [1729] "speeds"                "ha"                    "jitterbug"
# [1732] "plans"                 "firmware"              "india"
# [1735] "operator"              "prompted"              "force"
# [1738] "baited"                "edges"                 "fuss"
# [1741] "marring"               "minor"                 "odds"
# [1744] "receipt"               "recipients"            "shrink"
# [1747] "wrap"                  "wrapped"               "drags"
# [1750] "expired"               "feet"                  "letting"
# [1753] "suggest"               "terms"                 "uncertain"
# [1756] "beloved"               "seands"                "wana"
# [1759] "wished"                "cute"                  "decided"
# [1762] "final"                 "quick"                 "renown"
# [1765] "sms"                   "xperia"                "apples"
# [1768] "booting"               "july"                  "las"
# [1771] "mid"                   "mile"                  "originally"
# [1774] "removing"              "replacing"             "signs"
# [1777] "technician"            "trip"                  "automail"
# [1780] "cords"                 "wiggle"                "reached"
# [1783] "absolute"              "eof"                   "headache"
# [1786] "it\xe2\u0080\xb0"      "justice"               "meomory"
# [1789] "prevent"               "짧ll"                  "december"
# [1792] "meet"                  "arising"               "btw"
# [1795] "buffered"              "clicked"               "compensate"
# [1798] "covering"              "fiance"                "lucky"
# [1801] "shipment"              "smoothly"              "strongly"
# [1804] "vivid"                 "worn"                  "appstore"
# [1807] "birds"                 "flappy"                "fusion"
# [1810] "incredible"            "instagram"             "isn"
# [1813] "lame"                  "madden"                "format"
# [1816] "bbm"                   "deception"             "delivery"
# [1819] "discharged"            "explain"               "lasts"
# ...
# [5764] "nba"                   "nowthe"                "riptide"
# [5767] "surpasses"             "albums"                "angular"
# [5770] "arrogant"              "backside"              "beneath"
# [5773] "bind"                  "bodies"                "boring"
# [5776] "capacitive"            "crop"                  "demo"
# [5779] "dimensions"            "dimpled"               "dominant"
# [5782] "dreaded"               "employed"              "faux"
# [5785] "fearing"               "flack"                 "flanked"
# [5788] "flatter"               "heartedly"             "jumps"
# [5791] "launches"              "maker"                 "modes"
# [5794] "natural"               "oz"                    "pixelation"
# [5797] "produce"               "profile"               "profiles"
# [5800] "reviewer"              "roundness"             "shoot"
# [5803] "square"                "squared"               "street"
# [5806] "stutter"               "subjective"            "suggests"
# [5809] "tallest"               "thickest"              "vastly"
# [5812] "weighs"                "widest"                "usevoice"
# [5815] "volumefast"            "dcreen"                "splash"
# [5818] "recbi"                 "batter"                "elected"
# [5821] "margins"               "packet"                "profit"
# [5824] "rumor"                 "sailing"               "solves"
# [5827] "alongside"             "breather"              "deeply"
# [5830] "dimming"               "extension"             "impress"
# [5833] "maxes"                 "pleasing"              "priorities"
# [5836] "regard"                "sexier"                "strengths"
# [5839] "unblock"               "weaknesses"            "bike"
# [5842] "electric"              "erica"                 "griffin"
# [5845] "ota"                   "primary"               "proofness"
# [5848] "rainy"                 "qwert"                 "mejor"
# [5851] "satisfecho"            "airtime"               "analyze"
# [5854] "blind"                 "catches"               "compelled"
# [5857] "concert"               "fallen"                "fanatic"
# [5860] "gaze"                  "judgement"             "leaks"
# [5863] "shouldnt"              "stole"                 "surprises"
# [5866] "tvcons"                "unfocusing"            "classeasy"
# [5869] "amateur"               "duper"                 "industrial"
# [5872] "leagues"               "parameters"            "steroeo"
# [5875] "superbly"              "becsuse"               "hace"
# [5878] "prosscesor"            "shopped"               "assumed"
# [5881] "cardart"               "leg"                   "term"
# [5884] "matte"                 "belt"                  "clam"
# [5887] "industry"              "sandwiches"            "scabbard"
# [5890] "vxx"                   "duable"                "inferno"
# [5893] "impaired"              "farther"               "fragile"
# [5896] "likewise"              "althought"             "gigantic"
# [5899] "growing"               "hype"                  "lacky"
# [5902] "overloaded"            "refinement"            "samll"
# [5905] "fighting"              "punctual"              "convient"
# [5908] "squareness"            "aus"                   "widely"
# [5911] "relation"              "doesn\xe2\u0080\xb0"   "amaizing"
# [5914] "destroys"              "multitask"             "bmp"
# [5917] "cushions"              "defender"              "kits"
# [5920] "lightly"               "midnight"              "nightstand"
# [5923] "occasion"              "pelican"               "routed"
# [5926] "swipes"                "tasker"                "tinkering"
# [5929] "barnyard"              "unlimted"              "barrel"
# [5932] "dryer"                 "hurray"                "qt"
# [5935] "spoil"                 "wash"                  "boat"
# [5938] "chipset"               "crippling"             "editor"
# [5941] "exynos"                "headaches"             "kb"
# [5944] "measured"              "severe"                "traveler"
# [5947] "insanely"              "onboard"               "shove"
# [5950] "absorption"            "advertize"             "align"
# [5953] "androidify"            "apple\xe2\u0080\xb0"   "awe"
# [5956] "bedrooms"              "boom"                  "buttery"
# [5959] "cortex"                "crank"                 "cyclone"
# [5962] "designs"               "disks"                 "docs"
# [5965] "drainage"              "driven"                "earth"
# [5968] "ext"                   "fitness"               "garmin"
# [5971] "gm"                    "hasa"                  "host"
# [5974] "hosts"                 "hve"                   "infrared"
# [5977] "intl"                  "ironed"                "iterated"
# [5980] "kg"                    "krait"                 "linkedin"
# [5983] "maturity"              "mileage"               "mindcamera"
# [5986] "misc"                  "moon"                  "moot"
# [5989] "msm"                   "nailing"               "nature"
# [5992] "navigon"               "ndisputed"             "obsoletion"
# [5995] "offices"               "oily"                  "perforated"
# [5998] "plethora"              "podcasts"              "preview"
# [6001] "receivers"             "regimen"               "reputed"
# [6004] "sample"                "sar"                   "sizes"
# [6007] "space\xe2\u0080\xb0"   "specifics"             "stats"
# [6010] "streamer"              "stunning"              "subsonic"
# [6013] "suggestion"            "syndrome"              "tactile"
# [6016] "tapatalk"              "themes"                "tom"
# [6019] "twit"                  "underrated"            "upto"
# [6022] "variants"              "voiceask"              "walking"
# [6025] "lightness"             "ailments"              "arthritis"
# [6028] "inlays"                "macular"               "microcell"
# [6031] "thous"                 "tones"                 "portion"
# [6034] "stylish"               "tho"                   "antenna"
# [6037] "friedman"              "gregg"                 "hectic"
# [6040] "spells"                "workday"               "est"
# [6043] "study"                 "conducts"              "courteous"
# [6046] "resell"                "inevitable"            "valuable"
# [6049] "ace"                   "beginners"             "cosmetic"
# [6052] "seamlessly"            "bless"                 "joy"
# [6055] "bean"                  "jelly"                 "okim"
# [6058] "whould"                "kindle"                "planning"
# [6061] "sporadic"              "promissed"             "sat"
# [6064] "anctipated"            "repacement"            "comapnies"
# [6067] "itime"                 "leek"                  "overal"
# [6070] "reseaching"            "sinse"                 "sp"
# [6073] "sumsung"               "greati"                "assigned"
# [6076] "hurts"                 "medley"                "comunicate"
# [6079] "nicelly"               "effortless"            "login"
# [6082] "geared"                "mixed"                 "nifty"
# [6085] "inquiring"             "motorolo"              "risky"
# [6088] "classic"               "confidence"            "gents"
# [6091] "richness"              "argentina"             "lags"
# [6094] "smarttalk"             "desing"                "agitate"
# [6097] "hesitated"             "planwhile"             "algo"
# [6100] "cancelar"              "cantidad"              "costo"
# [6103] "deber"                 "desbloqueo"            "fue"
# [6106] "justo"                 "ofertado"              "ofertar"
# [6109] "parece"                "parte"                 "recibido"
# [6112] "reimburse"             "tuve"                  "htcdev"
# [6115] "gusta"                 "worksto"               "batts"
# [6118] "finishing"             "rates"                 "upmid"
# [6121] "androids"              "utility"               "책"
# [6124] "첨책"                  "perfec"                "selfie"
# [6127] "tobago"                "adds"                  "audiothis"
# [6130] "behave"                "behaviors"             "benchmarks"
# [6133] "brights"               "camerathis"            "complains"
# [6136] "conclude"              "deeper"                "designthe"
# [6139] "displays"              "equation"              "executes"
# [6142] "fitting"               "food"                  "frontal"
# [6145] "gains"                 "heaviest"              "hipster"
# [6148] "lowest"                "modify"                "patterns"
# [6151] "privileges"            "prolly"                "restricted"
# [6154] "resume"                "sacrifices"            "sanpdragon"
# [6157] "screenthe"             "solved"                "topic"
# [6160] "tricky"                "ufocus"                "interest"
# [6163] "batery"                "migrating"             "intensely"
# [6166] "venezuelan"            "cheapest"              "awesomely"
# [6169] "ice"                   "thinner"               "motto"
# [6172] "rejecting"             "sizeand"               "uncommon"
# [6175] "commitment"            "bud"                   "evrything"
# [6178] "visual"                "booster"               "adn"
# [6181] "comercial"             "promise"               "todo"
# [6184] "decently"              "enlarging"             "handed"
# [6187] "phtablet"              "toilet"                "intending"
# [6190] "rules"                 "adapted"               "community"
# [6193] "itwill"                "mobilei"               "osmmmm"
# [6196] "superbbbb"             "challenged"            "flips"
# [6199] "beatiful"              "ciudad"                "desde"
# [6202] "saludos"               "powerfull"             "amozon"
# [6205] "molested"              "tailwind"              "unrivaled"
# [6208] "batterly"              "brighter"              "overlays"
# [6211] "strings"               "amps"                  "aperture"
# [6214] "chamber"               "ecstatic"              "focusing"
# [6217] "gathering"             "muilti"                "passion"
# [6220] "pasted"                "sports"                "tracks"
# [6223] "혻"                    "hurry"                 "takeover"
# [6226] "timme"                 "wit"                   "daugther"
# [6229] "diamond"               "sparkles"              "evolved"
# [6232] "fasination"            "hammer"                "niffty"
# [6235] "smash"                 "internets"             "hq"
# [6238] "ins"                   "movilnet"              "requesting"
# [6241] "venzuela"              "aluminium"             "cpuit"
# [6244] "criteria"              "gravity"               "iosit"
# [6247] "maine"                 "primeit"               "ramit"
# [6250] "rural"                 "toughthe"              "unlockedi"
# [6253] "drew"                  "goodreads"             "heft"
# [6256] "illustra"              "amaze"                 "regarded"
# [6259] "speced"                "bout"                  "sooof"
# [6262] "takin"                 "excelllent"            "junkies"
# [6265] "cliff"                 "op"                    "finest"
# [6268] "inferior"              "collect"               "recharging"
# [6271] "realy"                 "easeir"                "eay"
# [6274] "prev"                  "produces"              "deff"
# [6277] "adept"                 "acclaimed"             "act"
# [6280] "animated"              "creator"               "gif"
# [6283] "intend"                "navigating"            "outputs"
# [6286] "panorama"              "pentax"                "praised"
# [6289] "remotely"              "sequence"              "spherical"
# [6292] "surround"              "universal"             "viewer"
# [6295] "bueno"                 "agil"                  "agile"
# [6298] "alta"                  "gama"                  "rapido"
# [6301] "todos"                 "veloz"                 "abd"
# [6304] "anazon"                "sonetines"             "twenty"
# [6307] "defenitely"            "recomended"            "sturdily"
# [6310] "boosters"              "elegance"              "hdmi"
# [6313] "minimize"              "miracast"              "freezy"
# [6316] "shocking"              "NA"                    "repent"
# [6319] "rain"                  "withstood"             "drums"
# [6322] "sounding"              "bandas"                "liberado"
# [6325] "telofono"              "gem"                   "peruse"
# [6328] "qualms"                "endless"               "jotting"
# [6331] "centro"                "avoids"                "collection"
# [6334] "onei"                  "ports"                 "quintupled"
# [6337] "receptacle"            "station\xe2\u0080\xb0" "acquainted"
# [6340] "breath"                "browse"                "viber"
# [6343] "whitedr"               "arirang"               "bumper"
# [6346] "killed"                "swapping"              "types"
# [6349] "malawi"                "phiojnes"              "sy"
# [6352] "fingertips"            "transfered"            "confort"
# [6355] "bbs"                   "robust"                "lovely"
# [6358] "nooooo"                "ilove"                 "prox"
# [6361] "noproblems"            "phoneand"              "phoneslike"
# [6364] "pack"                  "caboose"               "kickstand"
# [6367] "pointed"               "savy"                  "sorted"
# [6370] "tilt"

# %%
dtm.test <- DocumentTermMatrix(corpus,
                               control = list(tolower = T,
                                              removePunctuation = T,
                                              removeNumbers = T,
                                              wordLengths=c(2, 5),
                                              stopwords = stopwords("SMART"),
                                              weighting = weightTfIdf,
                                              dictionary = Terms(dtm)))
# Out:
# Error in tolower(txt): 'utf8towcs'내에 입력 'its a good good good good good product,sometimes little bit stuck<95>_<ce>all in all it's a good good product any more'이 잘못되었습니다
# Traceback:
#
# 1. DocumentTermMatrix(corpus, control = list(tolower = T, removePunctuation = T,
#  .     removeNumbers = T, wordLengths = c(2, 5), stopwords = stopwords("SMART"),
#  .     weighting = weightTfIdf, dictionary = Terms(dtm)))
# 2. t(TermDocumentMatrix(x, control))
# 3. TermDocumentMatrix(x, control)
# 4. TermDocumentMatrix.SimpleCorpus(x, control)
# 5. tolower(txt)

# %%
senti.lm.test <- polarity(dtm.test, names(pos.lm), names(neg.lm))
senti.lasso.test <- polarity(dtm.test, names(pos.lasso), names(neg.lasso))
senti.ridge.test <- polarity(dtm.test, names(pos.ridge), names(neg.ridge))
senti.elastic.test <- polarity(dtm.test, names(pos.elastic), names(neg.elastic))

senti.lm.b.test <- ifelse(senti.lm.test > 0, 1, 0)
senti.lasso.b.test <- ifelse(senti.lasso.test > 0, 1, 0)
senti.ridge.b.test <- ifelse(senti.ridge.test > 0, 1, 0)
senti.elastic.b.test <- ifelse(senti.elastic.test > 0, 1, 0)

library(caret)

confusionMatrix(senti.lm.b.test, data.test$Sentiment)
confusionMatrix(senti.lasso.b.test, data.test$Sentiment)
confusionMatrix(senti.ridge.b.test, data.test$Sentiment)
confusionMatrix(senti.elastic.b.test, data.test$Sentiment)
